# %%
import pandas as pd
import numpy as np
import os
import requests
from time import sleep

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Scryfall API

# %%
all_cards_path = os.path.join(os.getcwd(), 'data', 'all_scryfall.json')
all_cards_df = pd.DataFrame()
cards_url = 'https://api.scryfall.com/cards?page=1'
has_more = True
while has_more:
    res = requests.get(cards_url)
    
    if int(cards_url[-1]) % 10 == 0:
        print('Getting page {}'.format(cards_url))
    
    cards_df = pd.DataFrame.from_dict(res.json()['data'])

    all_cards_df = pd.concat([all_cards_df, cards_df], sort=True, ignore_index=True)
          
    has_more = res.json()['has_more']
    cards_url = res.json()['next_page']
    
    sleep(0.1)
    
all_cards_df.to_json(all_cards_path)
# Out:
# Getting page https://api.scryfall.com/cards?page=10
# Getting page https://api.scryfall.com/cards?page=20
# Getting page https://api.scryfall.com/cards?page=30
# Getting page https://api.scryfall.com/cards?page=40
# Getting page https://api.scryfall.com/cards?page=50
# Getting page https://api.scryfall.com/cards?page=60
# Getting page https://api.scryfall.com/cards?page=70
# Getting page https://api.scryfall.com/cards?page=80
# Getting page https://api.scryfall.com/cards?page=90
# Getting page https://api.scryfall.com/cards?page=100
# Getting page https://api.scryfall.com/cards?page=110
# Getting page https://api.scryfall.com/cards?page=120
# Getting page https://api.scryfall.com/cards?page=130
# Getting page https://api.scryfall.com/cards?page=140
# Getting page https://api.scryfall.com/cards?page=150
# Getting page https://api.scryfall.com/cards?page=160
# Getting page https://api.scryfall.com/cards?page=170
# Getting page https://api.scryfall.com/cards?page=180
# Getting page https://api.scryfall.com/cards?page=190
# Getting page https://api.scryfall.com/cards?page=200
# Getting page https://api.scryfall.com/cards?page=210
# Getting page https://api.scryfall.com/cards?page=220
# Getting page https://api.scryfall.com/cards?page=230
# Getting page https://api.scryfall.com/cards?page=240
# Getting page https://api.scryfall.com/cards?page=250
# Getting page https://api.scryfall.com/cards?page=260
# Getting page https://api.scryfall.com/cards?page=270
# Getting page https://api.scryfall.com/cards?page=280
# Getting page https://api.scryfall.com/cards?page=290
# Getting page https://api.scryfall.com/cards?page=300
# Getting page https://api.scryfall.com/cards?page=310
# Getting page https://api.scryfall.com/cards?page=320
# Getting page https://api.scryfall.com/cards?page=330
# Getting page https://api.scryfall.com/cards?page=340
# Getting page https://api.scryfall.com/cards?page=350
# Getting page https://api.scryfall.com/cards?page=360
# Getting page https://api.scryfall.com/cards?page=370
# Getting page https://api.scryfall.com/cards?page=380
# Getting page https://api.scryfall.com/cards?page=390
# Getting page https://api.scryfall.com/cards?page=400
# Getting page https://api.scryfall.com/cards?page=410
# Getting page https://api.scryfall.com/cards?page=420
# Getting page https://api.scryfall.com/cards?page=430
# Getting page https://api.scryfall.com/cards?page=440
# Getting page https://api.scryfall.com/cards?page=450
# Getting page https://api.scryfall.com/cards?page=460
# Getting page https://api.scryfall.com/cards?page=470
# Getting page https://api.scryfall.com/cards?page=480
# Getting page https://api.scryfall.com/cards?page=490
# Getting page https://api.scryfall.com/cards?page=500
# Getting page https://api.scryfall.com/cards?page=510
# Getting page https://api.scryfall.com/cards?page=520
# Getting page https://api.scryfall.com/cards?page=530
# Getting page https://api.scryfall.com/cards?page=540
# Getting page https://api.scryfall.com/cards?page=550
# Getting page https://api.scryfall.com/cards?page=560
# Getting page https://api.scryfall.com/cards?page=570
# Getting page https://api.scryfall.com/cards?page=580
# Getting page https://api.scryfall.com/cards?page=590
# Getting page https://api.scryfall.com/cards?page=600
# Getting page https://api.scryfall.com/cards?page=610
# Getting page https://api.scryfall.com/cards?page=620
# Getting page https://api.scryfall.com/cards?page=630
# Getting page https://api.scryfall.com/cards?page=640
# Getting page https://api.scryfall.com/cards?page=650
# Getting page https://api.scryfall.com/cards?page=660
# Getting page https://api.scryfall.com/cards?page=670
# Getting page https://api.scryfall.com/cards?page=680
# Getting page https://api.scryfall.com/cards?page=690
# Getting page https://api.scryfall.com/cards?page=700
# Getting page https://api.scryfall.com/cards?page=710
# Getting page https://api.scryfall.com/cards?page=720
# Getting page https://api.scryfall.com/cards?page=730
# Getting page https://api.scryfall.com/cards?page=740
# Getting page https://api.scryfall.com/cards?page=750
# Getting page https://api.scryfall.com/cards?page=760
# Getting page https://api.scryfall.com/cards?page=770
# Getting page https://api.scryfall.com/cards?page=780
# Getting page https://api.scryfall.com/cards?page=790
# Getting page https://api.scryfall.com/cards?page=800
# Getting page https://api.scryfall.com/cards?page=810
# Getting page https://api.scryfall.com/cards?page=820
# Getting page https://api.scryfall.com/cards?page=830
# Getting page https://api.scryfall.com/cards?page=840
# Getting page https://api.scryfall.com/cards?page=850
# Getting page https://api.scryfall.com/cards?page=860
# Getting page https://api.scryfall.com/cards?page=870
# Getting page https://api.scryfall.com/cards?page=880
# Getting page https://api.scryfall.com/cards?page=890
# Getting page https://api.scryfall.com/cards?page=900
# Getting page https://api.scryfall.com/cards?page=910
# Getting page https://api.scryfall.com/cards?page=920
# Getting page https://api.scryfall.com/cards?page=930
# Getting page https://api.scryfall.com/cards?page=940
# Getting page https://api.scryfall.com/cards?page=950
# Getting page https://api.scryfall.com/cards?page=960
# Getting page https://api.scryfall.com/cards?page=970
# Getting page https://api.scryfall.com/cards?page=980
# Getting page https://api.scryfall.com/cards?page=990
# Getting page https://api.scryfall.com/cards?page=1000
# Getting page https://api.scryfall.com/cards?page=1010
# Getting page https://api.scryfall.com/cards?page=1020
# Getting page https://api.scryfall.com/cards?page=1030
# Getting page https://api.scryfall.com/cards?page=1040
# Getting page https://api.scryfall.com/cards?page=1050
# Getting page https://api.scryfall.com/cards?page=1060
# Getting page https://api.scryfall.com/cards?page=1070
# Getting page https://api.scryfall.com/cards?page=1080
# Getting page https://api.scryfall.com/cards?page=1090
# Getting page https://api.scryfall.com/cards?page=1100
# Getting page https://api.scryfall.com/cards?page=1110
# Getting page https://api.scryfall.com/cards?page=1120
# Getting page https://api.scryfall.com/cards?page=1130
# Getting page https://api.scryfall.com/cards?page=1140
# Getting page https://api.scryfall.com/cards?page=1150
# Getting page https://api.scryfall.com/cards?page=1160
# Getting page https://api.scryfall.com/cards?page=1170
# Getting page https://api.scryfall.com/cards?page=1180
# Getting page https://api.scryfall.com/cards?page=1190
# Getting page https://api.scryfall.com/cards?page=1200
# Getting page https://api.scryfall.com/cards?page=1210
# Getting page https://api.scryfall.com/cards?page=1220
# Getting page https://api.scryfall.com/cards?page=1230
# Getting page https://api.scryfall.com/cards?page=1240
# Getting page https://api.scryfall.com/cards?page=1250
# Getting page https://api.scryfall.com/cards?page=1260
# Getting page https://api.scryfall.com/cards?page=1270
# Getting page https://api.scryfall.com/cards?page=1280
# Getting page https://api.scryfall.com/cards?page=1290
# Getting page https://api.scryfall.com/cards?page=1300
# Getting page https://api.scryfall.com/cards?page=1310
# Getting page https://api.scryfall.com/cards?page=1320
# Getting page https://api.scryfall.com/cards?page=1330
# Getting page https://api.scryfall.com/cards?page=1340
# Getting page https://api.scryfall.com/cards?page=1350
# Getting page https://api.scryfall.com/cards?page=1360
# Getting page https://api.scryfall.com/cards?page=1370
# Getting page https://api.scryfall.com/cards?page=1380
# Getting page https://api.scryfall.com/cards?page=1390
# Getting page https://api.scryfall.com/cards?page=1400
# Getting page https://api.scryfall.com/cards?page=1410
# Getting page https://api.scryfall.com/cards?page=1420
# Getting page https://api.scryfall.com/cards?page=1430
# Getting page https://api.scryfall.com/cards?page=1440
# Getting page https://api.scryfall.com/cards?page=1450
# Getting page https://api.scryfall.com/cards?page=1460
# Getting page https://api.scryfall.com/cards?page=1470
# Getting page https://api.scryfall.com/cards?page=1480
# Getting page https://api.scryfall.com/cards?page=1490

# %%
all_cards_df.shape
# Out:
# (261438, 73)

# %%
url = all_cards_df.sample(5).image_uris.values[4]['normal']

# %%
from PIL import Image
import requests
from io import BytesIO

response = requests.get(url)
img = Image.open(BytesIO(response.content))
img.show()
