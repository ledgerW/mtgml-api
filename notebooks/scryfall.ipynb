# %%
import pandas as pd
import numpy as np
import os
import requests
from time import sleep

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Scryfall API

# %%
import json

# %%
pages = (1, 101)

# %%
payload = json.dumps({"first": pages[0], "last": pages[1]})
payload
# Out:
# '{"first": 1, "last": 101}'

# %%
event = json.loads(payload)
event
# Out:
# {'first': 1, 'last': 101}

# %%
leonin = 'https://api.scryfall.com/cards/named?fuzzy=leonin+warleader'

# %%
cards_url = 'https://api.scryfall.com/cards?page=1401'

# %%
res = requests.get(cards_url)

# %%
one = res.json()['data'][0]

# %%
len(res.json()['data'])
# Out:
# 175

# %%
BATCH_LIMIT = 25
CARDS_PER_PAGE = 175

# %%
dynamo_batch = [(first, first+BATCH_LIMIT) for first in list(range(0, CARDS_PER_PAGE, BATCH_LIMIT))]
dynamo_batch
# Out:
# [(0, 25), (25, 50), (50, 75), (75, 100), (100, 125), (125, 150), (150, 175)]

# %%
batch = dynamo_batch[0]
batch
# Out:
# (0, 25)

# %%
list(range(5, 5))
# Out:
# []

# %%
table = 'global-cards-table'

# %%
cards = res.json()['data'][batch[0]:batch[1]]

# %%
len(cards[0]['mana_cost'])
# Out:
# 0

# %%
for idx, card in enumerate(cards):
    for key, val in card.items():
        cards[idx][key] = batch_format(val)
    cards[idx]['cardId'] = cards[idx]['id']

# %%
def save_scryfall_page(table, page):
    dynamo_batches = [(first, first+BATCH_LIMIT) for first in list(range(0, CARDS_PER_PAGE, BATCH_LIMIT))]

    res = requests.get(CARDS_URL.format(page))
    for batch in dynamo_batch:
        cards = res.json()['data'][batch[0]:batch[1]]
        # Save to Dynamo
        RequestItems = {
            table: [
                {
                    'PutRequest': {
                        'Item': card
                    }
                } for card in cards
            ]
        }
        return RequestItems
        #_ = dynamodb_lib.call(table, 'batch_write_item', RequestItems)

# %%
items = save_scryfall_page(table, 1)

# %%
def batch_format(val):
    if type(val) is str:
        return {"S": str(val)} if len(val)>0 else {"NULL": True}
    if type(val) is int:
        return {"N": str(val)}
    if type(val) is float:
        return {"N": str(val)}
    if type(val) is list:
        if len(val)>0:
            if type(val[0]) is str:
                return {"SS": val}
            if type(val[0]) is int:
                return {"NS": [str(item) for item in val]}
            if type(val[0]) is float:
                return {"NS": [str(item) for item in val]}
            if type(val[0]) is dict:
                return {
                        "M": {
                                idx: {dict_key: batch_format(dict_val) for dict_key, dict_val in dict_item.items()
                                } for idx, dict_item in enumerate(val)
                            }
                        }
        else:
            return {"SS": ['empty']}
    if type(val) is bool:
        return {"BOOL": True}
    if val is None:
        return {"NULL": True}
    if type(val) is dict:
        return {"M": {val_key: batch_format(val_val) for val_key, val_val in val.items()}}

# %%
cards = res.json()['data'][0:100]

for idx, card in enumerate(cards):
    for key, val in card.items():
        cards[idx][key] = batch_format(val)
    cards[idx]['cardId'] = cards[idx]['id']

# %%
cards
# Out:
# [{'object': {'S': 'card'},
#   'id': {'S': '5797da37-ece2-40d0-ba2a-c47ce55e3744'},
#   'oracle_id': {'S': '7fcf8faa-2c93-4dc8-aa56-6fc40340e212'},
#   'multiverse_ids': {'NS': ['3912']},
#   'tcgplayer_id': {'N': '2176'},
#   'name': {'S': 'Glacial Wall'},
#   'lang': {'S': 'en'},
#   'released_at': {'S': '1997-03-24'},
#   'uri': {'S': 'https://api.scryfall.com/cards/5797da37-ece2-40d0-ba2a-c47ce55e3744'},
#   'scryfall_uri': {'S': 'https://scryfall.com/card/5ed
}}},
#   'mana_cost': {'S': '{2}{U}'},
#   'cmc': {'N': '3.0'},
#   'type_line': {'S': 'Creature — Wall'},
#   'oracle_text': {'S': "Defender (This creature can't attack.)"},
#   'power': {'S': '0'},
#   'toughness': {'S': '7'},
#   'colors': {'SS': ['U']},
#   'color_identity': {'SS': ['U']},
#   'legalities': {'M': {'standard': {'S': 'not_legal'},
#     'future': {'S': 'not_legal'},
#     'historic': {'S': 'not_legal'},
#     'pioneer': {'S': 'not_legal'},
#     'modern': {'S': 'not_legal'},
#     'legacy': {'S': 'legal'},
#     'pauper': {'S': 'legal'},
#     'vintage': {'S': 'legal'},
#     'penny': {'S': 'legal'},
#     'commander': {'S': 'legal'},
#     'brawl': {'S': 'not_legal'},
#     'duel': {'S': 'legal'},
#     'oldschool': {'S': 'not_legal'}}},
#   'games': {'SS': ['paper']},
#   'reserved': {'BOOL': True},
#   'foil': {'BOOL': True},
#   'nonfoil': {'BOOL': True},
#   'oversized': {'BOOL': True},
#   'promo': {'BOOL': True},
#   'reprint': {'BOOL': True},
#   'variation': {'BOOL': True},
#   'set': {'S': '5ed'},
#   'set_name': {'S': 'Fifth Edition'},
#   'set_type': {'S': 'core'},
#   'set_uri': {'S': 'https://api.scryfall.com/sets/5afd2f4b-8309-4f45-a2b2-3785018474cb'},
#   'set_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=set&q=e%3A5ed&unique=prints'},
#   'scryfall_set_uri': {'S': 'https://scryfall.com/sets/5ed?utm_source=api'},
#   'rulings_uri': {'S': 'https://api.scryfall.com/cards/9da7c542-dce0-4c0c-a696-53ff421be4e8/rulings'},
#   'prints_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A7fcf8faa-2c93-4dc8-aa56-6fc40340e212&unique=prints'},
#   'collector_number': {'S': '91'},
#   'digital': {'BOOL': True},
#   'rarity': {'S': 'uncommon'},
#   'card_back_id': {'S': '0aeebaf5-8c7d-4636-9e82-8c27447861f7'},
#   'artist': {'S': 'Greg Simanson'},
#   'artist_ids': {'SS': ['13f79e83-d576-4017-93b5-54c47313ed88']},
#   'illustration_id': {'S': '91a27edb-08e6-4822-a024-94f51ad1eae2'},
#   'border_color': {'S': 'white'},
#   'frame': {'S': '1997'},
#   'full_art': {'BOOL': True},
#   'textless': {'BOOL': True},
#   'booster': {'BOOL': True},
#   'story_spotlight': {'BOOL': True},
#   'edhrec_rank': {'N': '3949'},
#   'prices': {'M': {'usd': {'NULL': True},
#     'usd_foil': {'NULL': True},
#     'eur': {'NULL': True},
#     'tix': {'NULL': True}}},
#   'related_uris': {'M': {'tcgplayer_decks': {'S': 'https://decks.tcgplayer.com/magic/deck/search?contains=Glacial+Wall&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'edhrec': {'S': 'https://edhrec.com/route/?cc=Glacial+Wall'},
#     'mtgtop8': {'S': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Glacial+Wall'}}},
#   'purchase_uris': {'M': {'tcgplayer': {'S': 'https://shop.tcgplayer.com/productcatalog/product/show?ProductName=Glacial+Wall&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'cardmarket': {'S': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Glacial+Wall&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall'},
#     'cardhoarder': {'S': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Glacial+Wall&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}},
#   'cardId': {'S': '9da7c542-dce0-4c0c-a696-53ff421be4e8'}},
#  {'object': {'S': 'card'},
#   'id': {'S': 'b28477df-667a-4233-b90a-ee30e5bc29fc'},
#   'oracle_id': {'S': '896af9a9-12a2-4dd6-957c-e52150b5f3a2'},
#   'multiverse_ids': {'NS': ['3911']},
#   'tcgplayer_id': {'N': '2170'},
#   'name': {'S': 'Gaseous Form'},
#   'lang': {'S': 'en'},
#   'released_at': {'S': '1997-03-24'},
#   'uri': {'S': 'https://api.scryfall.com/cards/b28477df-667a-4233-b90a-ee30e5bc29fc'},
#   'scryfall_uri': {'S': 'https://scryfall.com/card/5ed/90/gaseous-form?utm_source=api'},
#   'layout': {'S': 'normal'},
#   'highres_image': {'BOOL': True},
#   'image_uris': {'M': {'small': {'S': 'https://img.scryfall.com/cards/small/front/b/2/b28477df-667a-4233-b90a-ee30e5bc29fc.jpg?1562593296'},
#     'normal': {'S': 'https://img.scryfall.com/cards/normal/front/b/2/b28477df-667a-4233-b90a-ee30e5bc29fc.jpg?1562593296'},
#     'large': {'S': 'https://img.scryfall.com/cards/large/front/b/2/b28477df-667a-4233-b90a-ee30e5bc29fc.jpg?1562593296'},
#     'png': {'S': 'https://img.scryfall.com/cards/png/front/b/2/b28477df-667a-4233-b90a-ee30e5bc29fc.png?1562593296'},
#     'art_crop': {'S': 'https://img.scryfall.com/cards/art_crop/front/b/2/b28477df-667a-4233-b90a-ee30e5bc29fc.jpg?1562593296'},
#     'border_crop': {'S': 'https://img.scryfall.com/cards/border_crop/front/b/2/b28477df-667a-4233-b90a-ee30e5bc29fc.jpg?1562593296'}}},
#   'mana_cost': {'S': '{2}{U}'},
#   'cmc': {'N': '3.0'},
#   'type_line': {'S': 'Enchantment — Aura'},
#   'oracle_text': {'S': 'Enchant creature\nPrevent all combat damage that would be dealt to and dealt by enchanted creature.'},
#   'colors': {'SS': ['U']},
#   'color_identity': {'SS': ['U']},
#   'legalities': {'M': {'standard': {'S': 'not_legal'},
#     'future': {'S': 'not_legal'},
#     'historic': {'S': 'not_legal'},
#     'pioneer': {'S': 'not_legal'},
#     'modern': {'S': 'not_legal'},
#     'legacy': {'S': 'legal'},
#     'pauper': {'S': 'legal'},
#     'vintage': {'S': 'legal'},
#     'penny': {'S': 'legal'},
#     'commander': {'S': 'legal'},
#     'brawl': {'S': 'not_legal'},
#     'duel': {'S': 'legal'},
#     'oldschool': {'S': 'not_legal'}}},
#   'games': {'SS': ['paper']},
#   'reserved': {'BOOL': True},
#   'foil': {'BOOL': True},
#   'nonfoil': {'BOOL': True},
#   'oversized': {'BOOL': True},
#   'promo': {'BOOL': True},
#   'reprint': {'BOOL': True},
#   'variation': {'BOOL': True},
#   'set': {'S': '5ed'},
#   'set_name': {'S': 'Fifth Edition'},
#   'set_type': {'S': 'core'},
#   'set_uri': {'S': 'https://api.scryfall.com/sets/5afd2f4b-8309-4f45-a2b2-3785018474cb'},
#   'set_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=set&q=e%3A5ed&unique=prints'},
#   'scryfall_set_uri': {'S': 'https://scryfall.com/sets/5ed?utm_source=api'},
#   'rulings_uri': {'S': 'https://api.scryfall.com/cards/b28477df-667a-4233-b90a-ee30e5bc29fc/rulings'},
#   'prints_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A896af9a9-12a2-4dd6-957c-e52150b5f3a2&unique=prints'},
#   'collector_number': {'S': '90'},
#   'digital': {'BOOL': True},
#   'rarity': {'S': 'common'},
#   'flavor_text': {'S': '". . . [A]nd gives to airy nothing A local habitation and a name." —William Shakespeare, A Midsummer-Night\'s Dream'},
#   'card_back_id': {'S': '0aeebaf5-8c7d-4636-9e82-8c27447861f7'},
#   'artist': {'S': 'Doug Keith'},
#   'artist_ids': {'SS': ['ecc1b3b4-d970-4e3a-b3ef-93e584d48b64']},
#   'illustration_id': {'S': 'e57c4c1e-f5e0-4add-8b4b-960a68224e26'},
#   'border_color': {'S': 'white'},
#   'frame': {'S': '1997'},
#   'full_art': {'BOOL': True},
#   'textless': {'BOOL': True},
#   'booster': {'BOOL': True},
#   'story_spotlight': {'BOOL': True},
#   'edhrec_rank': {'N': '13742'},
#   'prices': {'M': {'usd': {'S': '0.04'},
#     'usd_foil': {'NULL': True},
#     'eur': {'S': '0.04'},
#     'tix': {'NULL': True}}},
#   'related_uris': {'M': {'gatherer': {'S': 'https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=3911'},
#     'tcgplayer_decks': {'S': 'https://decks.tcgplayer.com/magic/deck/search?contains=Gaseous+Form&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'edhrec': {'S': 'https://edhrec.com/route/?cc=Gaseous+Form'},
#     'mtgtop8': {'S': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Gaseous+Form'}}},
#   'purchase_uris': {'M': {'tcgplayer': {'S': 'https://shop.tcgplayer.com/product/productsearch?id=2170&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'cardmarket': {'S': 'https://www.cardmarket.com/en/Magic/Products/Singles/Fifth-Edition/Gaseous-Form?referrer=scryfall&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall'},
#     'cardhoarder': {'S': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Gaseous+Form&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}},
#   'cardId': {'S': 'b28477df-667a-4233-b90a-ee30e5bc29fc'}},
#  {'object': {'S': 'card'},
#   'id': {'S': '96a0276e-6e5c-424b-9b00-6edcadf18277'},
#   'oracle_id': {'S': '896af9a9-12a2-4dd6-957c-e52150b5f3a2'},
#   'multiverse_ids': {'SS': ['empty']},
#   'name': {'S': 'Gaseous Form'},
#   'printed_name': {'S': 'Gasförmigkeit'},
#   'lang': {'S': 'de'},
#   'released_at': {'S': '1997-03-24'},
#   'uri': {'S': 'https://api.scryfall.com/cards/96a0276e-6e5c-424b-9b00-6edcadf18277'},
#   'scryfall_uri': {'S': 'https://scryfall.com/card/5ed/90/de/gasf%C3%B6rmigkeit?utm_source=api'},
#   'layout': {'S': 'normal'},
#   'highres_image': {'BOOL': True},
#   'image_uris': {'M': {'small': {'S': 'https://img.scryfall.com/cards/small/front/9/6/96a0276e-6e5c-424b-9b00-6edcadf18277.jpg?1539777007'},
#     'normal': {'S': 'https://img.scryfall.com/cards/normal/front/9/6/96a0276e-6e5c-424b-9b00-6edcadf18277.jpg?1539777007'},
#     'large': {'S': 'https://img.scryfall.com/cards/large/front/9/6/96a0276e-6e5c-424b-9b00-6edcadf18277.jpg?1539777007'},
#     'png': {'S': 'https://img.scryfall.com/cards/png/front/9/6/96a0276e-6e5c-424b-9b00-6edcadf18277.png?1539777007'},
#     'art_crop': {'S': 'https://img.scryfall.com/cards/art_crop/front
rulings'},
#   'prints_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Acc187110-1148-4090-bbb8-e205694a39f5&unique=prints'},
#   'collector_number': {'S': '77'},
#   'digital': {'BOOL': True},
#   'rarity': {'S': 'common'},
#   'card_back_id': {'S': '0aeebaf5-8c7d-4636-9e82-8c27447861f7'},
#   'artist': {'S': 'Hannibal King'},
#   'artist_ids': {'SS': ['47fa68ed-4d79-4116-a562-fc0c11096e81']},
#   'illustration_id': {'S': '717edff6-c8e9-4dfd-9cc1-1128aee55915'},
#   'border_color': {'S': 'white'},
#   'frame': {'S': '1997'},
#   'full_art': {'BOOL': True},
#   'textless': {'BOOL': True},
#   'booster': {'BOOL': True},
#   'story_spotlight': {'BOOL': True},
#   'edhrec_rank': {'N': '16'},
#   'prices': {'M': {'usd': {'S': '1.58'},
#     'usd_foil': {'NULL': True},
#     'eur': {'S': '0.78'},
#     'tix': {'NULL': True}}},
#   'related_uris': {'M': {'gatherer': {'S': 'https://gatherer.wizards.com/Pages/Card/Details.aspx?multiverseid=3898'},
#     'tcgplayer_decks': {'S': 'https://decks.tcgplayer.com/magic/deck/search?contains=Counterspell&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'edhrec': {'S': 'https://edhrec.com/route/?cc=Counterspell'},
#     'mtgtop8': {'S': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Counterspell'}}},
#   'purchase_uris': {'M': {'tcgplayer': {'S': 'https://shop.tcgplayer.com/product/productsearch?id=2086&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'cardmarket': {'S': 'https://www.cardmarket.com/en/Magic/Products/Singles/Fifth-Edition/Counterspell?referrer=scryfall&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall'},
#     'cardhoarder': {'S': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Counterspell&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}},
#   'cardId': {'S': 'b975289d-d8b8-46b4-8c60-d6ed4b594519'}},
#  {'object': {'S': 'card'},
#   'id': {'S': '85c6ff26-9454-4385-a645-bc2dbc95f574'},
#   'oracle_id': {'S': 'cc187110-1148-4090-bbb8-e205694a39f5'},
#   'multiverse_ids': {'SS': ['empty']},
#   'name': {'S': 'Counterspell'},
#   'printed_name': {'S': 'Gegenzauber'},
#   'lang': {'S': 'de'},
#   'released_at': {'S': '1997-03-24'},
#   'uri': {'S': 'https://api.scryfall.com/cards/85c6ff26-9454-4385-a645-bc2dbc95f574'},
#   'scryfall_uri': {'S': 'https://scryfall.com/card/5ed/77/de/gegenzauber?utm_source=api'},
#   'layout': {'S': 'normal'},
#   'highres_image': {'BOOL': True},
#   'image_uris': {'M': {'small': {'S': 'https://img.scryfall.com/cards/small/front/8/5/85c6ff26-9454-4385-a645-bc2dbc95f574.jpg?1539776735'},
#     'normal': {'S': 'https://img.scryfall.com/cards/normal/front/8/5/85c6ff26-9454-4385-a645-bc2dbc95f574.jpg?1539776735'},
#     'large': {'S': 'https://img.scryfall.com/cards/large/front/8/5/85c6ff26-9454-4385-a645-bc2dbc95f574.jpg?1539776735'},
#     'png': {'S': 'https://img.scryfall.com/cards/png/front/8/5/85c6ff26-9454-4385-a645-bc2dbc95f574.png?1539776735'},
#     'art_crop': {'S': 'https://img.scryfall.com/cards/art_crop/front/8/5/85c6ff26-9454-4385-a645-bc2dbc95f574.jpg?1539776735'},
#     'border_crop': {'S': 'https://img.scryfall.com/cards/border_crop/front/8/5/85c6ff26-9454-4385-a645-bc2dbc95f574.jpg?1539776735'}}},
#   'mana_cost': {'S': '{U}{U}'},
#   'cmc': {'N': '2.0'},
#   'type_line': {'S': 'Instant'},
#   'printed_type_line': {'S': 'Unterbrechungszauber'},
#   'oracle_text': {'S': 'Counter target spell.'},
#   'printed_text': {'S': 'Neutralisiere einen Zauberspruch Deiner Wahl'},
#   'colors': {'SS': ['U']},
#   'color_identity': {'SS': ['U']},
#   'legalities': {'M': {'standard': {'S': 'not_legal'},
#     'future': {'S': 'not_legal'},
#     'historic': {'S': 'not_legal'},
#     'pioneer': {'S': 'not_legal'},
#     'modern': {'S': 'not_legal'},
#     'legacy': {'S': 'legal'},
#     'pauper': {'S': 'legal'},
#     'vintage': {'S': 'legal'},
#     'penny': {'S': 'not_legal'},
#     'commander': {'S': 'legal'},
#     'brawl': {'S': 'not_legal'},
#     'duel': {'S': 'legal'},
#     'oldschool': {'S': 'not_legal'}}},
#   'games': {'SS': ['paper']},
#   'reserved': {'BOOL': True},
#   'foil': {'BOOL': True},
#   'nonfoil': {'BOOL': True},
#   'oversized': {'BOOL': True},
#   'promo': {'BOOL': True},
#   'reprint': {'BOOL': True},
#   'variation': {'BOOL': True},
#   'set': {'S': '5ed'},
#   'set_name': {'S': 'Fifth Edition'},
#   'set_type': {'S': 'core'},
#   'set_uri': {'S': 'https://api.scryfall.com/sets/5afd2f4b-8309-4f45-a2b2-3785018474cb'},
#   'set_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=set&q=e%3A5ed&unique=prints'},
#   'scryfall_set_uri': {'S': 'https://scryfall.com/sets/5ed?utm_source=api'},
#   'rulings_uri': {'S': 'https://api.scryfall.com/cards/85c6ff26-9454-4385-a645-bc2dbc95f574/rulings'},
#   'prints_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Acc187110-1148-4090-bbb8-e205694a39f5&unique=prints'},
#   'collector_number': {'S': '77'},
#   'digital': {'BOOL': True},
#   'rarity': {'S': 'common'},
#   'card_back_id': {'S': '0aeebaf5-8c7d-4636-9e82-8c27447861f7'},
#   'artist': {'S': 'Hannibal King'},
#   'artist_ids': {'SS': ['47fa68ed-4d79-4116-a562-fc0c11096e81']},
#   'illustration_id': {'S': '717edff6-c8e9-4dfd-9cc1-1128aee55915'},
#   'border_color': {'S': 'white'},
#   'frame': {'S': '1997'},
#   'full_art': {'BOOL': True},
#   'textless': {'BOOL': True},
#   'booster': {'BOOL': True},
#   'story_spotlight': {'BOOL': True},
#   'edhrec_rank': {'N': '16'},
#   'prices': {'M': {'usd': {'NULL': True},
#     'usd_foil': {'NULL': True},
#     'eur': {'NULL': True},
#     'tix': {'NULL': True}}},
#   'related_uris': {'M': {'tcgplayer_decks': {'S': 'https://decks.tcgplayer.com/magic/deck/search?contains=Counterspell&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'edhrec': {'S': 'https://edhrec.com/route/?cc=Counterspell'},
#     'mtgtop8': {'S': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Counterspell'}}},
#   'purchase_uris': {'M': {'tcgplayer': {'S': 'https://shop.tcgplayer.com/productcatalog/product/show?ProductName=Counterspell&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'cardmarket': {'S': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Counterspell&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall'},
#     'cardhoarder': {'S': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Counterspell&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}},
#   'cardId': {'S': '85c6ff26-9454-4385-a645-bc2dbc95f574'}}]

# %%
cards = res.json()['data'][batch[0]:batch[1]]

# %%
res.json()['total_cards']
# Out:
# 263830

# %%
import math

# %%
cards_per_page = 175
total_cards = res.json()['total_cards']

total_pages = math.ceil(total_cards / cards_per_page)

total_pages
# Out:
# 1508

# %%
PAGES_PER_WORKER = 100

# %%
total_pages = 1508

# %%
worker_pages = [(first, first+PAGES_PER_WORKER) for first in list(range(1, total_pages+1, PAGES_PER_WORKER))]
worker_pages
# Out:
# [(1, 101),
#  (101, 201),
#  (201, 301),
#  (301, 401),
#  (401, 501),
#  (501, 601),
#  (601, 701),
#  (701, 801),
#  (801, 901),
#  (901, 1001),
#  (1001, 1101),
#  (1101, 1201),
#  (1201, 1301),
#  (1301, 1401),
#  (1401, 1501),
#  (1501, 1601)]

# %%
CARDS_URL = 'https://api.scryfall.com/cards?page={}'

# %%
CARDS_URL.format(1)
# Out:
# 'https://api.scryfall.com/cards?page=1'

# %%
cards_url = 'https://api.scryfall.com/cards?page=10'

# %%
int(str.split(cards_url, '=')[1])
# Out:
# 10

# %%
import datetime

# %%
start = datetime.datetime.now()

# %%
print(datetime.datetime.now() - then)
# Out:
# 0:00:23.186929

# %%
start = datetime.datetime.now()
all_cards_path = os.path.join(os.getcwd(), 'data', 'all_scryfall.json')
all_cards_df = pd.DataFrame()
cards_url = 'https://api.scryfall.com/cards?page=1'
cards_per_page = 175
has_more = True
while has_more:
#while int(str.split(cards_url, '=')[1]) < 101:
    res = requests.get(cards_url)
    
    #if int(cards_url[-1]) % 10 == 0:
    #    print('Getting page {}'.format(cards_url))
    
    cards_df = pd.DataFrame.from_dict(res.json()['data'])

    all_cards_df = pd.concat([all_cards_df, cards_df], sort=True, ignore_index=True)
          
    has_more = res.json()['has_more']
    cards_url = res.json()['next_page']
    
    sleep(0.1)

print(datetime.datetime.now() - then)
#all_cards_df.to_json(all_cards_path)
# Out:
# Getting page https://api.scryfall.com/cards?page=10
# Getting page https://api.scryfall.com/cards?page=20
# Getting page https://api.scryfall.com/cards?page=30
# Getting page https://api.scryfall.com/cards?page=40
# Getting page https://api.scryfall.com/cards?page=50
# Getting page https://api.scryfall.com/cards?page=60
# Getting page https://api.scryfall.com/cards?page=70
# Getting page https://api.scryfall.com/cards?page=80
# Getting page https://api.scryfall.com/cards?page=90
# Getting page https://api.scryfall.com/cards?page=100
# 0:05:45.799994

# %%
all_cards_path
# Out:
# 'C:\\Users\\LWEST\\Desktop\\mtgml-api\\notebooks\\..\\data\\all_scryfall.json'

# %%
all_cards_path = os.path.join(os.getcwd(), '..', 'data', 'all_scryfall.json')

all_cards_df = pd.read_json(all_cards_path)

# %%
all_cards_df.shape
# Out:
# (261438, 73)

# %%
all_cards_df.head(2)
# Out:
#   all_parts  arena_id          artist                              artist_ids  \
# 0      None       NaN   Milivoj Ćeran  [1eced451-4da5-42bc-b49d-70c41246581f]
# 1      None       NaN  Lucas Graciano  [ce98f39c-7cdd-47e6-a520-6c50443bb4c2]
#
#    booster border_color                          card_back_id card_faces  cmc  \
# 0    False        black  0aeebaf5-8c7d-4636-9e82-8c27447861f7       None  6.0
# 1    False        black  0aeebaf5-8c7d-4636-9e82-8c27447861f7       None  6.0
#
#   collector_number color_identity color_indicator colors  digital  \
# 0                5            [G]            None    [G]    False
# 1                4            [R]            None    [R]    False
#
#    edhrec_rank                                        flavor_text  foil frame  \
# 0          NaN  "Come, my wild children. Let's give the interl...  True  2015
# 1          NaN                  Half the size, double the mayhem.  True  2015
#
#   frame_effects  full_art    games  hand_modifier  highres_image  \
# 0          None     False  [paper]            NaN          False
# 1          None     False  [paper]            NaN          False
#
#                                      id                       illustration_id  \
# 0  dbcdbf7a-9294-47ad-9f93-c16b78c7463a  fe97c475-ef9a-41b2-872b-2469ac9f48d7
# 1  acb3ce9b-ee4f-410a-8db3-e87aeb0a4444  56da4782-3fe9-4230-b426-8e7903fe281f
#
#                                           image_uris lang  layout  \
# 0  {'small': 'https://img.scryfall.com/cards/smal...   en  normal
# 1  {'small': 'https://img.scryfall.com/cards/smal...   en  normal
#
#                                           legalities  life_modifier loyalty  \
# 0  {'standard': 'not_legal', 'future': 'not_legal...            NaN    None
# 1  {'standard': 'not_legal', 'future': 'not_legal...            NaN    None
#
#    mana_cost  mtgo_foil_id  mtgo_id multiverse_ids               name  \
# 0  {4}{G}{G}           NaN      NaN             []  Earthshaker Giant
# 1  {4}{R}{R}           NaN      NaN             []       Fiendish Duo
#
#    nonfoil object                             oracle_id  \
# 0    False   card  cd6250ae-9079-4a62-8a70-0d94fbac21bc
# 1    False   card  ab0dfae5-b9d4-417b-8a0d-2525ae3a73b9
#
#                                          oracle_text  oversized power preview  \
# 0  Trample\nWhen Earthshaker Giant enters the bat...      False     6    None
# 1  First strike\nIf a source would deal damage to...      False     5    None
#
#                                               prices printed_name  \
# 0  {'usd': None, 'usd_foil': '12.00', 'eur': None...         None
# 1  {'usd': None, 'usd_foil': '15.00', 'eur': None...         None
#
#   printed_text printed_type_line  \
# 0         None              None
# 1         None              None
#
#                                    prints_search_uri  promo promo_types  \
# 0  https://api.scryfall.com/cards/search?order=re...  False        None
# 1  https://api.scryfall.com/cards/search?order=re...  False        None
#
#                                        purchase_uris  rarity  \
# 0  {'tcgplayer': 'https://shop.tcgplayer.com/prod...  mythic
# 1  {'tcgplayer': 'https://shop.tcgplayer.com/prod...  mythic
#
#                                         related_uris released_at  reprint  \
# 0  {'tcgplayer_decks': 'https://decks.tcgplayer.c...  2019-11-15    False
# 1  {'tcgplayer_decks': 'https://decks.tcgplayer.c...  2019-11-15    False
#
#    reserved                                        rulings_uri  \
# 0     False  https://api.scryfall.com/cards/dbcdbf7a-9294-4...
# 1     False  https://api.scryfall.com/cards/acb3ce9b-ee4f-4...
#
#                                scryfall_set_uri  \
# 0  https://scryfall.com/sets/gn2?utm_source=api
# 1  https://scryfall.com/sets/gn2?utm_source=api
#
#                                         scryfall_uri  set         set_name  \
# 0  https://scryfall.com/card/gn2/5/earthshaker-gi...  gn2  Game Night 2019
# 1  https://scryfall.com/card/gn2/4/fiendish-duo?u...  gn2  Game Night 2019
#
#                                       set_search_uri set_type  \
# 0  https://api.scryfall.com/cards/search?order=se...      box
# 1  https://api.scryfall.com/cards/search?order=se...      box
#
#                                              set_uri  story_spotlight  \
# 0  https://api.scryfall.com/sets/a72727dd-dbab-41...            False
# 1  https://api.scryfall.com/sets/a72727dd-dbab-41...            False
#
#    tcgplayer_id  textless toughness               type_line  \
# 0      200607.0     False         6  Creature — Giant Druid
# 1      200606.0     False         5        Creature — Devil
#
#                                                  uri  variation variation_of  \
# 0  https://api.scryfall.com/cards/dbcdbf7a-9294-4...      False         None
# 1  https://api.scryfall.com/cards/acb3ce9b-ee4f-4...      False         None
#
#   watermark
# 0      None
# 1      None

# %%
url = all_cards_df.sample(5).image_uris.values[4]['normal']

# %%
from PIL import Image
import requests
from io import BytesIO

response = requests.get(url)
img = Image.open(BytesIO(response.content))
img.show()
