# %%
import pandas as pd
import numpy as np
import os
import requests
import json
from time import sleep

pd.set_option('display.max_columns', None)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\LWEST\\Desktop\\mtgml-api\\notebooks'

# %%
cards_df = pd.read_pickle('cards_df.pkl')

# %%
cards_df[['n']].values.astype(int)
# Out:
# array([[4],
#        [3],
#        [4],
#        [4],
#        [4],
#        [2],
#        [2],
#        [8],
#        [4],
#        [3],
#        [4],
#        [4],
#        [4],
#        [4],
#        [4],
#        [7],
#        [2],
#        [3],
#        [2],
#        [4],
#        [3]])

# %%
n = cards_df[['n']].values.astype(int)
types = cards_df[['Land','Creature','Enchantment','Sorcery','Instant','Artifact','Planeswalker']]
type_curve = (types * n).sum(axis=0).to_dict()

# %%
sum(type_curve.values())
# Out:
# 86

# %%
cards_df.head(3)
# Out:
#                              type_line  set            set_name  \
# 0                          Enchantment  eld  Throne of Eldraine
# 1  Legendary Artifact Creature — Scout  m20       Core Set 2020
# 2                     Creature — Human  grn   Guilds of Ravnica
#
#                       name                                cardId  \
# 0       Happily Ever After  c38c9120-ac20-4f81-b8d8-9d490cc2a913
# 1  Golos, Tireless Pilgrim  1fa48620-4c3d-4f75-be1f-c12c4aa59f51
# 2           Hunted Witness  8c31b8e5-2349-4119-9dc2-3e41c5364a78
#
#                                          oracle_text   colors  \
# 0  When Happily Ever After enters the battlefield...      [W]
# 1  When Golos, Tireless Pilgrim enters the battle...  [empty]
# 2  When Hunted Witness dies, create a 1/1 white S...      [W]
#
#     color_identity  rarity                                          mana_cost  \
# 0              [W]    rare  [{'W': 1, 'B': 0, 'R': 0, 'G': 0, 'U': 0, 'X':...
# 1  [B, G, R, W, U]    rare  [{'W': 0, 'B': 0, 'R': 0, 'G': 0, 'U': 0, 'X':...
# 2              [W]  common  [{'W': 1, 'B': 0, 'R': 0, 'G': 0, 'U': 0, 'X':...
#
#   toughness power  n                                              small  \
# 0       NaN   NaN  4  https://img.scryfall.com/cards/small/front/c/3...
# 1         5     3  3  https://img.scryfall.com/cards/small/front/1/f...
# 2         1     1  4  https://img.scryfall.com/cards/small/front/8/c...
#
#                                                  png  \
# 0  https://img.scryfall.com/cards/png/front/c/3/c...
# 1  https://img.scryfall.com/cards/png/front/1/f/1...
# 2  https://img.scryfall.com/cards/png/front/8/c/8...
#
#                                               normal  \
# 0  https://img.scryfall.com/cards/normal/front/c/...
# 1  https://img.scryfall.com/cards/normal/front/1/...
# 2  https://img.scryfall.com/cards/normal/front/8/...
#
#                                          border_crop  \
# 0  https://img.scryfall.com/cards/border_crop/fro...
# 1  https://img.scryfall.com/cards/border_crop/fro...
# 2  https://img.scryfall.com/cards/border_crop/fro...
#
#                                                large  \
# 0  https://img.scryfall.com/cards/large/front/c/3...
# 1  https://img.scryfall.com/cards/large/front/1/f...
# 2  https://img.scryfall.com/cards/large/front/8/c...
#
#                                             art_crop standard  oldschool  \
# 0  https://img.scryfall.com/cards/art_crop/front/...    legal  not_legal
# 1  https://img.scryfall.com/cards/art_crop/front/...    legal  not_legal
# 2  https://img.scryfall.com/cards/art_crop/front/...    legal  not_legal
#
#   historic legacy pioneer commander modern     pauper future vintage   duel  \
# 0    legal  legal   legal     legal  legal  not_legal  legal   legal  legal
# 1    legal  legal   legal     legal  legal  not_legal  legal   legal  legal
# 2    legal  legal   legal     legal  legal      legal  legal   legal  legal
#
#     brawl      penny                                          tcgplayer  \
# 0   legal      legal  https://shop.tcgplayer.com/product/productsear...
# 1  banned  not_legal  https://shop.tcgplayer.com/product/productsear...
# 2   legal      legal  https://shop.tcgplayer.com/product/productsear...
#
#                                           cardmarket  \
# 0  https://www.cardmarket.com/en/Magic/Products/S...
# 1  https://www.cardmarket.com/en/Magic/Products/S...
# 2  https://www.cardmarket.com/en/Magic/Products/S...
#
#                                          cardhoarder usd_foil   tix   eur  \
# 0  https://www.cardhoarder.com/cards?affiliate_id...     4.15  None  None
# 1  https://www.cardhoarder.com/cards/73351?affili...     9.32  3.07  1.70
# 2  https://www.cardhoarder.com/cards/69403?affili...     0.65  0.01  0.09
#
#     usd  Land  Creature  Enchantment  Sorcery  Instant  Artifact  Planeswalker
# 0  1.00     0         0            1        0        0         0             0
# 1  2.14     0         1            0        0        0         1             0
# 2  0.12     0         1            0        0        0         0             0

# %%
cards_df['Creature'][0]
# Out:
# 0

# %%
full_df = pd.DataFrame()
for col in cards_df.columns:
    try:
        full_df[col] = cards_df[col].apply(lambda x: json.loads(x.replace("'",'"').replace('None', '"None"')))
        full_df = pd.concat([full_df.drop([col], axis=1), full_df[col].apply(pd.Series)], axis=1)
    except:
        full_df[col] = cards_df[col]
    
full_df
# Out:
#                               type_line  set             set_name  \
# 0                           Enchantment  eld   Throne of Eldraine
# 1   Legendary Artifact Creature — Scout  m20        Core Set 2020
# 2                      Creature — Human  grn    Guilds of Ravnica
# 3                       Creature — Bird  grn    Guilds of Ravnica
# 4       Legendary Planeswalker — Garruk  eld   Throne of Eldraine
# 5                               Instant  m20        Core Set 2020
# 6                    Enchantment — Aura  m20        Core Set 2020
# 7                   Basic Land — Plains  eld   Throne of Eldraine
# 8                                  Land  m20        Core Set 2020
# 9                               Instant  m20        Core Set 2020
# 10                              Sorcery  war     War of the Spark
# 11                             Artifact  grn    Guilds of Ravnica
# 12         Enchantment Creature — Nymph  thb  Theros Beyond Death
# 13                                 Land  m20        Core Set 2020
# 14                  Basic Land — Island  war     War of the Spark
# 15                  Basic Land — Forest  war     War of the Spark
# 16                              Sorcery  rna   Ravnica Allegiance
# 17                          Enchantment  thb  Theros Beyond Death
# 18                              Sorcery  war     War of the Spark
# 19                                 Land  m20        Core Set 2020
# 20                          Enchantment  eld   Throne of Eldraine
#
#                                                 small  \
# 0   https://img.scryfall.com/cards/small/front/c/3...
# 1   https://img.scryfall.com/cards/small/front/1/f...
# 2   https://img.scryfall.com/cards/small/front/8/c...
# 3   https://img.scryfall.com/cards/small/front/3/3...
# 4   https://img.scryfall.com/cards/small/front/a/b...
# 5   https://img.scryfall.com/cards/small/front/7/b...
# 6   https://img.scryfall.com/cards/small/front/3/1...
# 7   https://img.scryfall.com/cards/small/front/5/b...
# 8   https://img.scryfall.com/cards/small/front/9/b...
# 9   https://img.scryfall.com/cards/small/front/3/3...
# 10  https://img.scryfall.com/cards/small/front/1/1...
# 11  https://img.scryfall.com/cards/small/front/e/a...
# 12  https://img.scryfall.com/cards/small/front/6/d...
# 13  https://img.scryfall.com/cards/small/front/3/b...
# 14  https://img.scryfall.com/cards/small/front/a/2...
# 15  https://img.scryfall.com/cards/small/front/0/1...
# 16  https://img.scryfall.com/cards/small/front/5/e...
# 17  https://img.scryfall.com/cards/small/front/a/1...
# 18  https://img.scryfall.com/cards/small/front/6/2...
# 19  https://img.scryfall.com/cards/small/front/7/5...
# 20  https://img.scryfall.com/cards/small/front/5/d...
#
#                                                   png  \
# 7    legal      legal                      Plains
# 8    legal      legal               Jungle Hollow
# 9    legal      legal                      Negate
# 10   legal  not_legal       Planewide Celebration
# 11   legal  not_legal           Chromatic Lantern
# 12   legal  not_legal  Dryad of the Ilysian Grove
# 13   legal      legal             Scoured Barrens
# 14   legal      legal                      Island
# 15   legal      legal                      Forest
# 16   legal  not_legal                Kaya's Wrath
# 17   legal      legal             Banishing Light
# 18   legal  not_legal                   Time Wipe
# 19   legal      legal               Tranquil Cove
# 20   legal  not_legal          Outlaws' Merriment
#
#                                   cardId  \
# 0   c38c9120-ac20-4f81-b8d8-9d490cc2a913
# 1   1fa48620-4c3d-4f75-be1f-c12c4aa59f51
# 2   8c31b8e5-2349-4119-9dc2-3e41c5364a78
# 3   3313bd5c-b657-47a3-822a-dd0d9165492a
# 4   abef512f-8f1d-4257-b16f-c0eed58670ec
# 5   7bbc462b-3736-4441-96ee-8dc5615b4529
# 6   31279d7c-5246-40b2-a8c7-0be4a5f24a29
# 7   5b5f9eef-925c-479e-a9a5-ce61fc06f3be
# 8   9b6b7a1d-943b-43f8-a70b-1a3a205476cf
# 9   33b83158-78b4-425e-8379-be3ef038295c
# 10  11016840-56b6-4759-bde6-3dc0e339e87e
# 11  ea123356-3055-4e42-b816-ac3c4e9087d1
# 12  6d964876-194b-49f1-8e74-cfe9269f2c62
# 13  3b9edd33-a64e-4526-a89f-edd31ac4b175
# 14  a24e28a0-a10f-4324-b008-09564e85573e
# 15  0120879f-df13-4583-b260-0fc298518f16
# 16  5ed140c1-752b-4539-88f2-1fa354049b17
# 17  a1ddd113-140f-49c9-b45c-cf1b0d1dffd8
# 18  62c59475-6f15-48d2-b105-f49901f20d44
# 19  75fa37aa-ef2e-49ff-9496-86b0e69128a7
# 20  5d7585ab-a364-471c-8ef1-318e459b4020
#
#                                           oracle_text  \
# 0   When Happily Ever After enters the battlefield...
# 1   When Golos, Tireless Pilgrim enters the battle...
# 2   When Hunted Witness dies, create a 1/1 white S...
# 3                                    Flying, lifelink
# 4   0: Create two 2/2 black and green Wolf creatur...
# 5   Target creature gets +2/+2 and gains lifelink ...
# 6   Enchant creature\nEnchanted creature can't att...
# 7                                     ({T}: Add {W}.)
# 8   Jungle Hollow enters the battlefield tapped.\n...
# 9                   Counter target noncreature spell.
# 10  Choose four. You may choose the same mode more...
# 11  Lands you control have "{T}: Add one mana of a...
# 12  You may play an additional land on each of you...
# 13  Scoured Barrens enters the battlefield tapped....
# 14                                    ({T}: Add {U}.)
# 15                                    ({T}: Add {G}.)
# 16  Destroy all creatures. You gain life equal to ...
# 17  When Banishing Light enters the battlefield, e...
# 18  Return a creature you control to its owner's h...
# 19  Tranquil Cove enters the battlefield tapped.\n...
# 20  At the beginning of your upkeep, choose one at...
#
#                                             tcgplayer  \
# 0   https://shop.tcgplayer.com/product/productsear...
# 1   https://shop.tcgplayer.com/product/productsear...
# 2   https://shop.tcgplayer.com/product/productsear...
# 3   https://shop.tcgplayer.com/product/productsear...
# 4   https://shop.tcgplayer.com/product/productsear...
# 5   https://shop.tcgplayer.com/product/productsear...
# 17  https://www.cardhoarder.com/cards/79132?affili...       {'W'}
# 18  https://www.cardhoarder.com/cards/72052?affili...  {'U', 'W'}
# 19  https://www.cardhoarder.com/cards/73417?affili...   {'empty'}
# 20  https://www.cardhoarder.com/cards/78540?affili...  {'R', 'W'}
#
#                color_identity usd_foil   tix   eur   usd    rarity  \
# 0                       {'W'}     4.15  None  None  1.00      rare
# 1   {'B', 'R', 'W', 'U', 'G'}     9.32  3.07  1.70  2.14      rare
# 2                       {'W'}     0.65  0.01  0.09  0.12    common
# 3                       {'W'}     2.22  0.01  0.08  0.28    common
# 4                  {'B', 'G'}     4.16  0.47  3.12  2.92    mythic
# 5                       {'W'}     0.11  0.01  0.04  0.04    common
# 6                       {'W'}     0.16  0.02  0.04  0.06    common
# 7                       {'W'}     0.24  0.01  0.05  0.07    common
# 8                  {'B', 'G'}     0.21  0.04  0.07  0.09    common
# 9                       {'U'}     0.63  0.04  0.08  0.12    common
# 10                      {'G'}     0.80  0.02  0.14  0.29      rare
# 11                  {'empty'}     8.61  0.03  3.47  6.29      rare
# 12                      {'G'}     9.23  1.16  5.34  7.06      rare
# 13                 {'B', 'W'}     0.27  0.04  0.09  0.11    common
# 14                      {'U'}     0.48  0.01  0.06  0.07    common
# 15                      {'G'}     0.33  0.01  0.03  0.07    common
# 16                 {'B', 'W'}     3.25  0.26  1.38  0.83      rare
# 17                      {'W'}     0.40  0.01  0.13  0.24  uncommon
# 18                 {'U', 'W'}     1.54  0.04  0.44  0.40      rare
# 19                 {'U', 'W'}     0.32  0.04  0.05  0.08    common
# 20                 {'R', 'W'}     1.25  0.08  0.66  0.72    mythic
#
#                                                     0  \
# 0   {'W': 1, 'B': 0, 'R': 0, 'G': 0, 'U': 0, 'X': ...
# 1   {'W': 0, 'B': 0, 'R': 0, 'G': 0, 'U': 0, 'X': ...
# 2   {'W': 1, 'B': 0, 'R': 0, 'G': 0, 'U': 0, 'X': ...
# 3   {'W': 1, 'B': 0, 'R': 0, 'G': 0, 'U': 0, 'X': ...
# 4   {'W': 0, 'B': 1, 'R': 0, 'G': 1, 'U': 0, 'X': ...
# 5   {'W': 1, 'B': 0, 'R': 0, 'G': 0, 'U': 0, 'X': ...
# 6   {'W': 1, 'B': 0, 'R': 0, 'G': 0, 'U': 0, 'X': ...
# 7   {'W': 0, 'B': 0, 'R': 0, 'G': 0, 'U': 0, 'X': ...
# 8   {'W': 0, 'B': 0, 'R': 0, 'G': 0, 'U': 0, 'X': ...
# 9   {'W': 0, 'B': 0, 'R': 0, 'G': 0, 'U': 1, 'X': ...
# 10  {'W': 0, 'B': 0, 'R': 0, 'G': 2, 'U': 0, 'X': ...
# 11  {'W': 0, 'B': 0, 'R': 0, 'G': 0, 'U': 0, 'X': ...
# 12  {'W': 0, 'B': 0, 'R': 0, 'G': 1, 'U': 0, 'X': ...
# 13  {'W': 0, 'B': 0, 'R': 0, 'G': 0, 'U': 0, 'X': ...
# 14  {'W': 0, 'B': 0, 'R': 0, 'G': 0, 'U': 0, 'X': ...
# 15  {'W': 0, 'B': 0, 'R': 0, 'G': 0, 'U': 0, 'X': ...
# 16  {'W': 2, 'B': 2, 'R': 0, 'G': 0, 'U': 0, 'X': ...
# 17  {'W': 1, 'B': 0, 'R': 0, 'G': 0, 'U': 0, 'X': ...
# 18  {'W': 2, 'B': 0, 'R': 0, 'G': 0, 'U': 1, 'X': ...
# 19  {'W': 0, 'B': 0, 'R': 0, 'G': 0, 'U': 0, 'X': ...
# 20  {'W': 2, 'B': 0, 'R': 1, 'G': 0, 'U': 0, 'X': ...
#
#                                                  type  toughness  power
# 0   Counter({'Enchantment': 1, 'Land': 0, 'Creatur...        NaN    NaN
# 1   Counter({'Creature': 1, 'Artifact': 1, 'Land':...        5.0    3.0
# 2   Counter({'Creature': 1, 'Land': 0, 'Enchantmen...        1.0    1.0
# 3   Counter({'Creature': 1, 'Land': 0, 'Enchantmen...        1.0    1.0
# 4   Counter({'Planeswalker': 1, 'Land': 0, 'Creatu...        NaN    NaN
# 5   Counter({'Instant': 1, 'Land': 0, 'Creature': ...        NaN    NaN
# 6   Counter({'Enchantment': 1, 'Land': 0, 'Creatur...        NaN    NaN
# 7   Counter({'Land': 1, 'Creature': 0, 'Enchantmen...        NaN    NaN
# 8   Counter({'Land': 1, 'Creature': 0, 'Enchantmen...        NaN    NaN
# 9   Counter({'Instant': 1, 'Land': 0, 'Creature': ...        NaN    NaN
# 10  Counter({'Sorcery': 1, 'Land': 0, 'Creature': ...        NaN    NaN
# 11  Counter({'Artifact': 1, 'Land': 0, 'Creature':...        NaN    NaN
# 12  Counter({'Creature': 1, 'Enchantment': 1, 'Lan...        4.0    2.0
# 13  Counter({'Land': 1, 'Creature': 0, 'Enchantmen...        NaN    NaN
# 14  Counter({'Land': 1, 'Creature': 0, 'Enchantmen...        NaN    NaN
# 15  Counter({'Land': 1, 'Creature': 0, 'Enchantmen...        NaN    NaN
# 16  Counter({'Sorcery': 1, 'Land': 0, 'Creature': ...        NaN    NaN
# 17  Counter({'Enchantment': 1, 'Land': 0, 'Creatur...        NaN    NaN
# 18  Counter({'Sorcery': 1, 'Land': 0, 'Creature': ...        NaN    NaN
# 19  Counter({'Land': 1, 'Creature': 0, 'Enchantmen...        NaN    NaN
# 20  Counter({'Enchantment': 1, 'Land': 0, 'Creatur...        NaN    NaN

# %%
cards_df = pd.concat([cards_df.drop(['type'], axis=1), cards_df['type'].apply(pd.Series)], axis=1)

# %%
cards_df.head(3)
# Out:
#                              type_line  set            set_name  \
# 0                          Enchantment  eld  Throne of Eldraine
# 1  Legendary Artifact Creature — Scout  m20       Core Set 2020
# 2                     Creature — Human  grn   Guilds of Ravnica
#
#                                           image_uris  \
# 0  {'small': 'https://img.scryfall.com/cards/smal...
# 1  {'small': 'https://img.scryfall.com/cards/smal...
# 2  {'small': 'https://img.scryfall.com/cards/smal...
#
#                                           legalities                     name  \
# 0  {'standard': 'legal', 'oldschool': 'not_legal'...       Happily Ever After
# 1  {'standard': 'legal', 'oldschool': 'not_legal'...  Golos, Tireless Pilgrim
# 2  {'standard': 'legal', 'oldschool': 'not_legal'...           Hunted Witness
#
#                                  cardId  \
# 0  c38c9120-ac20-4f81-b8d8-9d490cc2a913
# 1  1fa48620-4c3d-4f75-be1f-c12c4aa59f51
# 2  8c31b8e5-2349-4119-9dc2-3e41c5364a78
#
#                                          oracle_text  \
# 0  When Happily Ever After enters the battlefield...
# 1  When Golos, Tireless Pilgrim enters the battle...
# 2  When Hunted Witness dies, create a 1/1 white S...
#
#                                        purchase_uris     colors  \
# 0  {'tcgplayer': 'https://shop.tcgplayer.com/prod...      {'W'}
# 1  {'tcgplayer': 'https://shop.tcgplayer.com/prod...  {'empty'}
# 2  {'tcgplayer': 'https://shop.tcgplayer.com/prod...      {'W'}
#
#               color_identity  \
# 0                      {'W'}
# 1  {'B', 'R', 'W', 'U', 'G'}
# 2                      {'W'}
#
#                                               prices  rarity  \
# 0  {'usd_foil': '4.15', 'tix': None, 'eur': None,...    rare
# 1  {'usd_foil': '9.32', 'tix': '3.07', 'eur': '1....    rare
# 2  {'usd_foil': '0.65', 'tix': '0.01', 'eur': '0....  common
#
#                                            mana_cost  \
# 0  [{'W': 1, 'B': 0, 'R': 0, 'G': 0, 'U': 0, 'X':...
# 1  [{'W': 0, 'B': 0, 'R': 0, 'G': 0, 'U': 0, 'X':...
# 2  [{'W': 1, 'B': 0, 'R': 0, 'G': 0, 'U': 0, 'X':...
#
#                                                 type  toughness  power
# 0  Counter({'Enchantment': 1, 'Land': 0, 'Creatur...        NaN    NaN
# 1  Counter({'Creature': 1, 'Artifact': 1, 'Land':...        5.0    3.0
# 2  Counter({'Creature': 1, 'Land': 0, 'Enchantmen...        1.0    1.0

# %% [markdown]
# # Scryfall API

# %%
CARDS_PER_PAGE = 175
PAGES_PER_WORKER = 100
BATCH_LIMIT = 20

dynamo_batches = [(first, first+BATCH_LIMIT) for first in list(range(0, CARDS_PER_PAGE, BATCH_LIMIT))]
dynamo_batches
# Out:
# [(0, 20),
#  (20, 40),
#  (40, 60),
#  (60, 80),
#  (80, 100),
#  (100, 120),
#  (120, 140),
#  (140, 160),
#  (160, 180)]

# %%
import json

# %%
pages = (1, 101)

# %%
payload = json.dumps({"first": pages[0], "last": pages[1]})
payload
# Out:
# '{"first": 1, "last": 101}'

# %%
event = json.loads(payload)
event
# Out:
# {'first': 1, 'last': 101}

# %%
leonin = 'https://api.scryfall.com/cards/named?fuzzy=leonin+warleader'

# %%
cards_url = 'https://api.scryfall.com/cards?page=11'

# %%
res = requests.get(cards_url)

# %%
one = res.json()['data'][0]

# %%
len(res.json()['data'])
# Out:
# 175

# %%
BATCH_LIMIT = 25
CARDS_PER_PAGE = 175

# %%
dynamo_batch = [(first, first+BATCH_LIMIT) for first in list(range(0, CARDS_PER_PAGE, BATCH_LIMIT))]
dynamo_batch
# Out:
# [(0, 25), (25, 50), (50, 75), (75, 100), (100, 125), (125, 150), (150, 175)]

# %%
batch = dynamo_batch[0]
batch
# Out:
# (0, 25)

# %%
list(range(5, 5))
# Out:
# []

# %%
table = 'global-cards-table'

# %%
cards = res.json()['data'][batch[0]:batch[1]]

# %%
len(cards[0]['mana_cost'])
# Out:
# 0

# %%
for idx, card in enumerate(cards):
    for key, val in card.items():
        cards[idx][key] = batch_format(val)
    cards[idx]['cardId'] = cards[idx]['id']

# %%
def save_scryfall_page(table, page):
    dynamo_batches = [(first, first+BATCH_LIMIT) for first in list(range(0, CARDS_PER_PAGE, BATCH_LIMIT))]

    res = requests.get(CARDS_URL.format(page))
    for batch in dynamo_batch:
        cards = res.json()['data'][batch[0]:batch[1]]
        # Save to Dynamo
        RequestItems = {
            table: [
                {
                    'PutRequest': {
                        'Item': card
                    }
                } for card in cards
            ]
        }
        return RequestItems
        #_ = dynamodb_lib.call(table, 'batch_write_item', RequestItems)

# %%
items = save_scryfall_page(table, 1)

# %%
def batch_format(val):
    if type(val) is str:
        return {"S": str(val)} if len(val)>0 else {"NULL": True}
    if type(val) is int:
        return {"N": str(val)}
    if type(val) is float:
        return {"N": str(val)}
    if type(val) is list:
        if len(val)>0:
            if type(val[0]) is str:
                return {"SS": val}
            if type(val[0]) is int:
                return {"NS": [str(item) for item in val]}
            if type(val[0]) is float:
                return {"NS": [str(item) for item in val]}
            if type(val[0]) is dict:
                return {
                        "M": {
                                str(idx): {
                                    "M": {dict_key: batch_format(dict_val) for dict_key, dict_val in dict_item.items()}
                                } for idx, dict_item in enumerate(val)
                            }  
                        }
        else:
            return {"SS": ['empty']}
    if type(val) is bool:
        return {"BOOL": True}
    if val is None:
        return {"NULL": True}
    if type(val) is dict:
        return {"M": {val_key: batch_format(val_val) for val_key, val_val in val.items()}}

# %%
cards = res.json()['data']

# %%
for key, val in cards[1].items():
    cards[1][key] = batch_format(val)

# %%
cards[1]
# Out:
# {'object': {'S': 'card'},
#  'id': {'S': '940509ec-8f58-4593-a598-142a827f55b0'},
#  'oracle_id': {'S': '2b565791-1b94-4dad-a48d-be7fc2198e19'},
#  'multiverse_ids': {'SS': ['empty']},
#  'tcgplayer_id': {'N': '204039'},
#  'name': {'S': 'Jushi Apprentice // Tomoya the Revealer'},
#  'lang': {'S': 'en'},
#  'released_at': {'S': '2019-11-07'},
#  'uri': {'S': 'https://api.scryfall.com/cards/940509ec-8f58-4593-a598-142a827f55b0'},
#  'scryfall_uri': {'S': 'https://scryfall.com/card/mb1/411/jushi-apprentice-tomoya-the-revealer?utm_source=api'},
#  'layout': {'S': 'flip'},
#  'highres_image': {'BOOL': True},
#  'image_uris': {'M': {'small': {'S': 'https://img.scryfall.com/cards/small/front/9/4/940509ec-8f58-4593-a598-142a827f55b0.jpg?1573507789'},
#    'normal': {'S': 'https://img.scryfall.com/cards/normal/front/9/4/940509ec-8f58-4593-a598-142a827f55b0.jpg?1573507789'},
#    'large': {'S': 'https://img.scryfall.com/cards/large/front/9/4/940509ec-8f58-4593-a598-142a827f55b0.jpg?1573507789'},
#    'png': {'S': 'https://img.scryfall.com/cards/png/front/9/4/940509ec-8f58-4593-a598-142a827f55b0.png?1573507789'},
#    'art_crop': {'S': 'https://img.scryfall.com/cards/art_crop/front/9/4/940509ec-8f58-4593-a598-142a827f55b0.jpg?1573507789'},
#    'border_crop': {'S': 'https://img.scryfall.com/cards/border_crop/front/9/4/940509ec-8f58-4593-a598-142a827f55b0.jpg?1573507789'}}},
#  'mana_cost': {'S': '{1}{U}'},
#  'cmc': {'N': '2.0'},
#  'type_line': {'S': 'Creature — Human Wizard // Legendary Creature — Human Wizard'},
#  'power': {'S': '1'},
#  'toughness': {'S': '2'},
#  'colors': {'SS': ['U']},
#  'color_identity': {'SS': ['U']},
#  'card_faces': {'M': {'0': {'M': {'object': {'S': 'card_face'},
#      'name': {'S': 'Jushi Apprentice'},
#      'mana_cost': {'S': '{1}{U}'},
#      'type_line': {'S': 'Creature — Human Wizard'},
#      'oracle_text': {'S': '{2}{U}, {T}: Draw a card. If you have nine or more cards in hand, flip Jushi Apprentice.'},
#      'power': {'S': '1'},
#      'toughness': {'S': '2'},
#      'artist': {'S': 'Glen Angus'},
#      'artist_id': {'S': '7be3b9e4-de9b-4a3d-884e-e67b9681d409'},
#      'illustration_id': {'S': '42548f86-c5d6-4056-b5d4-9087d24f0549'}}},
#    '1': {'M': {'object': {'S': 'card_face'},
#      'name': {'S': 'Tomoya the Revealer'},
#      'mana_cost': {'NULL': True},
#      'type_line': {'S': 'Legendary Creature — Human Wizard'},
#      'oracle_text': {'S': '{3}{U}{U}, {T}: Target player draws X cards, where X is the number of cards in your hand.'},
#      'power': {'S': '2'},
#      'toughness': {'S': '3'},
#      'artist': {'S': 'Glen Angus'},
#      'artist_id': {'S': '7be3b9e4-de9b-4a3d-884e-e67b9681d409'}}}}},
#  'legalities': {'M': {'standard': {'S': 'not_legal'},
#    'future': {'S': 'not_legal'},
#    'historic': {'S': 'not_legal'},
#    'pioneer': {'S': 'not_legal'},
#    'modern': {'S': 'legal'},
#    'legacy': {'S': 'legal'},
#    'pauper': {'S': 'not_legal'},
#    'vintage': {'S': 'legal'},
#    'penny': {'S': 'legal'},
#    'commander': {'S': 'legal'},
#    'brawl': {'S': 'not_legal'},
#    'duel': {'S': 'legal'},
#    'oldschool': {'S': 'not_legal'}}},
#  'games': {'SS': ['paper']},
#  'reserved': {'BOOL': True},
#  'foil': {'BOOL': True},
#  'nonfoil': {'BOOL': True},
#  'oversized': {'BOOL': True},
#  'promo': {'BOOL': True},
#  'reprint': {'BOOL': True},
#  'variation': {'BOOL': True},
#  'set': {'S': 'mb1'},
#  'set_name': {'S': 'Mystery Booster'},
#  'set_type': {'S': 'funny'},
#  'set_uri': {'S': 'https://api.scryfall.com/sets/d13bfc70-6137-4179-aa96-da30fd84de29'},
#  'set_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=set&q=e%3Amb1&unique=prints'},
#  'scryfall_set_uri': {'S': 'https://scryfall.com/sets/mb1?utm_source=api'},
#  'rulings_uri': {'S': 'https://api.scryfall.com/cards/940509ec-8f58-4593-a598-142a827f55b0/rulings'},
#  'prints_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A2b565791-1b94-4dad-a48d-be7fc2198e19&unique=prints'},
#  'collector_number': {'S': '411'},
#  'digital': {'BOOL': True},
#  'rarity': {'S': 'rare'},
#  'card_back_id': {'S': '0aeebaf5-8c7d-4636-9e82-8c27447861f7'},
#  'artist': {'S': 'Glen Angus'},
#  'artist_ids': {'SS': ['7be3b9e4-de9b-4a3d-884e-e67b9681d409']},
#  'illustration_id': {'S': '42548f86-c5d6-4056-b5d4-9087d24f0549'},
#  'border_color': {'S': 'black'},
#  'frame': {'S': '2003'},
#  'full_art': {'BOOL': True},
#  'textless': {'BOOL': True},
#  'booster': {'BOOL': True},
#  'story_spotlight': {'BOOL': True},
#  'edhrec_rank': {'N': '7001'},
#  'prices': {'M': {'usd': {'NULL': True},
#    'usd_foil': {'NULL': True},
#    'eur': {'NULL': True},
#    'tix': {'NULL': True}}},
#  'related_uris': {'M': {'tcgplayer_decks': {'S': 'https://decks.tcgplayer.com/magic/deck/search?contains=Jushi+Apprentice&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#    'edhrec': {'S': 'https://edhrec.com/route/?cc=Jushi+Apprentice'},
#    'mtgtop8': {'S': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Jushi+Apprentice'}}},
#  'purchase_uris': {'M': {'tcgplayer': {'S': 'https://shop.tcgplayer.com/product/productsearch?id=204039&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#    'cardmarket': {'S': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Jushi+Apprentice&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall'},
#    'cardhoarder': {'S': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Jushi+Apprentice&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}}}

# %%
cards = res.json()['data'][0:100]

for idx, card in enumerate(cards):
    for key, val in card.items():
        cards[idx][key] = batch_format(val)
    cards[idx]['cardId'] = cards[idx]['id']

# %%
cards = res.json()['data'][batch[0]:batch[1]]

# %%
res.json()['total_cards']
# Out:
# 263830

# %%
import math

# %%
cards_per_page = 175
total_cards = res.json()['total_cards']

total_pages = math.ceil(total_cards / cards_per_page)

total_pages
# Out:
# 1508

# %%
PAGES_PER_WORKER = 100

# %%
total_pages = 1508

# %%
worker_pages = [(first, first+PAGES_PER_WORKER) for first in list(range(1, total_pages+1, PAGES_PER_WORKER))]
worker_pages
# Out:
# [(1, 101),
#  (101, 201),
#  (201, 301),
#  (301, 401),
#  (401, 501),
#  (501, 601),
#  (601, 701),
#  (701, 801),
#  (801, 901),
#  (901, 1001),
#  (1001, 1101),
#  (1101, 1201),
#  (1201, 1301),
#  (1301, 1401),
#  (1401, 1501),
#  (1501, 1601)]

# %%
CARDS_URL = 'https://api.scryfall.com/cards?page={}'

# %%
CARDS_URL.format(1)
# Out:
# 'https://api.scryfall.com/cards?page=1'

# %%
cards_url = 'https://api.scryfall.com/cards?page=10'

# %%
int(str.split(cards_url, '=')[1])
# Out:
# 10

# %%
import datetime

# %%
start = datetime.datetime.now()

# %%
print(datetime.datetime.now() - then)
# Out:
# 0:00:23.186929

# %%
start = datetime.datetime.now()
all_cards_path = os.path.join(os.getcwd(), 'data', 'all_scryfall.json')
all_cards_df = pd.DataFrame()
cards_url = 'https://api.scryfall.com/cards?page=1'
cards_per_page = 175
has_more = True
while has_more:
#while int(str.split(cards_url, '=')[1]) < 101:
    res = requests.get(cards_url)
    
    #if int(cards_url[-1]) % 10 == 0:
    #    print('Getting page {}'.format(cards_url))
    
    cards_df = pd.DataFrame.from_dict(res.json()['data'])

    all_cards_df = pd.concat([all_cards_df, cards_df], sort=True, ignore_index=True)
          
    has_more = res.json()['has_more']
    cards_url = res.json()['next_page']
    
    sleep(0.1)

print(datetime.datetime.now() - then)
#all_cards_df.to_json(all_cards_path)
# Out:
# Getting page https://api.scryfall.com/cards?page=10
# Getting page https://api.scryfall.com/cards?page=20
# Getting page https://api.scryfall.com/cards?page=30
# Getting page https://api.scryfall.com/cards?page=40
# Getting page https://api.scryfall.com/cards?page=50
# Getting page https://api.scryfall.com/cards?page=60
# Getting page https://api.scryfall.com/cards?page=70
# Getting page https://api.scryfall.com/cards?page=80
# Getting page https://api.scryfall.com/cards?page=90
# Getting page https://api.scryfall.com/cards?page=100
# 0:05:45.799994

# %%
all_cards_path
# Out:
# 'C:\\Users\\LWEST\\Desktop\\mtgml-api\\notebooks\\..\\data\\all_scryfall.json'

# %%
all_cards_path = os.path.join(os.getcwd(), '..', 'data', 'all_scryfall.json')

all_cards_df = pd.read_json(all_cards_path)

# %%
all_cards_df.shape
# Out:
# (261438, 73)

# %%
all_cards_df.head(2)
# Out:
#   all_parts  arena_id          artist                              artist_ids  \
# 0      None       NaN   Milivoj Ćeran  [1eced451-4da5-42bc-b49d-70c41246581f]
# 1      None       NaN  Lucas Graciano  [ce98f39c-7cdd-47e6-a520-6c50443bb4c2]
#
#    booster border_color                          card_back_id card_faces  cmc  \
# 0    False        black  0aeebaf5-8c7d-4636-9e82-8c27447861f7       None  6.0
# 1    False        black  0aeebaf5-8c7d-4636-9e82-8c27447861f7       None  6.0
#
#   collector_number color_identity color_indicator colors  digital  \
# 0                5            [G]            None    [G]    False
# 1                4            [R]            None    [R]    False
#
#    edhrec_rank                                        flavor_text  foil frame  \
# 0          NaN  "Come, my wild children. Let's give the interl...  True  2015
# 1          NaN                  Half the size, double the mayhem.  True  2015
#
#   frame_effects  full_art    games  hand_modifier  highres_image  \
# 0          None     False  [paper]            NaN          False
# 1          None     False  [paper]            NaN          False
#
#                                      id                       illustration_id  \
# 0  dbcdbf7a-9294-47ad-9f93-c16b78c7463a  fe97c475-ef9a-41b2-872b-2469ac9f48d7
# 1  acb3ce9b-ee4f-410a-8db3-e87aeb0a4444  56da4782-3fe9-4230-b426-8e7903fe281f
#
#                                           image_uris lang  layout  \
# 0  {'small': 'https://img.scryfall.com/cards/smal...   en  normal
# 1  {'small': 'https://img.scryfall.com/cards/smal...   en  normal
#
#                                           legalities  life_modifier loyalty  \
# 0  {'standard': 'not_legal', 'future': 'not_legal...            NaN    None
# 1  {'standard': 'not_legal', 'future': 'not_legal...            NaN    None
#
#    mana_cost  mtgo_foil_id  mtgo_id multiverse_ids               name  \
# 0  {4}{G}{G}           NaN      NaN             []  Earthshaker Giant
# 1  {4}{R}{R}           NaN      NaN             []       Fiendish Duo
#
#    nonfoil object                             oracle_id  \
# 0    False   card  cd6250ae-9079-4a62-8a70-0d94fbac21bc
# 1    False   card  ab0dfae5-b9d4-417b-8a0d-2525ae3a73b9
#
#                                          oracle_text  oversized power preview  \
# 0  Trample\nWhen Earthshaker Giant enters the bat...      False     6    None
# 1  First strike\nIf a source would deal damage to...      False     5    None
#
#                                               prices printed_name  \
# 0  {'usd': None, 'usd_foil': '12.00', 'eur': None...         None
# 1  {'usd': None, 'usd_foil': '15.00', 'eur': None...         None
#
#   printed_text printed_type_line  \
# 0         None              None
# 1         None              None
#
#                                    prints_search_uri  promo promo_types  \
# 0  https://api.scryfall.com/cards/search?order=re...  False        None
# 1  https://api.scryfall.com/cards/search?order=re...  False        None
#
#                                        purchase_uris  rarity  \
# 0  {'tcgplayer': 'https://shop.tcgplayer.com/prod...  mythic
# 1  {'tcgplayer': 'https://shop.tcgplayer.com/prod...  mythic
#
#                                         related_uris released_at  reprint  \
# 0  {'tcgplayer_decks': 'https://decks.tcgplayer.c...  2019-11-15    False
# 1  {'tcgplayer_decks': 'https://decks.tcgplayer.c...  2019-11-15    False
#
#    reserved                                        rulings_uri  \
# 0     False  https://api.scryfall.com/cards/dbcdbf7a-9294-4...
# 1     False  https://api.scryfall.com/cards/acb3ce9b-ee4f-4...
#
#                                scryfall_set_uri  \
# 0  https://scryfall.com/sets/gn2?utm_source=api
# 1  https://scryfall.com/sets/gn2?utm_source=api
#
#                                         scryfall_uri  set         set_name  \
# 0  https://scryfall.com/card/gn2/5/earthshaker-gi...  gn2  Game Night 2019
# 1  https://scryfall.com/card/gn2/4/fiendish-duo?u...  gn2  Game Night 2019
#
#                                       set_search_uri set_type  \
# 0  https://api.scryfall.com/cards/search?order=se...      box
# 1  https://api.scryfall.com/cards/search?order=se...      box
#
#                                              set_uri  story_spotlight  \
# 0  https://api.scryfall.com/sets/a72727dd-dbab-41...            False
# 1  https://api.scryfall.com/sets/a72727dd-dbab-41...            False
#
#    tcgplayer_id  textless toughness               type_line  \
# 0      200607.0     False         6  Creature — Giant Druid
# 1      200606.0     False         5        Creature — Devil
#
#                                                  uri  variation variation_of  \
# 0  https://api.scryfall.com/cards/dbcdbf7a-9294-4...      False         None
# 1  https://api.scryfall.com/cards/acb3ce9b-ee4f-4...      False         None
#
#   watermark
# 0      None
# 1      None

# %%
url = all_cards_df.sample(5).image_uris.values[4]['normal']

# %%
from PIL import Image
import requests
from io import BytesIO

response = requests.get(url)
img = Image.open(BytesIO(response.content))
img.show()
