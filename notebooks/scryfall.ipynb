# %%
import pandas as pd
import numpy as np
import os
import requests
from time import sleep

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Scryfall API

# %%
cards_url = 'https://api.scryfall.com/cards?page=1'

# %%
res = requests.get(cards_url)

# %%
len(res.json()['data'])
# Out:
# 175

# %%
BATCH_LIMIT = 25
CARDS_PER_PAGE = 175

# %%
dynamo_batch = [(first, first+BATCH_LIMIT) for first in list(range(0, CARDS_PER_PAGE, BATCH_LIMIT))]
dynamo_batch
# Out:
# [(0, 25), (25, 50), (50, 75), (75, 100), (100, 125), (125, 150), (150, 175)]

# %%
batch = dynamo_batch[0]
batch
# Out:
# (0, 25)

# %%
list(range(5, 5))
# Out:
# []

# %%
table = 'global-cards-table'

# %%
cards = res.json()['data'][batch[0]:batch[1]]

# %%
len(cards[0]['mana_cost'])
# Out:
# 0

# %%
for idx, card in enumerate(cards):
    for key, val in card.items():
        cards[idx][key] = batch_format(val)
    cards[idx]['cardId'] = cards[idx]['id']

# %%
cards
# Out:
# [{'object': {'S': 'card'},
#   'id': {'S': '61dc9a80-850c-4945-b84a-85381cc3ee85'},
#   'oracle_id': {'S': 'e521322b-0e83-458c-8936-7021a80ee279'},
#   'multiverse_ids': {'SS': []},
#   'tcgplayer_id': {'N': '206636'},
#   'name': {'S': 'Temple of Plenty'},
#   'lang': {'S': 'en'},
#   'released_at': {'S': '2020-01-24'},
#   'uri': {'S': 'https://api.scryfall.com/cards/61dc9a80-850c-4945-b84a-85381cc3ee85'},
#   'scryfall_uri': {'S': 'https://scryfall.com/card/thb/351/temple-of-plenty?utm_source=api'},
#   'layout': {'S': 'normal'},
#   'highres_image': {'BOOL': True},
#   'image_uris': {'M': {'small': {'S': 'https://img.scryfall.com/cards/small/front/6/1/61dc9a80-850c-4945-b84a-85381cc3ee85.jpg?1577717404'},
#     'normal': {'S': 'https://img.scryfall.com/cards/normal/front/6/1/61dc9a80-850c-4945-b84a-85381cc3ee85.jpg?1577717404'},
#     'large': {'S': 'https://img.scryfall.com/cards/large/front/6/1/61dc9a80-850c-4945-b84a-85381cc3ee85.jpg?1577717404'},
#     'png': {'S': 'https://img.scryfall.com/cards/png/front/6/1/61dc9a80-850c-4945-b84a-85381cc3ee85.png?1577717404'},
#     'art_crop': {'S': 'https://img.scryfall.com/cards/art_crop/front/6/1/61dc9a80-850c-4945-b84a-85381cc3ee85.jpg?1577717404'},
#     'border_crop': {'S': 'https://img.scryfall.com/cards/border_crop/front/6/1/61dc9a80-850c-4945-b84a-85381cc3ee85.jpg?1577717404'}}},
#   'mana_cost': {'S': ''},
#   'cmc': {'N': '0.0'},
#   'type_line': {'S': 'Land'},
#   'oracle_text': {'S': 'Temple of Plenty enters the battlefield tapped.\nWhen Temple of Plenty enters the battlefield, scry 1. (Look at the top card of your library. You may put that card on the bottom of your library.)\n{T}: Add {G} or {W}.'},
#   'colors': {'SS': []},
#   'color_identity': {'SS': ['G', 'W']},
#   'legalities': {'M': {'standard': {'S': 'not_legal'},
#     'future': {'S': 'legal'},
#     'historic': {'S': 'not_legal'},
#     'pioneer': {'S': 'legal'},
#     'modern': {'S': 'legal'},
#     'legacy': {'S': 'legal'},
#     'pauper': {'S': 'not_legal'},
#     'vintage': {'S': 'legal'},
#     'penny': {'S': 'not_legal'},
#     'commander': {'S': 'legal'},
#     'brawl': {'S': 'not_legal'},
#     'duel': {'S': 'legal'},
#     'oldschool': {'S': 'not_legal'}}},
#   'games': {'SS': []},
#   'reserved': {'BOOL': True},
#   'foil': {'BOOL': True},
#   'nonfoil': {'BOOL': True},
#   'oversized': {'BOOL': True},
#   'promo': {'BOOL': True},
#   'reprint': {'BOOL': True},
#   'variation': {'BOOL': True},
#   'set': {'S': 'thb'},
#   'set_name': {'S': 'Theros Beyond Death'},
#   'set_type': {'S': 'expansion'},
#   'set_uri': {'S': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913'},
#   'set_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints'},
#   'scryfall_set_uri': {'S': 'https://scryfall.com/sets/thb?utm_source=api'},
#   'rulings_uri': {'S': 'https://api.scryfall.com/cards/61dc9a80-850c-4945-b84a-85381cc3ee85/rulings'},
#   'prints_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Ae521322b-0e83-458c-8936-7021a80ee279&unique=prints'},
#   'collector_number': {'S': '351'},
#   'digital': {'BOOL': True},
#   'rarity': {'S': 'rare'},
#   'card_back_id': {'S': '0aeebaf5-8c7d-4636-9e82-8c27447861f7'},
#   'artist': {'S': 'Chris Ostrowski'},
#   'artist_ids': {'SS': ['b5f1bd34-abee-40c9-99f7-a6ee089fb30b']},
#   'illustration_id': {'S': '846b14b7-34e8-4f0c-86bb-8bf5dc45bd00'},
#   'border_color': {'S': 'black'},
#   'frame': {'S': '2015'},
#   'frame_effects': {'SS': ['extendedart']},
#   'full_art': {'BOOL': True},
#   'textless': {'BOOL': True},
#   'booster': {'BOOL': True},
#   'story_spotlight': {'BOOL': True},
#   'edhrec_rank': {'N': '394'},
#   'preview': {'M': {'source': {'S': 'ChannelFireball'},
#     'source_uri': {'S': 'https://www.channelfireball.com/all-strategy/articles/3-point/theros-beyond-death-exclusive-preview/'},
#     'previewed_at': {'S': '2019-12-30'}}},
#   'prices': {'M': {'usd': {'S': '1.26'},
#     'usd_foil': {'NULL': True},
#     'eur': {'NULL': True},
#     'tix': {'NULL': True}}},
#   'related_uris': {'M': {'tcgplayer_decks': {'S': 'https://decks.tcgplayer.com/magic/deck/search?contains=Temple+of+Plenty&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'edhrec': {'S': 'https://edhrec.com/route/?cc=Temple+of+Plenty'},
#     'mtgtop8': {'S': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Temple+of+Plenty'}}},
#   'purchase_uris': {'M': {'tcgplayer': {'S': 'https://shop.tcgplayer.com/product/productsearch?id=206636&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'cardmarket': {'S': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Temple+of+Plenty&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall'},
#     'cardhoarder': {'S': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Temple+of+Plenty&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}},
#   'cardId': {'S': '61dc9a80-850c-4945-b84a-85381cc3ee85'}},
#  {'object': {'S': 'card'},
#   'id': {'S': 'c7f80f4d-0858-46ff-9305-ee6e380eb521'},
#   'oracle_id': {'S': '7c439c18-31dc-41fe-b03d-3fca06e6fc0b'},
#   'multiverse_ids': {'SS': []},
#   'tcgplayer_id': {'N': '206635'},
#   'name': {'S': 'Temple of Malice'},
#   'lang': {'S': 'en'},
#   'released_at': {'S': '2020-01-24'},
#   'uri': {'S': 'https://api.scryfall.com/cards/c7f80f4d-0858-46ff-9305-ee6e380eb521'},
#   'scryfall_uri': {'S': 'https://scryfall.com/card/thb/350/temple-of-malice?utm_source=api'},
#   'layout': {'S': 'normal'},
#   'highres_image': {'BOOL': True},
#   'image_uris': {'M': {'small': {'S': 'https://img.scryfall.com/cards/small/front/c/7/c7f80f4d-0858-46ff-9305-ee6e380eb521.jpg?1577717143'},
#     'normal': {'S': 'https://img.scryfall.com/cards/normal/front/c/7/c7f80f4d-0858-46ff-9305-ee6e380eb521.jpg?1577717143'},
#     'large': {'S': 'https://img.scryfall.com/cards/large/front/c/7/c7f80f4d-0858-46ff-9305-ee6e380eb521.jpg?1577717143'},
#     'png': {'S': 'https://img.scryfall.com/cards/png/front/c/7/c7f80f4d-0858-46ff-9305-ee6e380eb521.png?1577717143'},
#     'art_crop': {'S': 'https://img.scryfall.com/cards/art_crop/front/c/7/c7f80f4d-0858-46ff-9305-ee6e380eb521.jpg?1577717143'},
#     'border_crop': {'S': 'https://img.scryfall.com/cards/border_crop/front/c/7/c7f80f4d-0858-46ff-9305-ee6e380eb521.jpg?1577717143'}}},
#   'mana_cost': {'S': ''},
#   'cmc': {'N': '0.0'},
#   'type_line': {'S': 'Land'},
#   'oracle_text': {'S': 'Temple of Malice enters the battlefield tapped.\nWhen Temple of Malice enters the battlefield, scry 1. (Look at the top card of your library. You may put that card on the bottom of your library.)\n{T}: Add {B} or {R}.'},
#   'colors': {'SS': []},
#   'color_identity': {'SS': ['B', 'R']},
#   'legalities': {'M': {'standard': {'S': 'not_legal'},
#     'future': {'S': 'legal'},
#     'historic': {'S': 'not_legal'},
#     'pioneer': {'S': 'legal'},
#     'modern': {'S': 'legal'},
#     'legacy': {'S': 'legal'},
#     'pauper': {'S': 'not_legal'},
#     'vintage': {'S': 'legal'},
#     'penny': {'S': 'not_legal'},
#     'commander': {'S': 'legal'},
#     'brawl': {'S': 'not_legal'},
#     'duel': {'S': 'legal'},
#     'oldschool': {'S': 'not_legal'}}},
#   'games': {'SS': []},
#   'reserved': {'BOOL': True},
#   'foil': {'BOOL': True},
#   'nonfoil': {'BOOL': True},
#   'oversized': {'BOOL': True},
#   'promo': {'BOOL': True},
#   'reprint': {'BOOL': True},
#   'variation': {'BOOL': True},
#   'set': {'S': 'thb'},
#   'set_name': {'S': 'Theros Beyond Death'},
#   'set_type': {'S': 'expansion'},
#   'set_uri': {'S': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913'},
#   'set_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints'},
#   'scryfall_set_uri': {'S': 'https://scryfall.com/sets/thb?utm_source=api'},
#   'rulings_uri': {'S': 'https://api.scryfall.com/cards/c7f80f4d-0858-46ff-9305-ee6e380eb521/rulings'},
#   'prints_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A7c439c18-31dc-41fe-b03d-3fca06e6fc0b&unique=prints'},
#   'collector_number': {'S': '350'},
#   'digital': {'BOOL': True},
#   'rarity': {'S': 'rare'},
#   'card_back_id': {'S': '0aeebaf5-8c7d-4636-9e82-8c27447861f7'},
#   'artist': {'S': 'Jonas De Ro'},
#   'artist_ids': {'SS': ['561ebf9e-8d93-4b57-8156-8826d0c19601']},
#   'illustration_id': {'S': '28247dd9-4241-4f06-b6b3-6552fc45561e'},
#   'border_color': {'S': 'black'},
#   'frame': {'S': '2015'},
#   'frame_effects': {'SS': ['extendedart']},
#   'full_art': {'BOOL': True},
#   'textless': {'BOOL': True},
#   'booster': {'BOOL': True},
#   'story_spotlight': {'BOOL': True},
#   'edhrec_rank': {'N': '411'},
#   'preview': {'M': {'source': {'S': 'ChannelFireball'},
#     'source_uri': {'S': 'https://www.channelfireball.com/all-strategy/articles/3-point/theros-beyond-death-exclusive-preview/'},
#     'previewed_at': {'S': '2019-12-30'}}},
#   'prices': {'M': {'usd': {'S': '1.40'},
#     'usd_foil': {'NULL': True},
#     'eur': {'NULL': True},
#     'tix': {'NULL': True}}},
#   'related_uris': {'M': {'tcgplayer_decks': {'S': 'https://decks.tcgplayer.com/magic/deck/search?contains=Temple+of+Malice&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'edhrec': {'S': 'https://edhrec.com/route/?cc=Temple+of+Malice'},
#     'mtgtop8': {'S': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Temple+of+Malice'}}},
#   'purchase_uris': {'M': {'tcgplayer': {'S': 'https://shop.tcgplayer.com/product/productsearch?id=206635&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'cardmarket': {'S': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Temple+of+Malice&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall'},
#     'cardhoarder': {'S': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Temple+of+Malice&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}},
#   'cardId': {'S': 'c7f80f4d-0858-46ff-9305-ee6e380eb521'}},
#  {'object': {'S': 'card'},
#   'id': {'S': '7b705a44-b1b6-491b-aaab-53e0577fdde3'},
#   'oracle_id': {'S': '89f43e27-790b-4ca1-8ba7-0882b31e0783'},
#   'multiverse_ids': {'SS': []},
#   'tcgplayer_id': {'N': '206634'},
#   'name': {'S': 'Temple of Enlightenment'},
#   'lang': {'S': 'en'},
#   'released_at': {'S': '2020-01-24'},
#   'uri': {'S': 'https://api.scryfall.com/cards/7b705a44-b1b6-491b-aaab-53e0577fdde3'},
#   'scryfall_uri': {'S': 'https://scryfall.com/card/thb/349/temple-of-enlightenment?utm_source=api'},
#   'layout': {'S': 'normal'},
#   'highres_image': {'BOOL': True},
#   'image_uris': {'M': {'small': {'S': 'https://img.scryfall.com/cards/small/front/7/b/7b705a44-b1b6-491b-aaab-53e0577fdde3.jpg?1577716937'},
#     'normal': {'S': 'https://img.scryfall.com/cards/normal/front/7/b/7b705a44-b1b6-491b-aaab-53e0577fdde3.jpg?1577716937'},
#     'large': {'S': 'https://img.scryfall.com/cards/large/front/7/b/7b705a44-b1b6-491b-aaab-53e0577fdde3.jpg?1577716937'},
#     'png': {'S': 'https://img.scryfall.com/cards/png/front/7/b/7b705a44-b1b6-491b-aaab-53e0577fdde3.png?1577716937'},
#     'art_crop': {'S': 'https://img.scryfall.com/cards/art_crop/front/7/b/7b705a44-b1b6-491b-aaab-53e0577fdde3.jpg?1577716937'},
#     'border_crop': {'S': 'https://img.scryfall.com/cards/border_crop/front/7/b/7b705a44-b1b6-491b-aaab-53e0577fdde3.jpg?1577716937'}}},
#   'mana_cost': {'S': ''},
#   'cmc': {'N': '0.0'},
#   'type_line': {'S': 'Land'},
#   'oracle_text': {'S': 'Temple of Enlightenment enters the battlefield tapped.\nWhen Temple of Enlightenment enters the battlefield, scry 1. (Look at the top card of your library. You may put that card on the bottom of your library.)\n{T}: Add {W} or {U}.'},
#   'colors': {'SS': []},
#   'color_identity': {'SS': ['U', 'W']},
#   'legalities': {'M': {'standard': {'S': 'not_legal'},
#     'future': {'S': 'legal'},
#     'historic': {'S': 'not_legal'},
#     'pioneer': {'S': 'legal'},
#     'modern': {'S': 'legal'},
#     'legacy': {'S': 'legal'},
#     'pauper': {'S': 'not_legal'},
#     'vintage': {'S': 'legal'},
#     'penny': {'S': 'not_legal'},
#     'commander': {'S': 'legal'},
#     'brawl': {'S': 'not_legal'},
#     'duel': {'S': 'legal'},
#     'oldschool': {'S': 'not_legal'}}},
#   'games': {'SS': []},
#   'reserved': {'BOOL': True},
#   'foil': {'BOOL': True},
#   'nonfoil': {'BOOL': True},
#   'oversized': {'BOOL': True},
#   'promo': {'BOOL': True},
#   'reprint': {'BOOL': True},
#   'variation': {'BOOL': True},
#   'set': {'S': 'thb'},
#   'set_name': {'S': 'Theros Beyond Death'},
#   'set_type': {'S': 'expansion'},
#   'set_uri': {'S': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913'},
#   'set_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints'},
#   'scryfall_set_uri': {'S': 'https://scryfall.com/sets/thb?utm_source=api'},
#   'rulings_uri': {'S': 'https://api.scryfall.com/cards/7b705a44-b1b6-491b-aaab-53e0577fdde3/rulings'},
#   'prints_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A89f43e27-790b-4ca1-8ba7-0882b31e0783&unique=prints'},
#   'collector_number': {'S': '349'},
#   'digital': {'BOOL': True},
#   'rarity': {'S': 'rare'},
#   'card_back_id': {'S': '0aeebaf5-8c7d-4636-9e82-8c27447861f7'},
#   'artist': {'S': 'Piotr Dura'},
#   'artist_ids': {'SS': ['aff176e8-1d15-432e-ad1d-207a474decba']},
#   'illustration_id': {'S': 'ccd5a446-1ef3-40ba-a596-68578dd6f35c'},
#   'border_color': {'S': 'black'},
#   'frame': {'S': '2015'},
#   'frame_effects': {'SS': ['extendedart']},
#   'full_art': {'BOOL': True},
#   'textless': {'BOOL': True},
#   'booster': {'BOOL': True},
#   'story_spotlight': {'BOOL': True},
#   'edhrec_rank': {'N': '337'},
#   'preview': {'M': {'source': {'S': 'ChannelFireball'},
#     'source_uri': {'S': 'https://www.channelfireball.com/all-strategy/articles/3-point/theros-beyond-death-exclusive-preview/'},
#     'previewed_at': {'S': '2019-12-30'}}},
#   'prices': {'M': {'usd': {'S': '1.21'},
#     'usd_foil': {'NULL': True},
#     'eur': {'NULL': True},
#     'tix': {'NULL': True}}},
#   'related_uris': {'M': {'tcgplayer_decks': {'S': 'https://decks.tcgplayer.com/magic/deck/search?contains=Temple+of+Enlightenment&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'edhrec': {'S': 'https://edhrec.com/route/?cc=Temple+of+Enlightenment'},
#     'mtgtop8': {'S': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Temple+of+Enlightenment'}}},
#   'purchase_uris': {'M': {'tcgplayer': {'S': 'https://shop.tcgplayer.com/product/productsearch?id=206634&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'cardmarket': {'S': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Temple+of+Enlightenment&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall'},
#     'cardhoarder': {'S': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Temple+of+Enlightenment&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}},
#   'cardId': {'S': '7b705a44-b1b6-491b-aaab-53e0577fdde3'}},
#  {'object': {'S': 'card'},
#   'id': {'S': '80c6be18-356e-4e8b-899c-4a82f5d41a41'},
#   'oracle_id': {'S': '33b9b3bd-33ca-46f3-b8bb-a978bc3d1085'},
#   'multiverse_ids': {'SS': []},
#   'tcgplayer_id': {'N': '206633'},
#   'name': {'S': 'Temple of Deceit'},
#   'lang': {'S': 'en'},
#   'released_at': {'S': '2020-01-24'},
#   'uri': {'S': 'https://api.scryfall.com/cards/80c6be18-356e-4e8b-899c-4a82f5d41a41'},
#   'scryfall_uri': {'S': 'https://scryfall.com/card/thb/348/temple-of-deceit?utm_source=api'},
#   'layout': {'S': 'normal'},
#   'highres_image': {'BOOL': True},
#   'image_uris': {'M': {'small': {'S': 'https://img.scryfall.com/cards/small/front/8/0/80c6be18-356e-4e8b-899c-4a82f5d41a41.jpg?1577905582'},
#     'normal': {'S': 'https://img.scryfall.com/cards/normal/front/8/0/80c6be18-356e-4e8b-899c-4a82f5d41a41.jpg?1577905582'},
#     'large': {'S': 'https://img.scryfall.com/cards/large/front/8/0/80c6be18-356e-4e8b-899c-4a82f5d41a41.jpg?1577905582'},
#     'png': {'S': 'https://img.scryfall.com/cards/png/front/8/0/80c6be18-356e-4e8b-899c-4a82f5d41a41.png?1577905582'},
#     'art_crop': {'S': 'https://img.scryfall.com/cards/art_crop/front/8/0/80c6be18-356e-4e8b-899c-4a82f5d41a41.jpg?1577905582'},
#     'border_crop': {'S': 'https://img.scryfall.com/cards/border_crop/front/8/0/80c6be18-356e-4e8b-899c-4a82f5d41a41.jpg?1577905582'}}},
#   'mana_cost': {'S': ''},
#   'cmc': {'N': '0.0'},
#   'type_line': {'S': 'Land'},
#   'oracle_text': {'S': 'Temple of Deceit enters the battlefield tapped.\nWhen Temple of Deceit enters the battlefield, scry 1. (Look at the top card of your library. You may put that card on the bottom of your library.)\n{T}: Add {U} or {B}.'},
#   'colors': {'SS': []},
#   'color_identity': {'SS': ['B', 'U']},
#   'legalities': {'M': {'standard': {'S': 'not_legal'},
#     'future': {'S': 'legal'},
#     'historic': {'S': 'not_legal'},
#     'pioneer': {'S': 'legal'},
#     'modern': {'S': 'legal'},
#     'legacy': {'S': 'legal'},
#     'pauper': {'S': 'not_legal'},
#     'vintage': {'S': 'legal'},
#     'penny': {'S': 'not_legal'},
#     'commander': {'S': 'legal'},
#     'brawl': {'S': 'not_legal'},
#     'duel': {'S': 'legal'},
#     'oldschool': {'S': 'not_legal'}}},
#   'games': {'SS': []},
#   'reserved': {'BOOL': True},
#   'foil': {'BOOL': True},
#   'nonfoil': {'BOOL': True},
#   'oversized': {'BOOL': True},
#   'promo': {'BOOL': True},
#   'reprint': {'BOOL': True},
#   'variation': {'BOOL': True},
#   'set': {'S': 'thb'},
#   'set_name': {'S': 'Theros Beyond Death'},
#   'set_type': {'S': 'expansion'},
#   'set_uri': {'S': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913'},
#   'set_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints'},
#   'scryfall_set_uri': {'S': 'https://scryfall.com/sets/thb?utm_source=api'},
#   'rulings_uri': {'S': 'https://api.scryfall.com/cards/80c6be18-356e-4e8b-899c-4a82f5d41a41/rulings'},
#   'prints_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A33b9b3bd-33ca-46f3-b8bb-a978bc3d1085&unique=prints'},
#   'collector_number': {'S': '348'},
#   'digital': {'BOOL': True},
#   'rarity': {'S': 'rare'},
#   'card_back_id': {'S': '0aeebaf5-8c7d-4636-9e82-8c27447861f7'},
#   'artist': {'S': 'Jonas De Ro'},
#   'artist_ids': {'SS': ['561ebf9e-8d93-4b57-8156-8826d0c19601']},
#   'illustration_id': {'S': '8acc157a-0401-456a-8bf1-9d7e0da9ebd1'},
#   'border_color': {'S': 'black'},
#   'frame': {'S': '2015'},
#   'frame_effects': {'SS': ['extendedart']},
#   'full_art': {'BOOL': True},
#   'textless': {'BOOL': True},
#   'booster': {'BOOL': True},
#   'story_spotlight': {'BOOL': True},
#   'edhrec_rank': {'N': '236'},
#   'preview': {'M': {'source': {'S': 'ChannelFireball'},
#     'source_uri': {'S': 'https://www.channelfireball.com/all-strategy/articles/3-point/theros-beyond-death-exclusive-preview/'},
#     'previewed_at': {'S': '2019-12-30'}}},
#   'prices': {'M': {'usd': {'S': '1.20'},
#     'usd_foil': {'NULL': True},
#     'eur': {'NULL': True},
#     'tix': {'NULL': True}}},
#   'related_uris': {'M': {'tcgplayer_decks': {'S': 'https://decks.tcgplayer.com/magic/deck/search?contains=Temple+of+Deceit&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'edhrec': {'S': 'https://edhrec.com/route/?cc=Temple+of+Deceit'},
#     'mtgtop8': {'S': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Temple+of+Deceit'}}},
#   'purchase_uris': {'M': {'tcgplayer': {'S': 'https://shop.tcgplayer.com/product/productsearch?id=206633&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'cardmarket': {'S': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Temple+of+Deceit&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall'},
#     'cardhoarder': {'S': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Temple+of+Deceit&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}},
#   'cardId': {'S': '80c6be18-356e-4e8b-899c-4a82f5d41a41'}},
#  {'object': {'S': 'card'},
#   'id': {'S': '2a4471a4-efcf-46a9-87df-62af9d616bd1'},
#   'oracle_id': {'S': '3baa8e38-ef93-435d-b63e-f781d5bfcc68'},
#   'multiverse_ids': {'SS': []},
#   'tcgplayer_id': {'N': '206632'},
#   'name': {'S': 'Temple of Abandon'},
#   'lang': {'S': 'en'},
#   'released_at': {'S': '2020-01-24'},
#   'uri': {'S': 'https://api.scryfall.com/cards/2a4471a4-efcf-46a9-87df-62af9d616bd1'},
#   'scryfall_uri': {'S': 'https://scryfall.com/card/thb/347/temple-of-abandon?utm_source=api'},
#   'layout': {'S': 'normal'},
#   'highres_image': {'BOOL': True},
#   'image_uris': {'M': {'small': {'S': 'https://img.scryfall.com/cards/small/front/2/a/2a4471a4-efcf-46a9-87df-62af9d616bd1.jpg?1577716642'},
#     'normal': {'S': 'https://img.scryfall.com/cards/normal/front/2/a/2a4471a4-efcf-46a9-87df-62af9d616bd1.jpg?1577716642'},
#     'large': {'S': 'https://img.scryfall.com/cards/large/front/2/a/2a4471a4-efcf-46a9-87df-62af9d616bd1.jpg?1577716642'},
#     'png': {'S': 'https://img.scryfall.com/cards/png/front/2/a/2a4471a4-efcf-46a9-87df-62af9d616bd1.png?1577716642'},
#     'art_crop': {'S': 'https://img.scryfall.com/cards/art_crop/front/2/a/2a4471a4-efcf-46a9-87df-62af9d616bd1.jpg?1577716642'},
#     'border_crop': {'S': 'https://img.scryfall.com/cards/border_crop/front/2/a/2a4471a4-efcf-46a9-87df-62af9d616bd1.jpg?1577716642'}}},
#   'mana_cost': {'S': ''},
#   'cmc': {'N': '0.0'},
#   'type_line': {'S': 'Land'},
#   'oracle_text': {'S': 'Temple of Abandon enters the battlefield tapped.\nWhen Temple of Abandon enters the battlefield, scry 1. (Look at the top card of your library. You may put that card on the bottom of your library.)\n{T}: Add {R} or {G}.'},
#   'colors': {'SS': []},
#   'color_identity': {'SS': ['G', 'R']},
#   'legalities': {'M': {'standard': {'S': 'not_legal'},
#     'future': {'S': 'legal'},
#     'historic': {'S': 'not_legal'},
#     'pioneer': {'S': 'legal'},
#     'modern': {'S': 'legal'},
#     'legacy': {'S': 'legal'},
#     'pauper': {'S': 'not_legal'},
#     'vintage': {'S': 'legal'},
#     'penny': {'S': 'not_legal'},
#     'commander': {'S': 'legal'},
#     'brawl': {'S': 'not_legal'},
#     'duel': {'S': 'legal'},
#     'oldschool': {'S': 'not_legal'}}},
#   'games': {'SS': []},
#   'reserved': {'BOOL': True},
#   'foil': {'BOOL': True},
#   'nonfoil': {'BOOL': True},
#   'oversized': {'BOOL': True},
#   'promo': {'BOOL': True},
#   'reprint': {'BOOL': True},
#   'variation': {'BOOL': True},
#   'set': {'S': 'thb'},
#   'set_name': {'S': 'Theros Beyond Death'},
#   'set_type': {'S': 'expansion'},
#   'set_uri': {'S': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913'},
#   'set_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints'},
#   'scryfall_set_uri': {'S': 'https://scryfall.com/sets/thb?utm_source=api'},
#   'rulings_uri': {'S': 'https://api.scryfall.com/cards/2a4471a4-efcf-46a9-87df-62af9d616bd1/rulings'},
#   'prints_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A3baa8e38-ef93-435d-b63e-f781d5bfcc68&unique=prints'},
#   'collector_number': {'S': '347'},
#   'digital': {'BOOL': True},
#   'rarity': {'S': 'rare'},
#   'card_back_id': {'S': '0aeebaf5-8c7d-4636-9e82-8c27447861f7'},
#   'artist': {'S': 'Adam Paquette'},
#   'artist_ids': {'SS': ['89023dad-e6c0-41e0-83fb-eb2bfbbdc3f2']},
#   'illustration_id': {'S': '2a0fba2e-b5f9-44cd-8b42-f843b5fa84ba'},
#   'border_color': {'S': 'black'},
#   'frame': {'S': '2015'},
#   'frame_effects': {'SS': ['extendedart']},
#   'full_art': {'BOOL': True},
#   'textless': {'BOOL': True},
#   'booster': {'BOOL': True},
#   'story_spotlight': {'BOOL': True},
#   'edhrec_rank': {'N': '374'},
#   'preview': {'M': {'source': {'S': 'ChannelFireball'},
#     'source_uri': {'S': 'https://www.channelfireball.com/all-strategy/articles/3-point/theros-beyond-death-exclusive-preview/'},
#     'previewed_at': {'S': '2019-12-30'}}},
#   'prices': {'M': {'usd': {'S': '1.23'},
#     'usd_foil': {'NULL': True},
#     'eur': {'NULL': True},
#     'tix': {'NULL': True}}},
#   'related_uris': {'M': {'tcgplayer_decks': {'S': 'https://decks.tcgplayer.com/magic/deck/search?contains=Temple+of+Abandon&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'edhrec': {'S': 'https://edhrec.com/route/?cc=Temple+of+Abandon'},
#     'mtgtop8': {'S': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Temple+of+Abandon'}}},
#   'purchase_uris': {'M': {'tcgplayer': {'S': 'https://shop.tcgplayer.com/product/productsearch?id=206632&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'cardmarket': {'S': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Temple+of+Abandon&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall'},
#     'cardhoarder': {'S': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Temple+of+Abandon&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}},
#   'cardId': {'S': '2a4471a4-efcf-46a9-87df-62af9d616bd1'}},
#  {'object': {'S': 'card'},
#   'id': {'S': 'f3e73185-afdf-4fae-82c3-b5ea355c1572'},
#   'oracle_id': {'S': 'cfb8cdde-11f6-441a-942b-32d8c191fc90'},
#   'multiverse_ids': {'SS': []},
#   'tcgplayer_id': {'N': '206648'},
#   'name': {'S': 'Nyx Lotus'},
#   'lang': {'S': 'en'},
#   'released_at': {'S': '2020-01-24'},
#   'uri': {'S': 'https://api.scryfall.com/cards/f3e73185-afdf-4fae-82c3-b5ea355c1572'},
#   'scryfall_uri': {'S': 'https://scryfall.com/card/thb/344/nyx-lotus?utm_source=api'},
#   'layout': {'S': 'normal'},
#   'highres_image': {'BOOL': True},
#   'image_uris': {'M': {'small': {'S': 'https://img.scryfall.com/cards/small/front/f/3/f3e73185-afdf-4fae-82c3-b5ea355c1572.jpg?1577968563'},
#     'normal': {'S': 'https://img.scryfall.com/cards/normal/front/f/3/f3e73185-afdf-4fae-82c3-b5ea355c1572.jpg?1577968563'},
#     'large': {'S': 'https://img.scryfall.com/cards/large/front/f/3/f3e73185-afdf-4fae-82c3-b5ea355c1572.jpg?1577968563'},
#     'png': {'S': 'https://img.scryfall.com/cards/png/front/f/3/f3e73185-afdf-4fae-82c3-b5ea355c1572.png?1577968563'},
#     'art_crop': {'S': 'https://img.scryfall.com/cards/art_crop/front/f/3/f3e73185-afdf-4fae-82c3-b5ea355c1572.jpg?1577968563'},
#     'border_crop': {'S': 'https://img.scryfall.com/cards/border_crop/front/f/3/f3e73185-afdf-4fae-82c3-b5ea355c1572.jpg?1577968563'}}},
#   'mana_cost': {'S': '{4}'},
#   'cmc': {'N': '4.0'},
#   'type_line': {'S': 'Legendary Artifact'},
#   'oracle_text': {'S': 'Nyx Lotus enters the battlefield tapped.\n{T}: Choose a color. Add an amount of mana of that color equal to your devotion to that color. (Your devotion to a color is the number of mana symbols of that color in the mana costs of permanents you control.)'},
#   'colors': {'SS': []},
#   'color_identity': {'SS': []},
#   'legalities': {'M': {'standard': {'S': 'not_legal'},
#     'future': {'S': 'legal'},
#     'historic': {'S': 'not_legal'},
#     'pioneer': {'S': 'not_legal'},
#     'modern': {'S': 'not_legal'},
#     'legacy': {'S': 'not_legal'},
#     'pauper': {'S': 'not_legal'},
#     'vintage': {'S': 'not_legal'},
#     'penny': {'S': 'not_legal'},
#     'commander': {'S': 'not_legal'},
#     'brawl': {'S': 'not_legal'},
#     'duel': {'S': 'not_legal'},
#     'oldschool': {'S': 'not_legal'}}},
#   'games': {'SS': []},
#   'reserved': {'BOOL': True},
#   'foil': {'BOOL': True},
#   'nonfoil': {'BOOL': True},
#   'oversized': {'BOOL': True},
#   'promo': {'BOOL': True},
#   'reprint': {'BOOL': True},
#   'variation': {'BOOL': True},
#   'set': {'S': 'thb'},
#   'set_name': {'S': 'Theros Beyond Death'},
#   'set_type': {'S': 'expansion'},
#   'set_uri': {'S': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913'},
#   'set_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints'},
#   'scryfall_set_uri': {'S': 'https://scryfall.com/sets/thb?utm_source=api'},
#   'rulings_uri': {'S': 'https://api.scryfall.com/cards/f3e73185-afdf-4fae-82c3-b5ea355c1572/rulings'},
#   'prints_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Acfb8cdde-11f6-441a-942b-32d8c191fc90&unique=prints'},
#   'collector_number': {'S': '344'},
#   'digital': {'BOOL': True},
#   'rarity': {'S': 'rare'},
#   'card_back_id': {'S': '0aeebaf5-8c7d-4636-9e82-8c27447861f7'},
#   'artist': {'S': 'Raoul Vitale'},
#   'artist_ids': {'SS': ['c7c15d49-f84b-4d98-9a34-e80e8347b756']},
#   'illustration_id': {'S': '1f1ddcb3-6e8e-4165-9c32-f31362ea90d9'},
#   'border_color': {'S': 'black'},
#   'frame': {'S': '2015'},
#   'frame_effects': {'SS': ['extendedart', 'legendary']},
#   'full_art': {'BOOL': True},
#   'textless': {'BOOL': True},
#   'booster': {'BOOL': True},
#   'story_spotlight': {'BOOL': True},
#   'edhrec_rank': {'N': '16269'},
#   'preview': {'M': {'source': {'S': 'Wizards of the Coast'},
#     'source_uri': {'S': 'https://magic.wizards.com/en/articles/archive/card-image-gallery/theros-beyond-death-variants'},
#     'previewed_at': {'S': '2020-01-02'}}},
#   'prices': {'M': {'usd': {'S': '9.22'},
#     'usd_foil': {'NULL': True},
#     'eur': {'NULL': True},
#     'tix': {'NULL': True}}},
#   'related_uris': {'M': {'tcgplayer_decks': {'S': 'https://decks.tcgplayer.com/magic/deck/search?contains=Nyx+Lotus&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'edhrec': {'S': 'https://edhrec.com/route/?cc=Nyx+Lotus'},
#     'mtgtop8': {'S': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Nyx+Lotus'}}},
#   'purchase_uris': {'M': {'tcgplayer': {'S': 'https://shop.tcgplayer.com/product/productsearch?id=206648&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'cardmarket': {'S': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Nyx+Lotus&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall'},
#     'cardhoarder': {'S': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Nyx+Lotus&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}},
#   'cardId': {'S': 'f3e73185-afdf-4fae-82c3-b5ea355c1572'}},
#  {'object': {'S': 'card'},
#   'id': {'S': 'bcf6e4d1-1b4f-450c-a0fc-2d02313979ca'},
#   'oracle_id': {'S': 'ee302659-59ed-4eef-babe-451b9ccf7f14'},
#   'multiverse_ids': {'SS': []},
#   'name': {'S': "Uro, Titan of Nature's Wrath"},
#   'lang': {'S': 'en'},
#   'released_at': {'S': '2020-01-24'},
#   'uri': {'S': 'https://api.scryfall.com/cards/bcf6e4d1-1b4f-450c-a0fc-2d02313979ca'},
#   'scryfall_uri': {'S': 'https://scryfall.com/card/thb/343/uro-titan-of-natures-wrath?utm_source=api'},
#   'layout': {'S': 'normal'},
#   'highres_image': {'BOOL': True},
#   'image_uris': {'M': {'small': {'S': 'https://img.scryfall.com/cards/small/front/b/c/bcf6e4d1-1b4f-450c-a0fc-2d02313979ca.jpg?1578316116'},
#     'normal': {'S': 'https://img.scryfall.com/cards/normal/front/b/c/bcf6e4d1-1b4f-450c-a0fc-2d02313979ca.jpg?1578316116'},
#     'large': {'S': 'https://img.scryfall.com/cards/large/front/b/c/bcf6e4d1-1b4f-450c-a0fc-2d02313979ca.jpg?1578316116'},
#     'png': {'S': 'https://img.scryfall.com/cards/png/front/b/c/bcf6e4d1-1b4f-450c-a0fc-2d02313979ca.png?1578316116'},
#     'art_crop': {'S': 'https://img.scryfall.com/cards/art_crop/front/b/c/bcf6e4d1-1b4f-450c-a0fc-2d02313979ca.jpg?1578316116'},
#     'border_crop': {'S': 'https://img.scryfall.com/cards/border_crop/front/b/c/bcf6e4d1-1b4f-450c-a0fc-2d02313979ca.jpg?1578316116'}}},
#   'mana_cost': {'S': '{1}{G}{U}'},
#   'cmc': {'N': '3.0'},
#   'type_line': {'S': 'Legendary Creature — Elder Giant'},
#   'oracle_text': {'S': 'When Uro enters the battlefield, sacrifice it unless it escaped.\nWhenever Uro enters the battlefield or attacks, you gain 3 life and draw a card, then you may put a land card from your hand onto the battlefield.\nEscape-{G}{G}{U}{U}, Exile five other cards from your graveyard. (You may cast this card from your graveyard for its escape cost.)'},
#   'power': {'S': '6'},
#   'toughness': {'S': '6'},
#   'colors': {'SS': ['G', 'U']},
#   'color_identity': {'SS': ['G', 'U']},
#   'legalities': {'M': {'standard': {'S': 'not_legal'},
#     'future': {'S': 'legal'},
#     'historic': {'S': 'not_legal'},
#     'pioneer': {'S': 'not_legal'},
#     'modern': {'S': 'not_legal'},
#     'legacy': {'S': 'not_legal'},
#     'pauper': {'S': 'not_legal'},
#     'vintage': {'S': 'not_legal'},
#     'penny': {'S': 'not_legal'},
#     'commander': {'S': 'not_legal'},
#     'brawl': {'S': 'not_legal'},
#     'duel': {'S': 'not_legal'},
#     'oldschool': {'S': 'not_legal'}}},
#   'games': {'SS': []},
#   'reserved': {'BOOL': True},
#   'foil': {'BOOL': True},
#   'nonfoil': {'BOOL': True},
#   'oversized': {'BOOL': True},
#   'promo': {'BOOL': True},
#   'reprint': {'BOOL': True},
#   'variation': {'BOOL': True},
#   'set': {'S': 'thb'},
#   'set_name': {'S': 'Theros Beyond Death'},
#   'set_type': {'S': 'expansion'},
#   'set_uri': {'S': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913'},
#   'set_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints'},
#   'scryfall_set_uri': {'S': 'https://scryfall.com/sets/thb?utm_source=api'},
#   'rulings_uri': {'S': 'https://api.scryfall.com/cards/bcf6e4d1-1b4f-450c-a0fc-2d02313979ca/rulings'},
#   'prints_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Aee302659-59ed-4eef-babe-451b9ccf7f14&unique=prints'},
#   'collector_number': {'S': '343'},
#   'digital': {'BOOL': True},
#   'rarity': {'S': 'mythic'},
#   'card_back_id': {'S': '0aeebaf5-8c7d-4636-9e82-8c27447861f7'},
#   'artist': {'S': 'Vincent Proce'},
#   'artist_ids': {'SS': ['d82b1138-76d3-49f7-9d8c-bc2e2d3e0b0a']},
#   'illustration_id': {'S': '319b6606-dff4-4e49-a209-550c2aa69fa6'},
#   'border_color': {'S': 'black'},
#   'frame': {'S': '2015'},
#   'frame_effects': {'SS': ['extendedart', 'legendary']},
#   'full_art': {'BOOL': True},
#   'textless': {'BOOL': True},
#   'booster': {'BOOL': True},
#   'story_spotlight': {'BOOL': True},
#   'preview': {'M': {'source': {'S': 'MTGGoldfish'},
#     'source_uri': {'S': 'https://twitter.com/MTGGoldfish/status/1214218500664782849'},
#     'previewed_at': {'S': '2020-01-06'}}},
#   'prices': {'M': {'usd': {'NULL': True},
#     'usd_foil': {'NULL': True},
#     'eur': {'NULL': True},
#     'tix': {'NULL': True}}},
#   'related_uris': {'M': {'tcgplayer_decks': {'S': 'https://decks.tcgplayer.com/magic/deck/search?contains=Uro%2C+Titan+of+Nature%27s+Wrath&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'edhrec': {'S': 'https://edhrec.com/route/?cc=Uro%2C+Titan+of+Nature%27s+Wrath'},
#     'mtgtop8': {'S': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Uro%2C+Titan+of+Nature%27s+Wrath'}}},
#   'purchase_uris': {'M': {'tcgplayer': {'S': 'https://shop.tcgplayer.com/productcatalog/product/show?ProductName=Uro%2C+Titan+of+Nature%27s+Wrath&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'cardmarket': {'S': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Uro%2C+Titan+of+Nature%27s+Wrath&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall'},
#     'cardhoarder': {'S': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Uro%2C+Titan+of+Nature%27s+Wrath&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}},
#   'cardId': {'S': 'bcf6e4d1-1b4f-450c-a0fc-2d02313979ca'}},
#  {'object': {'S': 'card'},
#   'id': {'S': 'a6ee5698-1a40-434c-937b-9462825a752b'},
#   'oracle_id': {'S': 'd297ce39-da98-4351-be9d-24f4d09bee7f'},
#   'multiverse_ids': {'SS': []},
#   'tcgplayer_id': {'N': '206656'},
#   'name': {'S': 'Kunoros, Hound of Athreos'},
#   'lang': {'S': 'en'},
#   'released_at': {'S': '2020-01-24'},
#   'uri': {'S': 'https://api.scryfall.com/cards/a6ee5698-1a40-434c-937b-9462825a752b'},
#   'scryfall_uri': {'S': 'https://scryfall.com/card/thb/341/kunoros-hound-of-athreos?utm_source=api'},
#   'layout': {'S': 'normal'},
#   'highres_image': {'BOOL': True},
#   'image_uris': {'M': {'small': {'S': 'https://img.scryfall.com/cards/small/front/a/6/a6ee5698-1a40-434c-937b-9462825a752b.jpg?1577966489'},
#     'normal': {'S': 'https://img.scryfall.com/cards/normal/front/a/6/a6ee5698-1a40-434c-937b-9462825a752b.jpg?1577966489'},
#     'large': {'S': 'https://img.scryfall.com/cards/large/front/a/6/a6ee5698-1a40-434c-937b-9462825a752b.jpg?1577966489'},
#     'png': {'S': 'https://img.scryfall.com/cards/png/front/a/6/a6ee5698-1a40-434c-937b-9462825a752b.png?1577966489'},
#     'art_crop': {'S': 'https://img.scryfall.com/cards/art_crop/front/a/6/a6ee5698-1a40-434c-937b-9462825a752b.jpg?1577966489'},
#     'border_crop': {'S': 'https://img.scryfall.com/cards/border_crop/front/a/6/a6ee5698-1a40-434c-937b-9462825a752b.jpg?1577966489'}}},
#   'mana_cost': {'S': '{1}{W}{B}'},
#   'cmc': {'N': '3.0'},
#   'type_line': {'S': 'Legendary Creature — Hound'},
#   'oracle_text': {'S': "Vigilance, menace, lifelink\nCreature cards in graveyards can't enter the battlefield.\nPlayers can't cast spells from graveyards."},
#   'power': {'S': '3'},
#   'toughness': {'S': '3'},
#   'colors': {'SS': ['B', 'W']},
#   'color_identity': {'SS': ['B', 'W']},
#   'legalities': {'M': {'standard': {'S': 'not_legal'},
#     'future': {'S': 'legal'},
#     'historic': {'S': 'not_legal'},
#     'pioneer': {'S': 'not_legal'},
#     'modern': {'S': 'not_legal'},
#     'legacy': {'S': 'not_legal'},
#     'pauper': {'S': 'not_legal'},
#     'vintage': {'S': 'not_legal'},
#     'penny': {'S': 'not_legal'},
#     'commander': {'S': 'not_legal'},
#     'brawl': {'S': 'not_legal'},
#     'duel': {'S': 'not_legal'},
#     'oldschool': {'S': 'not_legal'}}},
#   'games': {'SS': []},
#   'reserved': {'BOOL': True},
#   'foil': {'BOOL': True},
#   'nonfoil': {'BOOL': True},
#   'oversized': {'BOOL': True},
#   'promo': {'BOOL': True},
#   'reprint': {'BOOL': True},
#   'variation': {'BOOL': True},
#   'set': {'S': 'thb'},
#   'set_name': {'S': 'Theros Beyond Death'},
#   'set_type': {'S': 'expansion'},
#   'set_uri': {'S': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913'},
#   'set_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints'},
#   'scryfall_set_uri': {'S': 'https://scryfall.com/sets/thb?utm_source=api'},
#   'rulings_uri': {'S': 'https://api.scryfall.com/cards/a6ee5698-1a40-434c-937b-9462825a752b/rulings'},
#   'prints_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Ad297ce39-da98-4351-be9d-24f4d09bee7f&unique=prints'},
#   'collector_number': {'S': '341'},
#   'digital': {'BOOL': True},
#   'rarity': {'S': 'rare'},
#   'card_back_id': {'S': '0aeebaf5-8c7d-4636-9e82-8c27447861f7'},
#   'artist': {'S': 'Zezhou Chen'},
#   'artist_ids': {'SS': ['810677e5-a502-4c03-b726-78cd808a75d4']},
#   'illustration_id': {'S': 'ae469d0e-4249-4502-b391-10f464527708'},
#   'border_color': {'S': 'black'},
#   'frame': {'S': '2015'},
#   'frame_effects': {'SS': ['extendedart', 'legendary']},
#   'full_art': {'BOOL': True},
#   'textless': {'BOOL': True},
#   'booster': {'BOOL': True},
#   'story_spotlight': {'BOOL': True},
#   'edhrec_rank': {'N': '17535'},
#   'preview': {'M': {'source': {'S': 'David Caero'},
#     'source_uri': {'S': 'https://twitter.com/dogdog/status/1211770922383884290'},
#     'previewed_at': {'S': '2019-12-30'}}},
#   'prices': {'M': {'usd': {'S': '2.15'},
#     'usd_foil': {'S': '14.99'},
#     'eur': {'NULL': True},
#     'tix': {'NULL': True}}},
#   'related_uris': {'M': {'tcgplayer_decks': {'S': 'https://decks.tcgplayer.com/magic/deck/search?contains=Kunoros%2C+Hound+of+Athreos&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'edhrec': {'S': 'https://edhrec.com/route/?cc=Kunoros%2C+Hound+of+Athreos'},
#     'mtgtop8': {'S': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Kunoros%2C+Hound+of+Athreos'}}},
#   'purchase_uris': {'M': {'tcgplayer': {'S': 'https://shop.tcgplayer.com/product/productsearch?id=206656&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'cardmarket': {'S': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Kunoros%2C+Hound+of+Athreos&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall'},
#     'cardhoarder': {'S': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Kunoros%2C+Hound+of+Athreos&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}},
#   'cardId': {'S': 'a6ee5698-1a40-434c-937b-9462825a752b'}},
#  {'object': {'S': 'card'},
#   'id': {'S': 'f721cc84-8d76-4c57-b4ba-e384c67aeef7'},
#   'oracle_id': {'S': '43f135b5-d33e-4873-bc5a-8c939582d624'},
#   'multiverse_ids': {'SS': []},
#   'tcgplayer_id': {'N': '206624'},
#   'name': {'S': 'Gallia of the Endless Dance'},
#   'lang': {'S': 'en'},
#   'released_at': {'S': '2020-01-24'},
#   'uri': {'S': 'https://api.scryfall.com/cards/f721cc84-8d76-4c57-b4ba-e384c67aeef7'},
#   'scryfall_uri': {'S': 'https://scryfall.com/card/thb/338/gallia-of-the-endless-dance?utm_source=api'},
#   'layout': {'S': 'normal'},
#   'highres_image': {'BOOL': True},
#   'image_uris': {'M': {'small': {'S': 'https://img.scryfall.com/cards/small/front/f/7/f721cc84-8d76-4c57-b4ba-e384c67aeef7.jpg?1577968561'},
#     'normal': {'S': 'https://img.scryfall.com/cards/normal/front/f/7/f721cc84-8d76-4c57-b4ba-e384c67aeef7.jpg?1577968561'},
#     'large': {'S': 'https://img.scryfall.com/cards/large/front/f/7/f721cc84-8d76-4c57-b4ba-e384c67aeef7.jpg?1577968561'},
#     'png': {'S': 'https://img.scryfall.com/cards/png/front/f/7/f721cc84-8d76-4c57-b4ba-e384c67aeef7.png?1577968561'},
#     'art_crop': {'S': 'https://img.scryfall.com/cards/art_crop/front/f/7/f721cc84-8d76-4c57-b4ba-e384c67aeef7.jpg?1577968561'},
#     'border_crop': {'S': 'https://img.scryfall.com/cards/border_crop/front/f/7/f721cc84-8d76-4c57-b4ba-e384c67aeef7.jpg?1577968561'}}},
#   'mana_cost': {'S': '{R}{G}'},
#   'cmc': {'N': '2.0'},
#   'type_line': {'S': 'Legendary Creature — Satyr'},
#   'oracle_text': {'S': 'Haste\nOther Satyrs you control get +1/+1 and have haste.\nWhenever you attack with three or more creatures, you may discard a card at random. If you do, draw two cards.'},
#   'power': {'S': '2'},
#   'toughness': {'S': '2'},
#   'colors': {'SS': ['G', 'R']},
#   'color_identity': {'SS': ['G', 'R']},
#   'legalities': {'M': {'standard': {'S': 'not_legal'},
#     'future': {'S': 'legal'},
#     'historic': {'S': 'not_legal'},
#     'pioneer': {'S': 'not_legal'},
#     'modern': {'S': 'not_legal'},
#     'legacy': {'S': 'not_legal'},
#     'pauper': {'S': 'not_legal'},
#     'vintage': {'S': 'not_legal'},
#     'penny': {'S': 'not_legal'},
#     'commander': {'S': 'not_legal'},
#     'brawl': {'S': 'not_legal'},
#     'duel': {'S': 'not_legal'},
#     'oldschool': {'S': 'not_legal'}}},
#   'games': {'SS': []},
#   'reserved': {'BOOL': True},
#   'foil': {'BOOL': True},
#   'nonfoil': {'BOOL': True},
#   'oversized': {'BOOL': True},
#   'promo': {'BOOL': True},
#   'reprint': {'BOOL': True},
#   'variation': {'BOOL': True},
#   'set': {'S': 'thb'},
#   'set_name': {'S': 'Theros Beyond Death'},
#   'set_type': {'S': 'expansion'},
#   'set_uri': {'S': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913'},
#   'set_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints'},
#   'scryfall_set_uri': {'S': 'https://scryfall.com/sets/thb?utm_source=api'},
#   'rulings_uri': {'S': 'https://api.scryfall.com/cards/f721cc84-8d76-4c57-b4ba-e384c67aeef7/rulings'},
#   'prints_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A43f135b5-d33e-4873-bc5a-8c939582d624&unique=prints'},
#   'collector_number': {'S': '338'},
#   'digital': {'BOOL': True},
#   'rarity': {'S': 'rare'},
#   'card_back_id': {'S': '0aeebaf5-8c7d-4636-9e82-8c27447861f7'},
#   'artist': {'S': 'Johannes Voss'},
#   'artist_ids': {'SS': ['3593dd7e-c547-4a32-81cd-7da725f60118']},
#   'illustration_id': {'S': '4ba37543-346e-4bae-a218-7c3faa0a4fd1'},
#   'border_color': {'S': 'black'},
#   'frame': {'S': '2015'},
#   'frame_effects': {'SS': ['extendedart', 'legendary']},
#   'full_art': {'BOOL': True},
#   'textless': {'BOOL': True},
#   'booster': {'BOOL': True},
#   'story_spotlight': {'BOOL': True},
#   'edhrec_rank': {'N': '17947'},
#   'preview': {'M': {'source': {'S': 'Wizards of the Coast'},
#     'source_uri': {'S': 'https://magic.wizards.com/en/articles/archive/card-image-gallery/theros-beyond-death-variants'},
#     'previewed_at': {'S': '2020-01-02'}}},
#   'prices': {'M': {'usd': {'S': '1.97'},
#     'usd_foil': {'S': '9.98'},
#     'eur': {'NULL': True},
#     'tix': {'NULL': True}}},
#   'related_uris': {'M': {'tcgplayer_decks': {'S': 'https://decks.tcgplayer.com/magic/deck/search?contains=Gallia+of+the+Endless+Dance&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'edhrec': {'S': 'https://edhrec.com/route/?cc=Gallia+of+the+Endless+Dance'},
#     'mtgtop8': {'S': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Gallia+of+the+Endless+Dance'}}},
#   'purchase_uris': {'M': {'tcgplayer': {'S': 'https://shop.tcgplayer.com/product/productsearch?id=206624&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'cardmarket': {'S': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Gallia+of+the+Endless+Dance&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall'},
#     'cardhoarder': {'S': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Gallia+of+the+Endless+Dance&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}},
#   'cardId': {'S': 'f721cc84-8d76-4c57-b4ba-e384c67aeef7'}},
#  {'object': {'S': 'card'},
#   'id': {'S': '7dadfb33-7082-47b8-a498-f3bb963a8d78'},
#   'oracle_id': {'S': '211814a5-195d-41c6-b96c-4c26b2cbb33c'},
#   'multiverse_ids': {'SS': []},
#   'tcgplayer_id': {'N': '206674'},
#   'name': {'S': 'Dalakos, Crafter of Wonders'},
#   'lang': {'S': 'en'},
#   'released_at': {'S': '2020-01-24'},
#   'uri': {'S': 'https://api.scryfall.com/cards/7dadfb33-7082-47b8-a498-f3bb963a8d78'},
#   'scryfall_uri': {'S': 'https://scryfall.com/card/thb/335/dalakos-crafter-of-wonders?utm_source=api'},
#   'layout': {'S': 'normal'},
#   'highres_image': {'BOOL': True},
#   'image_uris': {'M': {'small': {'S': 'https://img.scryfall.com/cards/small/front/7/d/7dadfb33-7082-47b8-a498-f3bb963a8d78.jpg?1577968558'},
#     'normal': {'S': 'https://img.scryfall.com/cards/normal/front/7/d/7dadfb33-7082-47b8-a498-f3bb963a8d78.jpg?1577968558'},
#     'large': {'S': 'https://img.scryfall.com/cards/large/front/7/d/7dadfb33-7082-47b8-a498-f3bb963a8d78.jpg?1577968558'},
#     'png': {'S': 'https://img.scryfall.com/cards/png/front/7/d/7dadfb33-7082-47b8-a498-f3bb963a8d78.png?1577968558'},
#     'art_crop': {'S': 'https://img.scryfall.com/cards/art_crop/front/7/d/7dadfb33-7082-47b8-a498-f3bb963a8d78.jpg?1577968558'},
#     'border_crop': {'S': 'https://img.scryfall.com/cards/border_crop/front/7/d/7dadfb33-7082-47b8-a498-f3bb963a8d78.jpg?1577968558'}}},
#   'mana_cost': {'S': '{1}{U}{R}'},
#   'cmc': {'N': '3.0'},
#   'type_line': {'S': 'Legendary Creature — Merfolk Artificer'},
#   'oracle_text': {'S': '{T}: Add {C}{C}. Spend this mana only to cast artifact spells or activate abilities of artifacts.\nEquipped creatures you control have flying and haste.'},
#   'power': {'S': '2'},
#   'toughness': {'S': '4'},
#   'colors': {'SS': ['R', 'U']},
#   'color_identity': {'SS': ['R', 'U']},
#   'legalities': {'M': {'standard': {'S': 'not_legal'},
#     'future': {'S': 'legal'},
#     'historic': {'S': 'not_legal'},
#     'pioneer': {'S': 'not_legal'},
#     'modern': {'S': 'not_legal'},
#     'legacy': {'S': 'not_legal'},
#     'pauper': {'S': 'not_legal'},
#     'vintage': {'S': 'not_legal'},
#     'penny': {'S': 'not_legal'},
#     'commander': {'S': 'not_legal'},
#     'brawl': {'S': 'not_legal'},
#     'duel': {'S': 'not_legal'},
#     'oldschool': {'S': 'not_legal'}}},
#   'games': {'SS': []},
#   'reserved': {'BOOL': True},
#   'foil': {'BOOL': True},
#   'nonfoil': {'BOOL': True},
#   'oversized': {'BOOL': True},
#   'promo': {'BOOL': True},
#   'reprint': {'BOOL': True},
#   'variation': {'BOOL': True},
#   'set': {'S': 'thb'},
#   'set_name': {'S': 'Theros Beyond Death'},
#   'set_type': {'S': 'expansion'},
#   'set_uri': {'S': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913'},
# ...
#     'usd_foil': {'NULL': True},
#     'eur': {'NULL': True},
#     'tix': {'NULL': True}}},
#   'related_uris': {'M': {'tcgplayer_decks': {'S': 'https://decks.tcgplayer.com/magic/deck/search?contains=Treacherous+Blessing&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'edhrec': {'S': 'https://edhrec.com/route/?cc=Treacherous+Blessing'},
#     'mtgtop8': {'S': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Treacherous+Blessing'}}},
#   'purchase_uris': {'M': {'tcgplayer': {'S': 'https://shop.tcgplayer.com/product/productsearch?id=206658&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'cardmarket': {'S': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Treacherous+Blessing&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall'},
#     'cardhoarder': {'S': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Treacherous+Blessing&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}},
#   'cardId': {'S': '7cde9bcb-1c60-4f3f-af07-7db3f8baf1cc'}},
#  {'object': {'S': 'card'},
#   'id': {'S': 'a7f0dd24-d28c-4f94-8131-3061a1b92e93'},
#   'oracle_id': {'S': '820dab0f-3b6b-437c-ba4b-2311437709c3'},
#   'multiverse_ids': {'SS': []},
#   'tcgplayer_id': {'N': '206700'},
#   'name': {'S': 'Aphemia, the Cacophony'},
#   'lang': {'S': 'en'},
#   'released_at': {'S': '2020-01-24'},
#   'uri': {'S': 'https://api.scryfall.com/cards/a7f0dd24-d28c-4f94-8131-3061a1b92e93'},
#   'scryfall_uri': {'S': 'https://scryfall.com/card/thb/311/aphemia-the-cacophony?utm_source=api'},
#   'layout': {'S': 'normal'},
#   'highres_image': {'BOOL': True},
#   'image_uris': {'M': {'small': {'S': 'https://img.scryfall.com/cards/small/front/a/7/a7f0dd24-d28c-4f94-8131-3061a1b92e93.jpg?1577968544'},
#     'normal': {'S': 'https://img.scryfall.com/cards/normal/front/a/7/a7f0dd24-d28c-4f94-8131-3061a1b92e93.jpg?1577968544'},
#     'large': {'S': 'https://img.scryfall.com/cards/large/front/a/7/a7f0dd24-d28c-4f94-8131-3061a1b92e93.jpg?1577968544'},
#     'png': {'S': 'https://img.scryfall.com/cards/png/front/a/7/a7f0dd24-d28c-4f94-8131-3061a1b92e93.png?1577968544'},
#     'art_crop': {'S': 'https://img.scryfall.com/cards/art_crop/front/a/7/a7f0dd24-d28c-4f94-8131-3061a1b92e93.jpg?1577968544'},
#     'border_crop': {'S': 'https://img.scryfall.com/cards/border_crop/front/a/7/a7f0dd24-d28c-4f94-8131-3061a1b92e93.jpg?1577968544'}}},
#   'mana_cost': {'S': '{1}{B}'},
#   'cmc': {'N': '2.0'},
#   'type_line': {'S': 'Legendary Enchantment Creature — Harpy'},
#   'oracle_text': {'S': 'Flying\nAt the beginning of your end step, you may exile an enchantment card from your graveyard. If you do, create a 2/2 black Zombie creature token.'},
#   'power': {'S': '2'},
#   'toughness': {'S': '1'},
#   'colors': {'SS': ['B']},
#   'color_identity': {'SS': ['B']},
#   'legalities': {'M': {'standard': {'S': 'not_legal'},
#     'future': {'S': 'legal'},
#     'historic': {'S': 'not_legal'},
#     'pioneer': {'S': 'not_legal'},
#     'modern': {'S': 'not_legal'},
#     'legacy': {'S': 'not_legal'},
#     'pauper': {'S': 'not_legal'},
#     'vintage': {'S': 'not_legal'},
#     'penny': {'S': 'not_legal'},
#     'commander': {'S': 'not_legal'},
#     'brawl': {'S': 'not_legal'},
#     'duel': {'S': 'not_legal'},
#     'oldschool': {'S': 'not_legal'}}},
#   'games': {'SS': []},
#   'reserved': {'BOOL': True},
#   'foil': {'BOOL': True},
#   'nonfoil': {'BOOL': True},
#   'oversized': {'BOOL': True},
#   'promo': {'BOOL': True},
#   'reprint': {'BOOL': True},
#   'variation': {'BOOL': True},
#   'set': {'S': 'thb'},
#   'set_name': {'S': 'Theros Beyond Death'},
#   'set_type': {'S': 'expansion'},
#   'set_uri': {'S': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913'},
#   'set_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints'},
#   'scryfall_set_uri': {'S': 'https://scryfall.com/sets/thb?utm_source=api'},
#   'rulings_uri': {'S': 'https://api.scryfall.com/cards/a7f0dd24-d28c-4f94-8131-3061a1b92e93/rulings'},
#   'prints_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A820dab0f-3b6b-437c-ba4b-2311437709c3&unique=prints'},
#   'collector_number': {'S': '311'},
#   'digital': {'BOOL': True},
#   'rarity': {'S': 'rare'},
#   'flavor_text': {'S': '"Sing, beauty. Sing for death, and for the dead." —Ashiok'},
#   'card_back_id': {'S': '0aeebaf5-8c7d-4636-9e82-8c27447861f7'},
#   'artist': {'S': 'Lucas Graciano'},
#   'artist_ids': {'SS': ['ce98f39c-7cdd-47e6-a520-6c50443bb4c2']},
#   'illustration_id': {'S': '6fe63701-af1f-4a77-a95b-358eb3d9a1fc'},
#   'border_color': {'S': 'black'},
#   'frame': {'S': '2015'},
#   'frame_effects': {'SS': ['extendedart', 'legendary', 'nyxtouched']},
#   'full_art': {'BOOL': True},
#   'textless': {'BOOL': True},
#   'booster': {'BOOL': True},
#   'story_spotlight': {'BOOL': True},
#   'preview': {'M': {'source': {'S': 'Wizards of the Coast'},
#     'source_uri': {'S': 'https://magic.wizards.com/en/articles/archive/card-image-gallery/theros-beyond-death-variants'},
#     'previewed_at': {'S': '2020-01-02'}}},
#   'prices': {'M': {'usd': {'S': '0.92'},
#     'usd_foil': {'NULL': True},
#     'eur': {'NULL': True},
#     'tix': {'NULL': True}}},
#   'related_uris': {'M': {'tcgplayer_decks': {'S': 'https://decks.tcgplayer.com/magic/deck/search?contains=Aphemia%2C+the+Cacophony&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'edhrec': {'S': 'https://edhrec.com/route/?cc=Aphemia%2C+the+Cacophony'},
#     'mtgtop8': {'S': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Aphemia%2C+the+Cacophony'}}},
#   'purchase_uris': {'M': {'tcgplayer': {'S': 'https://shop.tcgplayer.com/product/productsearch?id=206700&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'cardmarket': {'S': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Aphemia%2C+the+Cacophony&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall'},
#     'cardhoarder': {'S': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Aphemia%2C+the+Cacophony&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}},
#   'cardId': {'S': 'a7f0dd24-d28c-4f94-8131-3061a1b92e93'}},
#  {'object': {'S': 'card'},
#   'id': {'S': '3044489e-84e0-453e-9248-a200d27ad17c'},
#   'oracle_id': {'S': '20004398-bd04-4583-8378-9df743246a32'},
#   'multiverse_ids': {'SS': []},
#   'name': {'S': 'Thryx, the Sudden Storm'},
#   'lang': {'S': 'en'},
#   'released_at': {'S': '2020-01-24'},
#   'uri': {'S': 'https://api.scryfall.com/cards/3044489e-84e0-453e-9248-a200d27ad17c'},
#   'scryfall_uri': {'S': 'https://scryfall.com/card/thb/309/thryx-the-sudden-storm?utm_source=api'},
#   'layout': {'S': 'normal'},
#   'highres_image': {'BOOL': True},
#   'image_uris': {'M': {'small': {'S': 'https://img.scryfall.com/cards/small/front/3/0/3044489e-84e0-453e-9248-a200d27ad17c.jpg?1578315895'},
#     'normal': {'S': 'https://img.scryfall.com/cards/normal/front/3/0/3044489e-84e0-453e-9248-a200d27ad17c.jpg?1578315895'},
#     'large': {'S': 'https://img.scryfall.com/cards/large/front/3/0/3044489e-84e0-453e-9248-a200d27ad17c.jpg?1578315895'},
#     'png': {'S': 'https://img.scryfall.com/cards/png/front/3/0/3044489e-84e0-453e-9248-a200d27ad17c.png?1578315895'},
#     'art_crop': {'S': 'https://img.scryfall.com/cards/art_crop/front/3/0/3044489e-84e0-453e-9248-a200d27ad17c.jpg?1578315895'},
#     'border_crop': {'S': 'https://img.scryfall.com/cards/border_crop/front/3/0/3044489e-84e0-453e-9248-a200d27ad17c.jpg?1578315895'}}},
#   'mana_cost': {'S': '{3}{U}{U}'},
#   'cmc': {'N': '5.0'},
#   'type_line': {'S': 'Legendary Creature — Elemental Giant'},
#   'oracle_text': {'S': "Flash\nFlying\nSpells you cast with converted mana cost 5 or greater cost {1} less to cast and can't be countered."},
#   'power': {'S': '4'},
#   'toughness': {'S': '5'},
#   'colors': {'SS': ['U']},
#   'color_identity': {'SS': ['U']},
#   'legalities': {'M': {'standard': {'S': 'not_legal'},
#     'future': {'S': 'legal'},
#     'historic': {'S': 'not_legal'},
#     'pioneer': {'S': 'not_legal'},
#     'modern': {'S': 'not_legal'},
#     'legacy': {'S': 'not_legal'},
#     'pauper': {'S': 'not_legal'},
#     'vintage': {'S': 'not_legal'},
#     'penny': {'S': 'not_legal'},
#     'commander': {'S': 'not_legal'},
#     'brawl': {'S': 'not_legal'},
#     'duel': {'S': 'not_legal'},
#     'oldschool': {'S': 'not_legal'}}},
#   'games': {'SS': []},
#   'reserved': {'BOOL': True},
#   'foil': {'BOOL': True},
#   'nonfoil': {'BOOL': True},
#   'oversized': {'BOOL': True},
#   'promo': {'BOOL': True},
#   'reprint': {'BOOL': True},
#   'variation': {'BOOL': True},
#   'set': {'S': 'thb'},
#   'set_name': {'S': 'Theros Beyond Death'},
#   'set_type': {'S': 'expansion'},
#   'set_uri': {'S': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913'},
#   'set_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints'},
#   'scryfall_set_uri': {'S': 'https://scryfall.com/sets/thb?utm_source=api'},
#   'rulings_uri': {'S': 'https://api.scryfall.com/cards/3044489e-84e0-453e-9248-a200d27ad17c/rulings'},
#   'prints_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A20004398-bd04-4583-8378-9df743246a32&unique=prints'},
#   'collector_number': {'S': '309'},
#   'digital': {'BOOL': True},
#   'rarity': {'S': 'rare'},
#   'card_back_id': {'S': '0aeebaf5-8c7d-4636-9e82-8c27447861f7'},
#   'artist': {'S': 'Mathias Kollros'},
#   'artist_ids': {'SS': ['2ae0dd12-047c-4efb-80d7-bccc3bac5fba']},
#   'illustration_id': {'S': 'a74932b7-6de8-4c39-8b4a-91867894bc75'},
#   'border_color': {'S': 'black'},
#   'frame': {'S': '2015'},
#   'frame_effects': {'SS': ['extendedart', 'legendary']},
#   'full_art': {'BOOL': True},
#   'textless': {'BOOL': True},
#   'booster': {'BOOL': True},
#   'story_spotlight': {'BOOL': True},
#   'prices': {'M': {'usd': {'NULL': True},
#     'usd_foil': {'NULL': True},
#     'eur': {'NULL': True},
#     'tix': {'NULL': True}}},
#   'related_uris': {'M': {'tcgplayer_decks': {'S': 'https://decks.tcgplayer.com/magic/deck/search?contains=Thryx%2C+the+Sudden+Storm&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'edhrec': {'S': 'https://edhrec.com/route/?cc=Thryx%2C+the+Sudden+Storm'},
#     'mtgtop8': {'S': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Thryx%2C+the+Sudden+Storm'}}},
#   'purchase_uris': {'M': {'tcgplayer': {'S': 'https://shop.tcgplayer.com/productcatalog/product/show?ProductName=Thryx%2C+the+Sudden+Storm&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'cardmarket': {'S': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Thryx%2C+the+Sudden+Storm&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall'},
#     'cardhoarder': {'S': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Thryx%2C+the+Sudden+Storm&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}},
#   'cardId': {'S': '3044489e-84e0-453e-9248-a200d27ad17c'}},
#  {'object': {'S': 'card'},
#   'id': {'S': 'f0c5d004-78bd-4564-9f4a-fcf463f3a76a'},
#   'oracle_id': {'S': '5a73d439-bd78-42e1-90ae-eedd30536881'},
#   'multiverse_ids': {'SS': []},
#   'tcgplayer_id': {'N': '206660'},
#   'name': {'S': 'Nadir Kraken'},
#   'lang': {'S': 'en'},
#   'released_at': {'S': '2020-01-24'},
#   'uri': {'S': 'https://api.scryfall.com/cards/f0c5d004-78bd-4564-9f4a-fcf463f3a76a'},
#   'scryfall_uri': {'S': 'https://scryfall.com/card/thb/305/nadir-kraken?utm_source=api'},
#   'layout': {'S': 'normal'},
#   'highres_image': {'BOOL': True},
#   'image_uris': {'M': {'small': {'S': 'https://img.scryfall.com/cards/small/front/f/0/f0c5d004-78bd-4564-9f4a-fcf463f3a76a.jpg?1577830947'},
#     'normal': {'S': 'https://img.scryfall.com/cards/normal/front/f/0/f0c5d004-78bd-4564-9f4a-fcf463f3a76a.jpg?1577830947'},
#     'large': {'S': 'https://img.scryfall.com/cards/large/front/f/0/f0c5d004-78bd-4564-9f4a-fcf463f3a76a.jpg?1577830947'},
#     'png': {'S': 'https://img.scryfall.com/cards/png/front/f/0/f0c5d004-78bd-4564-9f4a-fcf463f3a76a.png?1577830947'},
#     'art_crop': {'S': 'https://img.scryfall.com/cards/art_crop/front/f/0/f0c5d004-78bd-4564-9f4a-fcf463f3a76a.jpg?1577830947'},
#     'border_crop': {'S': 'https://img.scryfall.com/cards/border_crop/front/f/0/f0c5d004-78bd-4564-9f4a-fcf463f3a76a.jpg?1577830947'}}},
#   'mana_cost': {'S': '{1}{U}{U}'},
#   'cmc': {'N': '3.0'},
#   'type_line': {'S': 'Creature — Kraken'},
#   'oracle_text': {'S': 'Whenever you draw a card, you may pay {1}. If you do, put a +1/+1 counter on Nadir Kraken and create a 1/1 blue Tentacle creature token.'},
#   'power': {'S': '2'},
#   'toughness': {'S': '3'},
#   'colors': {'SS': ['U']},
#   'color_identity': {'SS': ['U']},
#   'legalities': {'M': {'standard': {'S': 'not_legal'},
#     'future': {'S': 'legal'},
#     'historic': {'S': 'not_legal'},
#     'pioneer': {'S': 'not_legal'},
#     'modern': {'S': 'not_legal'},
#     'legacy': {'S': 'not_legal'},
#     'pauper': {'S': 'not_legal'},
#     'vintage': {'S': 'not_legal'},
#     'penny': {'S': 'not_legal'},
#     'commander': {'S': 'not_legal'},
#     'brawl': {'S': 'not_legal'},
#     'duel': {'S': 'not_legal'},
#     'oldschool': {'S': 'not_legal'}}},
#   'games': {'SS': []},
#   'reserved': {'BOOL': True},
#   'foil': {'BOOL': True},
#   'nonfoil': {'BOOL': True},
#   'oversized': {'BOOL': True},
#   'promo': {'BOOL': True},
#   'reprint': {'BOOL': True},
#   'variation': {'BOOL': True},
#   'set': {'S': 'thb'},
#   'set_name': {'S': 'Theros Beyond Death'},
#   'set_type': {'S': 'expansion'},
#   'set_uri': {'S': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913'},
#   'set_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints'},
#   'scryfall_set_uri': {'S': 'https://scryfall.com/sets/thb?utm_source=api'},
#   'rulings_uri': {'S': 'https://api.scryfall.com/cards/f0c5d004-78bd-4564-9f4a-fcf463f3a76a/rulings'},
#   'prints_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A5a73d439-bd78-42e1-90ae-eedd30536881&unique=prints'},
#   'collector_number': {'S': '305'},
#   'digital': {'BOOL': True},
#   'rarity': {'S': 'rare'},
#   'card_back_id': {'S': '0aeebaf5-8c7d-4636-9e82-8c27447861f7'},
#   'artist': {'S': 'Dan Scott'},
#   'artist_ids': {'SS': ['f852fa13-137e-40f2-bbc1-0f01df09c0e0']},
#   'illustration_id': {'S': '81fb0188-5040-4d80-a8e7-0c733c4d0d09'},
#   'border_color': {'S': 'black'},
#   'frame': {'S': '2015'},
#   'frame_effects': {'SS': ['extendedart']},
#   'full_art': {'BOOL': True},
#   'textless': {'BOOL': True},
#   'booster': {'BOOL': True},
#   'story_spotlight': {'BOOL': True},
#   'edhrec_rank': {'N': '18722'},
#   'preview': {'M': {'source': {'S': 'TheAsianAvenger'},
#     'source_uri': {'S': 'https://twitter.com/Theasianavenger/status/1211868569719336960'},
#     'previewed_at': {'S': '2019-12-31'}}},
#   'prices': {'M': {'usd': {'S': '2.14'},
#     'usd_foil': {'NULL': True},
#     'eur': {'NULL': True},
#     'tix': {'NULL': True}}},
#   'related_uris': {'M': {'tcgplayer_decks': {'S': 'https://decks.tcgplayer.com/magic/deck/search?contains=Nadir+Kraken&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'edhrec': {'S': 'https://edhrec.com/route/?cc=Nadir+Kraken'},
#     'mtgtop8': {'S': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Nadir+Kraken'}}},
#   'purchase_uris': {'M': {'tcgplayer': {'S': 'https://shop.tcgplayer.com/product/productsearch?id=206660&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#     'cardmarket': {'S': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Nadir+Kraken&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall'},
#     'cardhoarder': {'S': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Nadir+Kraken&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}},
#   'cardId': {'S': 'f0c5d004-78bd-4564-9f4a-fcf463f3a76a'}}]

# %%
def save_scryfall_page(table, page):
    dynamo_batches = [(first, first+BATCH_LIMIT) for first in list(range(0, CARDS_PER_PAGE, BATCH_LIMIT))]

    res = requests.get(CARDS_URL.format(page))
    for batch in dynamo_batch:
        cards = res.json()['data'][batch[0]:batch[1]]
        # Save to Dynamo
        RequestItems = {
            table: [
                {
                    'PutRequest': {
                        'Item': card
                    }
                } for card in cards
            ]
        }
        return RequestItems
        #_ = dynamodb_lib.call(table, 'batch_write_item', RequestItems)

# %%
items = save_scryfall_page(table, 1)

# %%
items['global-cards-table']
# Out:
# [{'PutRequest': {'Item': {'object': 'card',
#     'id': '61dc9a80-850c-4945-b84a-85381cc3ee85',
#     'oracle_id': 'e521322b-0e83-458c-8936-7021a80ee279',
#     'multiverse_ids': [],
#     'tcgplayer_id': 206636,
#     'name': 'Temple of Plenty',
#     'lang': 'en',
#     'released_at': '2020-01-24',
#     'uri': 'https://api.scryfall.com/cards/61dc9a80-850c-4945-b84a-85381cc3ee85',
#     'scryfall_uri': 'https://scryfall.com/card/thb/351/temple-of-plenty?utm_source=api',
#     'layout': 'normal',
#     'highres_image': False,
#     'image_uris': {'small': 'https://img.scryfall.com/cards/small/front/6/1/61dc9a80-850c-4945-b84a-85381cc3ee85.jpg?1577717404',
#      'normal': 'https://img.scryfall.com/cards/normal/front/6/1/61dc9a80-850c-4945-b84a-85381cc3ee85.jpg?1577717404',
#      'large': 'https://img.scryfall.com/cards/large/front/6/1/61dc9a80-850c-4945-b84a-85381cc3ee85.jpg?1577717404',
#      'png': 'https://img.scryfall.com/cards/png/front/6/1/61dc9a80-850c-4945-b84a-85381cc3ee85.png?1577717404',
#      'art_crop': 'https://img.scryfall.com/cards/art_crop/front/6/1/61dc9a80-850c-4945-b84a-85381cc3ee85.jpg?1577717404',
#      'border_crop': 'https://img.scryfall.com/cards/border_crop/front/6/1/61dc9a80-850c-4945-b84a-85381cc3ee85.jpg?1577717404'},
#     'mana_cost': '',
#     'cmc': 0.0,
#     'type_line': 'Land',
#     'oracle_text': 'Temple of Plenty enters the battlefield tapped.\nWhen Temple of Plenty enters the battlefield, scry 1. (Look at the top card of your library. You may put that card on the bottom of your library.)\n{T}: Add {G} or {W}.',
#     'colors': [],
#     'color_identity': ['G', 'W'],
#     'legalities': {'standard': 'not_legal',
#      'future': 'legal',
#      'historic': 'not_legal',
#      'pioneer': 'legal',
#      'modern': 'legal',
#      'legacy': 'legal',
#      'pauper': 'not_legal',
#      'vintage': 'legal',
#      'penny': 'not_legal',
#      'commander': 'legal',
#      'brawl': 'not_legal',
#      'duel': 'legal',
#      'oldschool': 'not_legal'},
#     'games': [],
#     'reserved': False,
#     'foil': True,
#     'nonfoil': True,
#     'oversized': False,
#     'promo': True,
#     'reprint': True,
#     'variation': False,
#     'set': 'thb',
#     'set_name': 'Theros Beyond Death',
#     'set_type': 'expansion',
#     'set_uri': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913',
#     'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints',
#     'scryfall_set_uri': 'https://scryfall.com/sets/thb?utm_source=api',
#     'rulings_uri': 'https://api.scryfall.com/cards/61dc9a80-850c-4945-b84a-85381cc3ee85/rulings',
#     'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Ae521322b-0e83-458c-8936-7021a80ee279&unique=prints',
#     'collector_number': '351',
#     'digital': False,
#     'rarity': 'rare',
#     'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#     'artist': 'Chris Ostrowski',
#     'artist_ids': ['b5f1bd34-abee-40c9-99f7-a6ee089fb30b'],
#     'illustration_id': '846b14b7-34e8-4f0c-86bb-8bf5dc45bd00',
#     'border_color': 'black',
#     'frame': '2015',
#     'frame_effects': ['extendedart'],
#     'full_art': False,
#     'textless': False,
#     'booster': False,
#     'story_spotlight': False,
#     'edhrec_rank': 394,
#     'preview': {'source': 'ChannelFireball',
#      'source_uri': 'https://www.channelfireball.com/all-strategy/articles/3-point/theros-beyond-death-exclusive-preview/',
#      'previewed_at': '2019-12-30'},
#     'prices': {'usd': '1.26', 'usd_foil': None, 'eur': None, 'tix': None},
#     'related_uris': {'tcgplayer_decks': 'https://decks.tcgplayer.com/magic/deck/search?contains=Temple+of+Plenty&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'edhrec': 'https://edhrec.com/route/?cc=Temple+of+Plenty',
#      'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Temple+of+Plenty'},
#     'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=206636&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Temple+of+Plenty&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#      'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Temple+of+Plenty&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}}},
#  {'PutRequest': {'Item': {'object': 'card',
#     'id': 'c7f80f4d-0858-46ff-9305-ee6e380eb521',
#     'oracle_id': '7c439c18-31dc-41fe-b03d-3fca06e6fc0b',
#     'multiverse_ids': [],
#     'tcgplayer_id': 206635,
#     'name': 'Temple of Malice',
#     'lang': 'en',
#     'released_at': '2020-01-24',
#     'uri': 'https://api.scryfall.com/cards/c7f80f4d-0858-46ff-9305-ee6e380eb521',
#     'scryfall_uri': 'https://scryfall.com/card/thb/350/temple-of-malice?utm_source=api',
#     'layout': 'normal',
#     'highres_image': False,
#     'image_uris': {'small': 'https://img.scryfall.com/cards/small/front/c/7/c7f80f4d-0858-46ff-9305-ee6e380eb521.jpg?1577717143',
#      'normal': 'https://img.scryfall.com/cards/normal/front/c/7/c7f80f4d-0858-46ff-9305-ee6e380eb521.jpg?1577717143',
#      'large': 'https://img.scryfall.com/cards/large/front/c/7/c7f80f4d-0858-46ff-9305-ee6e380eb521.jpg?1577717143',
#      'png': 'https://img.scryfall.com/cards/png/front/c/7/c7f80f4d-0858-46ff-9305-ee6e380eb521.png?1577717143',
#      'art_crop': 'https://img.scryfall.com/cards/art_crop/front/c/7/c7f80f4d-0858-46ff-9305-ee6e380eb521.jpg?1577717143',
#      'border_crop': 'https://img.scryfall.com/cards/border_crop/front/c/7/c7f80f4d-0858-46ff-9305-ee6e380eb521.jpg?1577717143'},
#     'mana_cost': '',
#     'cmc': 0.0,
#     'type_line': 'Land',
#     'oracle_text': 'Temple of Malice enters the battlefield tapped.\nWhen Temple of Malice enters the battlefield, scry 1. (Look at the top card of your library. You may put that card on the bottom of your library.)\n{T}: Add {B} or {R}.',
#     'colors': [],
#     'color_identity': ['B', 'R'],
#     'legalities': {'standard': 'not_legal',
#      'future': 'legal',
#      'historic': 'not_legal',
#      'pioneer': 'legal',
#      'modern': 'legal',
#      'legacy': 'legal',
#      'pauper': 'not_legal',
#      'vintage': 'legal',
#      'penny': 'not_legal',
#      'commander': 'legal',
#      'brawl': 'not_legal',
#      'duel': 'legal',
#      'oldschool': 'not_legal'},
#     'games': [],
#     'reserved': False,
#     'foil': True,
#     'nonfoil': True,
#     'oversized': False,
#     'promo': True,
#     'reprint': True,
#     'variation': False,
#     'set': 'thb',
#     'set_name': 'Theros Beyond Death',
#     'set_type': 'expansion',
#     'set_uri': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913',
#     'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints',
#     'scryfall_set_uri': 'https://scryfall.com/sets/thb?utm_source=api',
#     'rulings_uri': 'https://api.scryfall.com/cards/c7f80f4d-0858-46ff-9305-ee6e380eb521/rulings',
#     'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A7c439c18-31dc-41fe-b03d-3fca06e6fc0b&unique=prints',
#     'collector_number': '350',
#     'digital': False,
#     'rarity': 'rare',
#     'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#     'artist': 'Jonas De Ro',
#     'artist_ids': ['561ebf9e-8d93-4b57-8156-8826d0c19601'],
#     'illustration_id': '28247dd9-4241-4f06-b6b3-6552fc45561e',
#     'border_color': 'black',
#     'frame': '2015',
#     'frame_effects': ['extendedart'],
#     'full_art': False,
#     'textless': False,
#     'booster': False,
#     'story_spotlight': False,
#     'edhrec_rank': 411,
#     'preview': {'source': 'ChannelFireball',
#      'source_uri': 'https://www.channelfireball.com/all-strategy/articles/3-point/theros-beyond-death-exclusive-preview/',
#      'previewed_at': '2019-12-30'},
#     'prices': {'usd': '1.40', 'usd_foil': None, 'eur': None, 'tix': None},
#     'related_uris': {'tcgplayer_decks': 'https://decks.tcgplayer.com/magic/deck/search?contains=Temple+of+Malice&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'edhrec': 'https://edhrec.com/route/?cc=Temple+of+Malice',
#      'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Temple+of+Malice'},
#     'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=206635&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Temple+of+Malice&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#      'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Temple+of+Malice&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}}},
#  {'PutRequest': {'Item': {'object': 'card',
#     'id': '7b705a44-b1b6-491b-aaab-53e0577fdde3',
#     'oracle_id': '89f43e27-790b-4ca1-8ba7-0882b31e0783',
#     'multiverse_ids': [],
#     'tcgplayer_id': 206634,
#     'name': 'Temple of Enlightenment',
#     'lang': 'en',
#     'released_at': '2020-01-24',
#     'uri': 'https://api.scryfall.com/cards/7b705a44-b1b6-491b-aaab-53e0577fdde3',
#     'scryfall_uri': 'https://scryfall.com/card/thb/349/temple-of-enlightenment?utm_source=api',
#     'layout': 'normal',
#     'highres_image': False,
#     'image_uris': {'small': 'https://img.scryfall.com/cards/small/front/7/b/7b705a44-b1b6-491b-aaab-53e0577fdde3.jpg?1577716937',
#      'normal': 'https://img.scryfall.com/cards/normal/front/7/b/7b705a44-b1b6-491b-aaab-53e0577fdde3.jpg?1577716937',
#      'large': 'https://img.scryfall.com/cards/large/front/7/b/7b705a44-b1b6-491b-aaab-53e0577fdde3.jpg?1577716937',
#      'png': 'https://img.scryfall.com/cards/png/front/7/b/7b705a44-b1b6-491b-aaab-53e0577fdde3.png?1577716937',
#      'art_crop': 'https://img.scryfall.com/cards/art_crop/front/7/b/7b705a44-b1b6-491b-aaab-53e0577fdde3.jpg?1577716937',
#      'border_crop': 'https://img.scryfall.com/cards/border_crop/front/7/b/7b705a44-b1b6-491b-aaab-53e0577fdde3.jpg?1577716937'},
#     'mana_cost': '',
#     'cmc': 0.0,
#     'type_line': 'Land',
#     'oracle_text': 'Temple of Enlightenment enters the battlefield tapped.\nWhen Temple of Enlightenment enters the battlefield, scry 1. (Look at the top card of your library. You may put that card on the bottom of your library.)\n{T}: Add {W} or {U}.',
#     'colors': [],
#     'color_identity': ['U', 'W'],
#     'legalities': {'standard': 'not_legal',
#      'future': 'legal',
#      'historic': 'not_legal',
#      'pioneer': 'legal',
#      'modern': 'legal',
#      'legacy': 'legal',
#      'pauper': 'not_legal',
#      'vintage': 'legal',
#      'penny': 'not_legal',
#      'commander': 'legal',
#      'brawl': 'not_legal',
#      'duel': 'legal',
#      'oldschool': 'not_legal'},
#     'games': [],
#     'reserved': False,
#     'foil': True,
#     'nonfoil': True,
#     'oversized': False,
#     'promo': True,
#     'reprint': True,
#     'variation': False,
#     'set': 'thb',
#     'set_name': 'Theros Beyond Death',
#     'set_type': 'expansion',
#     'set_uri': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913',
#     'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints',
#     'scryfall_set_uri': 'https://scryfall.com/sets/thb?utm_source=api',
#     'rulings_uri': 'https://api.scryfall.com/cards/7b705a44-b1b6-491b-aaab-53e0577fdde3/rulings',
#     'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A89f43e27-790b-4ca1-8ba7-0882b31e0783&unique=prints',
#     'collector_number': '349',
#     'digital': False,
#     'rarity': 'rare',
#     'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#     'artist': 'Piotr Dura',
#     'artist_ids': ['aff176e8-1d15-432e-ad1d-207a474decba'],
#     'illustration_id': 'ccd5a446-1ef3-40ba-a596-68578dd6f35c',
#     'border_color': 'black',
#     'frame': '2015',
#     'frame_effects': ['extendedart'],
#     'full_art': False,
#     'textless': False,
#     'booster': False,
#     'story_spotlight': False,
#     'edhrec_rank': 337,
#     'preview': {'source': 'ChannelFireball',
#      'source_uri': 'https://www.channelfireball.com/all-strategy/articles/3-point/theros-beyond-death-exclusive-preview/',
#      'previewed_at': '2019-12-30'},
#     'prices': {'usd': '1.21', 'usd_foil': None, 'eur': None, 'tix': None},
#     'related_uris': {'tcgplayer_decks': 'https://decks.tcgplayer.com/magic/deck/search?contains=Temple+of+Enlightenment&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'edhrec': 'https://edhrec.com/route/?cc=Temple+of+Enlightenment',
#      'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Temple+of+Enlightenment'},
#     'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=206634&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Temple+of+Enlightenment&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#      'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Temple+of+Enlightenment&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}}},
#  {'PutRequest': {'Item': {'object': 'card',
#     'id': '80c6be18-356e-4e8b-899c-4a82f5d41a41',
#     'oracle_id': '33b9b3bd-33ca-46f3-b8bb-a978bc3d1085',
#     'multiverse_ids': [],
#     'tcgplayer_id': 206633,
#     'name': 'Temple of Deceit',
#     'lang': 'en',
#     'released_at': '2020-01-24',
#     'uri': 'https://api.scryfall.com/cards/80c6be18-356e-4e8b-899c-4a82f5d41a41',
#     'scryfall_uri': 'https://scryfall.com/card/thb/348/temple-of-deceit?utm_source=api',
#     'layout': 'normal',
#     'highres_image': False,
#     'image_uris': {'small': 'https://img.scryfall.com/cards/small/front/8/0/80c6be18-356e-4e8b-899c-4a82f5d41a41.jpg?1577905582',
#      'normal': 'https://img.scryfall.com/cards/normal/front/8/0/80c6be18-356e-4e8b-899c-4a82f5d41a41.jpg?1577905582',
#      'large': 'https://img.scryfall.com/cards/large/front/8/0/80c6be18-356e-4e8b-899c-4a82f5d41a41.jpg?1577905582',
#      'png': 'https://img.scryfall.com/cards/png/front/8/0/80c6be18-356e-4e8b-899c-4a82f5d41a41.png?1577905582',
#      'art_crop': 'https://img.scryfall.com/cards/art_crop/front/8/0/80c6be18-356e-4e8b-899c-4a82f5d41a41.jpg?1577905582',
#      'border_crop': 'https://img.scryfall.com/cards/border_crop/front/8/0/80c6be18-356e-4e8b-899c-4a82f5d41a41.jpg?1577905582'},
#     'mana_cost': '',
#     'cmc': 0.0,
#     'type_line': 'Land',
#     'oracle_text': 'Temple of Deceit enters the battlefield tapped.\nWhen Temple of Deceit enters the battlefield, scry 1. (Look at the top card of your library. You may put that card on the bottom of your library.)\n{T}: Add {U} or {B}.',
#     'colors': [],
#     'color_identity': ['B', 'U'],
#     'legalities': {'standard': 'not_legal',
#      'future': 'legal',
#      'historic': 'not_legal',
#      'pioneer': 'legal',
#      'modern': 'legal',
#      'legacy': 'legal',
#      'pauper': 'not_legal',
#      'vintage': 'legal',
#      'penny': 'not_legal',
#      'commander': 'legal',
#      'brawl': 'not_legal',
#      'duel': 'legal',
#      'oldschool': 'not_legal'},
#     'games': [],
#     'reserved': False,
#     'foil': True,
#     'nonfoil': True,
#     'oversized': False,
#     'promo': True,
#     'reprint': True,
#     'variation': False,
#     'set': 'thb',
#     'set_name': 'Theros Beyond Death',
#     'set_type': 'expansion',
#     'set_uri': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913',
#     'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints',
#     'scryfall_set_uri': 'https://scryfall.com/sets/thb?utm_source=api',
#     'rulings_uri': 'https://api.scryfall.com/cards/80c6be18-356e-4e8b-899c-4a82f5d41a41/rulings',
#     'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A33b9b3bd-33ca-46f3-b8bb-a978bc3d1085&unique=prints',
#     'collector_number': '348',
#     'digital': False,
#     'rarity': 'rare',
#     'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#     'artist': 'Jonas De Ro',
#     'artist_ids': ['561ebf9e-8d93-4b57-8156-8826d0c19601'],
#     'illustration_id': '8acc157a-0401-456a-8bf1-9d7e0da9ebd1',
#     'border_color': 'black',
#     'frame': '2015',
#     'frame_effects': ['extendedart'],
#     'full_art': False,
#     'textless': False,
#     'booster': False,
#     'story_spotlight': False,
#     'edhrec_rank': 236,
#     'preview': {'source': 'ChannelFireball',
#      'source_uri': 'https://www.channelfireball.com/all-strategy/articles/3-point/theros-beyond-death-exclusive-preview/',
#      'previewed_at': '2019-12-30'},
#     'prices': {'usd': '1.20', 'usd_foil': None, 'eur': None, 'tix': None},
#     'related_uris': {'tcgplayer_decks': 'https://decks.tcgplayer.com/magic/deck/search?contains=Temple+of+Deceit&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'edhrec': 'https://edhrec.com/route/?cc=Temple+of+Deceit',
#      'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Temple+of+Deceit'},
#     'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=206633&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Temple+of+Deceit&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#      'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Temple+of+Deceit&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}}},
#  {'PutRequest': {'Item': {'object': 'card',
#     'id': '2a4471a4-efcf-46a9-87df-62af9d616bd1',
#     'oracle_id': '3baa8e38-ef93-435d-b63e-f781d5bfcc68',
#     'multiverse_ids': [],
#     'tcgplayer_id': 206632,
#     'name': 'Temple of Abandon',
#     'lang': 'en',
#     'released_at': '2020-01-24',
#     'uri': 'https://api.scryfall.com/cards/2a4471a4-efcf-46a9-87df-62af9d616bd1',
#     'scryfall_uri': 'https://scryfall.com/card/thb/347/temple-of-abandon?utm_source=api',
#     'layout': 'normal',
#     'highres_image': False,
#     'image_uris': {'small': 'https://img.scryfall.com/cards/small/front/2/a/2a4471a4-efcf-46a9-87df-62af9d616bd1.jpg?1577716642',
#      'normal': 'https://img.scryfall.com/cards/normal/front/2/a/2a4471a4-efcf-46a9-87df-62af9d616bd1.jpg?1577716642',
#      'large': 'https://img.scryfall.com/cards/large/front/2/a/2a4471a4-efcf-46a9-87df-62af9d616bd1.jpg?1577716642',
#      'png': 'https://img.scryfall.com/cards/png/front/2/a/2a4471a4-efcf-46a9-87df-62af9d616bd1.png?1577716642',
#      'art_crop': 'https://img.scryfall.com/cards/art_crop/front/2/a/2a4471a4-efcf-46a9-87df-62af9d616bd1.jpg?1577716642',
#      'border_crop': 'https://img.scryfall.com/cards/border_crop/front/2/a/2a4471a4-efcf-46a9-87df-62af9d616bd1.jpg?1577716642'},
#     'mana_cost': '',
#     'cmc': 0.0,
#     'type_line': 'Land',
#     'oracle_text': 'Temple of Abandon enters the battlefield tapped.\nWhen Temple of Abandon enters the battlefield, scry 1. (Look at the top card of your library. You may put that card on the bottom of your library.)\n{T}: Add {R} or {G}.',
#     'colors': [],
#     'color_identity': ['G', 'R'],
#     'legalities': {'standard': 'not_legal',
#      'future': 'legal',
#      'historic': 'not_legal',
#      'pioneer': 'legal',
#      'modern': 'legal',
#      'legacy': 'legal',
#      'pauper': 'not_legal',
#      'vintage': 'legal',
#      'penny': 'not_legal',
#      'commander': 'legal',
#      'brawl': 'not_legal',
#      'duel': 'legal',
#      'oldschool': 'not_legal'},
#     'games': [],
#     'reserved': False,
#     'foil': True,
#     'nonfoil': True,
#     'oversized': False,
#     'promo': True,
#     'reprint': True,
#     'variation': False,
#     'set': 'thb',
#     'set_name': 'Theros Beyond Death',
#     'set_type': 'expansion',
#     'set_uri': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913',
#     'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints',
#     'scryfall_set_uri': 'https://scryfall.com/sets/thb?utm_source=api',
#     'rulings_uri': 'https://api.scryfall.com/cards/2a4471a4-efcf-46a9-87df-62af9d616bd1/rulings',
#     'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A3baa8e38-ef93-435d-b63e-f781d5bfcc68&unique=prints',
#     'collector_number': '347',
#     'digital': False,
#     'rarity': 'rare',
#     'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#     'artist': 'Adam Paquette',
#     'artist_ids': ['89023dad-e6c0-41e0-83fb-eb2bfbbdc3f2'],
#     'illustration_id': '2a0fba2e-b5f9-44cd-8b42-f843b5fa84ba',
#     'border_color': 'black',
#     'frame': '2015',
#     'frame_effects': ['extendedart'],
#     'full_art': False,
#     'textless': False,
#     'booster': False,
#     'story_spotlight': False,
#     'edhrec_rank': 374,
#     'preview': {'source': 'ChannelFireball',
#      'source_uri': 'https://www.channelfireball.com/all-strategy/articles/3-point/theros-beyond-death-exclusive-preview/',
#      'previewed_at': '2019-12-30'},
#     'prices': {'usd': '1.23', 'usd_foil': None, 'eur': None, 'tix': None},
#     'related_uris': {'tcgplayer_decks': 'https://decks.tcgplayer.com/magic/deck/search?contains=Temple+of+Abandon&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'edhrec': 'https://edhrec.com/route/?cc=Temple+of+Abandon',
#      'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Temple+of+Abandon'},
#     'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=206632&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Temple+of+Abandon&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#      'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Temple+of+Abandon&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}}},
#  {'PutRequest': {'Item': {'object': 'card',
#     'id': 'f3e73185-afdf-4fae-82c3-b5ea355c1572',
#     'oracle_id': 'cfb8cdde-11f6-441a-942b-32d8c191fc90',
#     'multiverse_ids': [],
#     'tcgplayer_id': 206648,
#     'name': 'Nyx Lotus',
#     'lang': 'en',
#     'released_at': '2020-01-24',
#     'uri': 'https://api.scryfall.com/cards/f3e73185-afdf-4fae-82c3-b5ea355c1572',
#     'scryfall_uri': 'https://scryfall.com/card/thb/344/nyx-lotus?utm_source=api',
#     'layout': 'normal',
#     'highres_image': False,
#     'image_uris': {'small': 'https://img.scryfall.com/cards/small/front/f/3/f3e73185-afdf-4fae-82c3-b5ea355c1572.jpg?1577968563',
#      'normal': 'https://img.scryfall.com/cards/normal/front/f/3/f3e73185-afdf-4fae-82c3-b5ea355c1572.jpg?1577968563',
#      'large': 'https://img.scryfall.com/cards/large/front/f/3/f3e73185-afdf-4fae-82c3-b5ea355c1572.jpg?1577968563',
#      'png': 'https://img.scryfall.com/cards/png/front/f/3/f3e73185-afdf-4fae-82c3-b5ea355c1572.png?1577968563',
#      'art_crop': 'https://img.scryfall.com/cards/art_crop/front/f/3/f3e73185-afdf-4fae-82c3-b5ea355c1572.jpg?1577968563',
#      'border_crop': 'https://img.scryfall.com/cards/border_crop/front/f/3/f3e73185-afdf-4fae-82c3-b5ea355c1572.jpg?1577968563'},
#     'mana_cost': '{4}',
#     'cmc': 4.0,
#     'type_line': 'Legendary Artifact',
#     'oracle_text': 'Nyx Lotus enters the battlefield tapped.\n{T}: Choose a color. Add an amount of mana of that color equal to your devotion to that color. (Your devotion to a color is the number of mana symbols of that color in the mana costs of permanents you control.)',
#     'colors': [],
#     'color_identity': [],
#     'legalities': {'standard': 'not_legal',
#      'future': 'legal',
#      'historic': 'not_legal',
#      'pioneer': 'not_legal',
#      'modern': 'not_legal',
#      'legacy': 'not_legal',
#      'pauper': 'not_legal',
#      'vintage': 'not_legal',
#      'penny': 'not_legal',
#      'commander': 'not_legal',
#      'brawl': 'not_legal',
#      'duel': 'not_legal',
#      'oldschool': 'not_legal'},
#     'games': [],
#     'reserved': False,
#     'foil': True,
#     'nonfoil': True,
#     'oversized': False,
#     'promo': True,
#     'reprint': False,
#     'variation': False,
#     'set': 'thb',
#     'set_name': 'Theros Beyond Death',
#     'set_type': 'expansion',
#     'set_uri': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913',
#     'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints',
#     'scryfall_set_uri': 'https://scryfall.com/sets/thb?utm_source=api',
#     'rulings_uri': 'https://api.scryfall.com/cards/f3e73185-afdf-4fae-82c3-b5ea355c1572/rulings',
#     'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Acfb8cdde-11f6-441a-942b-32d8c191fc90&unique=prints',
#     'collector_number': '344',
#     'digital': False,
#     'rarity': 'rare',
#     'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#     'artist': 'Raoul Vitale',
#     'artist_ids': ['c7c15d49-f84b-4d98-9a34-e80e8347b756'],
#     'illustration_id': '1f1ddcb3-6e8e-4165-9c32-f31362ea90d9',
#     'border_color': 'black',
#     'frame': '2015',
#     'frame_effects': ['extendedart', 'legendary'],
#     'full_art': False,
#     'textless': False,
#     'booster': False,
#     'story_spotlight': False,
#     'edhrec_rank': 16269,
#     'preview': {'source': 'Wizards of the Coast',
#      'source_uri': 'https://magic.wizards.com/en/articles/archive/card-image-gallery/theros-beyond-death-variants',
#      'previewed_at': '2020-01-02'},
#     'prices': {'usd': '9.22', 'usd_foil': None, 'eur': None, 'tix': None},
#     'related_uris': {'tcgplayer_decks': 'https://decks.tcgplayer.com/magic/deck/search?contains=Nyx+Lotus&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'edhrec': 'https://edhrec.com/route/?cc=Nyx+Lotus',
#      'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Nyx+Lotus'},
#     'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=206648&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Nyx+Lotus&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#      'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Nyx+Lotus&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}}},
#  {'PutRequest': {'Item': {'object': 'card',
#     'id': 'bcf6e4d1-1b4f-450c-a0fc-2d02313979ca',
#     'oracle_id': 'ee302659-59ed-4eef-babe-451b9ccf7f14',
#     'multiverse_ids': [],
#     'name': "Uro, Titan of Nature's Wrath",
#     'lang': 'en',
#     'released_at': '2020-01-24',
#     'uri': 'https://api.scryfall.com/cards/bcf6e4d1-1b4f-450c-a0fc-2d02313979ca',
#     'scryfall_uri': 'https://scryfall.com/card/thb/343/uro-titan-of-natures-wrath?utm_source=api',
#     'layout': 'normal',
#     'highres_image': False,
#     'image_uris': {'small': 'https://img.scryfall.com/cards/small/front/b/c/bcf6e4d1-1b4f-450c-a0fc-2d02313979ca.jpg?1578316116',
#      'normal': 'https://img.scryfall.com/cards/normal/front/b/c/bcf6e4d1-1b4f-450c-a0fc-2d02313979ca.jpg?1578316116',
#      'large': 'https://img.scryfall.com/cards/large/front/b/c/bcf6e4d1-1b4f-450c-a0fc-2d02313979ca.jpg?1578316116',
#      'png': 'https://img.scryfall.com/cards/png/front/b/c/bcf6e4d1-1b4f-450c-a0fc-2d02313979ca.png?1578316116',
#      'art_crop': 'https://img.scryfall.com/cards/art_crop/front/b/c/bcf6e4d1-1b4f-450c-a0fc-2d02313979ca.jpg?1578316116',
#      'border_crop': 'https://img.scryfall.com/cards/border_crop/front/b/c/bcf6e4d1-1b4f-450c-a0fc-2d02313979ca.jpg?1578316116'},
#     'mana_cost': '{1}{G}{U}',
#     'cmc': 3.0,
#     'type_line': 'Legendary Creature — Elder Giant',
#     'oracle_text': 'When Uro enters the battlefield, sacrifice it unless it escaped.\nWhenever Uro enters the battlefield or attacks, you gain 3 life and draw a card, then you may put a land card from your hand onto the battlefield.\nEscape-{G}{G}{U}{U}, Exile five other cards from your graveyard. (You may cast this card from your graveyard for its escape cost.)',
#     'power': '6',
#     'toughness': '6',
#     'colors': ['G', 'U'],
#     'color_identity': ['G', 'U'],
#     'legalities': {'standard': 'not_legal',
#      'future': 'legal',
#      'historic': 'not_legal',
#      'pioneer': 'not_legal',
#      'modern': 'not_legal',
#      'legacy': 'not_legal',
#      'pauper': 'not_legal',
#      'vintage': 'not_legal',
#      'penny': 'not_legal',
#      'commander': 'not_legal',
#      'brawl': 'not_legal',
#      'duel': 'not_legal',
#      'oldschool': 'not_legal'},
#     'games': [],
#     'reserved': False,
#     'foil': True,
#     'nonfoil': True,
#     'oversized': False,
#     'promo': True,
#     'reprint': False,
#     'variation': False,
#     'set': 'thb',
#     'set_name': 'Theros Beyond Death',
#     'set_type': 'expansion',
#     'set_uri': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913',
#     'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints',
#     'scryfall_set_uri': 'https://scryfall.com/sets/thb?utm_source=api',
#     'rulings_uri': 'https://api.scryfall.com/cards/bcf6e4d1-1b4f-450c-a0fc-2d02313979ca/rulings',
#     'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Aee302659-59ed-4eef-babe-451b9ccf7f14&unique=prints',
#     'collector_number': '343',
#     'digital': False,
#     'rarity': 'mythic',
#     'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#     'artist': 'Vincent Proce',
#     'artist_ids': ['d82b1138-76d3-49f7-9d8c-bc2e2d3e0b0a'],
#     'illustration_id': '319b6606-dff4-4e49-a209-550c2aa69fa6',
#     'border_color': 'black',
#     'frame': '2015',
#     'frame_effects': ['extendedart', 'legendary'],
#     'full_art': False,
#     'textless': False,
#     'booster': False,
#     'story_spotlight': False,
#     'preview': {'source': 'MTGGoldfish',
#      'source_uri': 'https://twitter.com/MTGGoldfish/status/1214218500664782849',
#      'previewed_at': '2020-01-06'},
#     'prices': {'usd': None, 'usd_foil': None, 'eur': None, 'tix': None},
#     'related_uris': {'tcgplayer_decks': 'https://decks.tcgplayer.com/magic/deck/search?contains=Uro%2C+Titan+of+Nature%27s+Wrath&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'edhrec': 'https://edhrec.com/route/?cc=Uro%2C+Titan+of+Nature%27s+Wrath',
#      'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Uro%2C+Titan+of+Nature%27s+Wrath'},
#     'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/productcatalog/product/show?ProductName=Uro%2C+Titan+of+Nature%27s+Wrath&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Uro%2C+Titan+of+Nature%27s+Wrath&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#      'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Uro%2C+Titan+of+Nature%27s+Wrath&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}}},
#  {'PutRequest': {'Item': {'object': 'card',
#     'id': 'a6ee5698-1a40-434c-937b-9462825a752b',
#     'oracle_id': 'd297ce39-da98-4351-be9d-24f4d09bee7f',
#     'multiverse_ids': [],
#     'tcgplayer_id': 206656,
#     'name': 'Kunoros, Hound of Athreos',
#     'lang': 'en',
#     'released_at': '2020-01-24',
#     'uri': 'https://api.scryfall.com/cards/a6ee5698-1a40-434c-937b-9462825a752b',
#     'scryfall_uri': 'https://scryfall.com/card/thb/341/kunoros-hound-of-athreos?utm_source=api',
#     'layout': 'normal',
#     'highres_image': False,
#     'image_uris': {'small': 'https://img.scryfall.com/cards/small/front/a/6/a6ee5698-1a40-434c-937b-9462825a752b.jpg?1577966489',
#      'normal': 'https://img.scryfall.com/cards/normal/front/a/6/a6ee5698-1a40-434c-937b-9462825a752b.jpg?1577966489',
#      'large': 'https://img.scryfall.com/cards/large/front/a/6/a6ee5698-1a40-434c-937b-9462825a752b.jpg?1577966489',
#      'png': 'https://img.scryfall.com/cards/png/front/a/6/a6ee5698-1a40-434c-937b-9462825a752b.png?1577966489',
#      'art_crop': 'https://img.scryfall.com/cards/art_crop/front/a/6/a6ee5698-1a40-434c-937b-9462825a752b.jpg?1577966489',
#      'border_crop': 'https://img.scryfall.com/cards/border_crop/front/a/6/a6ee5698-1a40-434c-937b-9462825a752b.jpg?1577966489'},
#     'mana_cost': '{1}{W}{B}',
#     'cmc': 3.0,
#     'type_line': 'Legendary Creature — Hound',
#     'oracle_text': "Vigilance, menace, lifelink\nCreature cards in graveyards can't enter the battlefield.\nPlayers can't cast spells from graveyards.",
#     'power': '3',
#     'toughness': '3',
#     'colors': ['B', 'W'],
#     'color_identity': ['B', 'W'],
#     'legalities': {'standard': 'not_legal',
#      'future': 'legal',
#      'historic': 'not_legal',
#      'pioneer': 'not_legal',
#      'modern': 'not_legal',
#      'legacy': 'not_legal',
#      'pauper': 'not_legal',
#      'vintage': 'not_legal',
#      'penny': 'not_legal',
#      'commander': 'not_legal',
#      'brawl': 'not_legal',
#      'duel': 'not_legal',
#      'oldschool': 'not_legal'},
#     'games': [],
#     'reserved': False,
#     'foil': True,
#     'nonfoil': True,
#     'oversized': False,
#     'promo': True,
#     'reprint': False,
#     'variation': False,
#     'set': 'thb',
#     'set_name': 'Theros Beyond Death',
#     'set_type': 'expansion',
#     'set_uri': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913',
#     'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints',
#     'scryfall_set_uri': 'https://scryfall.com/sets/thb?utm_source=api',
#     'rulings_uri': 'https://api.scryfall.com/cards/a6ee5698-1a40-434c-937b-9462825a752b/rulings',
#     'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Ad297ce39-da98-4351-be9d-24f4d09bee7f&unique=prints',
#     'collector_number': '341',
#     'digital': False,
#     'rarity': 'rare',
#     'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#     'artist': 'Zezhou Chen',
#     'artist_ids': ['810677e5-a502-4c03-b726-78cd808a75d4'],
#     'illustration_id': 'ae469d0e-4249-4502-b391-10f464527708',
#     'border_color': 'black',
#     'frame': '2015',
#     'frame_effects': ['extendedart', 'legendary'],
#     'full_art': False,
#     'textless': False,
#     'booster': False,
#     'story_spotlight': False,
#     'edhrec_rank': 17535,
#     'preview': {'source': 'David Caero',
#      'source_uri': 'https://twitter.com/dogdog/status/1211770922383884290',
#      'previewed_at': '2019-12-30'},
#     'prices': {'usd': '2.15', 'usd_foil': '14.99', 'eur': None, 'tix': None},
#     'related_uris': {'tcgplayer_decks': 'https://decks.tcgplayer.com/magic/deck/search?contains=Kunoros%2C+Hound+of+Athreos&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'edhrec': 'https://edhrec.com/route/?cc=Kunoros%2C+Hound+of+Athreos',
#      'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Kunoros%2C+Hound+of+Athreos'},
#     'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=206656&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Kunoros%2C+Hound+of+Athreos&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#      'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Kunoros%2C+Hound+of+Athreos&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}}},
#  {'PutRequest': {'Item': {'object': 'card',
#     'id': 'f721cc84-8d76-4c57-b4ba-e384c67aeef7',
#     'oracle_id': '43f135b5-d33e-4873-bc5a-8c939582d624',
#     'multiverse_ids': [],
#     'tcgplayer_id': 206624,
#     'name': 'Gallia of the Endless Dance',
#     'lang': 'en',
#     'released_at': '2020-01-24',
#     'uri': 'https://api.scryfall.com/cards/f721cc84-8d76-4c57-b4ba-e384c67aeef7',
#     'scryfall_uri': 'https://scryfall.com/card/thb/338/gallia-of-the-endless-dance?utm_source=api',
#     'layout': 'normal',
#     'highres_image': False,
#     'image_uris': {'small': 'https://img.scryfall.com/cards/small/front/f/7/f721cc84-8d76-4c57-b4ba-e384c67aeef7.jpg?1577968561',
#      'normal': 'https://img.scryfall.com/cards/normal/front/f/7/f721cc84-8d76-4c57-b4ba-e384c67aeef7.jpg?1577968561',
#      'large': 'https://img.scryfall.com/cards/large/front/f/7/f721cc84-8d76-4c57-b4ba-e384c67aeef7.jpg?1577968561',
#      'png': 'https://img.scryfall.com/cards/png/front/f/7/f721cc84-8d76-4c57-b4ba-e384c67aeef7.png?1577968561',
#      'art_crop': 'https://img.scryfall.com/cards/art_crop/front/f/7/f721cc84-8d76-4c57-b4ba-e384c67aeef7.jpg?1577968561',
#      'border_crop': 'https://img.scryfall.com/cards/border_crop/front/f/7/f721cc84-8d76-4c57-b4ba-e384c67aeef7.jpg?1577968561'},
#     'mana_cost': '{R}{G}',
#     'cmc': 2.0,
#     'type_line': 'Legendary Creature — Satyr',
#     'oracle_text': 'Haste\nOther Satyrs you control get +1/+1 and have haste.\nWhenever you attack with three or more creatures, you may discard a card at random. If you do, draw two cards.',
#     'power': '2',
#     'toughness': '2',
#     'colors': ['G', 'R'],
#     'color_identity': ['G', 'R'],
#     'legalities': {'standard': 'not_legal',
#      'future': 'legal',
#      'historic': 'not_legal',
#      'pioneer': 'not_legal',
#      'modern': 'not_legal',
#      'legacy': 'not_legal',
#      'pauper': 'not_legal',
#      'vintage': 'not_legal',
#      'penny': 'not_legal',
#      'commander': 'not_legal',
#      'brawl': 'not_legal',
#      'duel': 'not_legal',
#      'oldschool': 'not_legal'},
#     'games': [],
#     'reserved': False,
#     'foil': True,
#     'nonfoil': True,
#     'oversized': False,
#     'promo': True,
#     'reprint': False,
#     'variation': False,
#     'set': 'thb',
#     'set_name': 'Theros Beyond Death',
#     'set_type': 'expansion',
#     'set_uri': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913',
#     'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints',
#     'scryfall_set_uri': 'https://scryfall.com/sets/thb?utm_source=api',
#     'rulings_uri': 'https://api.scryfall.com/cards/f721cc84-8d76-4c57-b4ba-e384c67aeef7/rulings',
#     'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A43f135b5-d33e-4873-bc5a-8c939582d624&unique=prints',
#     'collector_number': '338',
#     'digital': False,
#     'rarity': 'rare',
#     'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#     'artist': 'Johannes Voss',
#     'artist_ids': ['3593dd7e-c547-4a32-81cd-7da725f60118'],
#     'illustration_id': '4ba37543-346e-4bae-a218-7c3faa0a4fd1',
#     'border_color': 'black',
#     'frame': '2015',
#     'frame_effects': ['extendedart', 'legendary'],
#     'full_art': False,
#     'textless': False,
#     'booster': False,
#     'story_spotlight': False,
#     'edhrec_rank': 17947,
#     'preview': {'source': 'Wizards of the Coast',
#      'source_uri': 'https://magic.wizards.com/en/articles/archive/card-image-gallery/theros-beyond-death-variants',
#      'previewed_at': '2020-01-02'},
#     'prices': {'usd': '1.97', 'usd_foil': '9.98', 'eur': None, 'tix': None},
#     'related_uris': {'tcgplayer_decks': 'https://decks.tcgplayer.com/magic/deck/search?contains=Gallia+of+the+Endless+Dance&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'edhrec': 'https://edhrec.com/route/?cc=Gallia+of+the+Endless+Dance',
#      'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Gallia+of+the+Endless+Dance'},
#     'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=206624&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Gallia+of+the+Endless+Dance&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#      'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Gallia+of+the+Endless+Dance&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}}},
#  {'PutRequest': {'Item': {'object': 'card',
#     'id': '7dadfb33-7082-47b8-a498-f3bb963a8d78',
#     'oracle_id': '211814a5-195d-41c6-b96c-4c26b2cbb33c',
#     'multiverse_ids': [],
#     'tcgplayer_id': 206674,
#     'name': 'Dalakos, Crafter of Wonders',
#     'lang': 'en',
#     'released_at': '2020-01-24',
#     'uri': 'https://api.scryfall.com/cards/7dadfb33-7082-47b8-a498-f3bb963a8d78',
#     'scryfall_uri': 'https://scryfall.com/card/thb/335/dalakos-crafter-of-wonders?utm_source=api',
#     'layout': 'normal',
#     'highres_image': False,
#     'image_uris': {'small': 'https://img.scryfall.com/cards/small/front/7/d/7dadfb33-7082-47b8-a498-f3bb963a8d78.jpg?1577968558',
#      'normal': 'https://img.scryfall.com/cards/normal/front/7/d/7dadfb33-7082-47b8-a498-f3bb963a8d78.jpg?1577968558',
#      'large': 'https://img.scryfall.com/cards/large/front/7/d/7dadfb33-7082-47b8-a498-f3bb963a8d78.jpg?1577968558',
#      'png': 'https://img.scryfall.com/cards/png/front/7/d/7dadfb33-7082-47b8-a498-f3bb963a8d78.png?1577968558',
#      'art_crop': 'https://img.scryfall.com/cards/art_crop/front/7/d/7dadfb33-7082-47b8-a498-f3bb963a8d78.jpg?1577968558',
#      'border_crop': 'https://img.scryfall.com/cards/border_crop/front/7/d/7dadfb33-7082-47b8-a498-f3bb963a8d78.jpg?1577968558'},
#     'mana_cost': '{1}{U}{R}',
#     'cmc': 3.0,
#     'type_line': 'Legendary Creature — Merfolk Artificer',
#     'oracle_text': '{T}: Add {C}{C}. Spend this mana only to cast artifact spells or activate abilities of artifacts.\nEquipped creatures you control have flying and haste.',
#     'power': '2',
#     'toughness': '4',
#     'colors': ['R', 'U'],
#     'color_identity': ['R', 'U'],
#     'legalities': {'standard': 'not_legal',
#      'future': 'legal',
#      'historic': 'not_legal',
#      'pioneer': 'not_legal',
#      'modern': 'not_legal',
#      'legacy': 'not_legal',
#      'pauper': 'not_legal',
#      'vintage': 'not_legal',
#      'penny': 'not_legal',
#      'commander': 'not_legal',
#      'brawl': 'not_legal',
#      'duel': 'not_legal',
#      'oldschool': 'not_legal'},
#     'games': [],
#     'reserved': False,
#     'foil': True,
#     'nonfoil': True,
#     'oversized': False,
#     'promo': True,
#     'reprint': False,
#     'variation': False,
#     'set': 'thb',
#     'set_name': 'Theros Beyond Death',
#     'set_type': 'expansion',
#     'set_uri': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913',
#     'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints',
#     'scryfall_set_uri': 'https://scryfall.com/sets/thb?utm_source=api',
#     'rulings_uri': 'https://api.scryfall.com/cards/7dadfb33-7082-47b8-a498-f3bb963a8d78/rulings',
#     'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A211814a5-195d-41c6-b96c-4c26b2cbb33c&unique=prints',
#     'collector_number': '335',
#     'digital': False,
#     'rarity': 'rare',
#     'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#     'artist': 'Ryan Pancoast',
#     'artist_ids': ['89cc9475-dda2-4d13-bf88-54b92867a25c'],
#     'illustration_id': '54a3da49-4493-465b-af7a-f57bd56af69c',
#     'border_color': 'black',
#     'frame': '2015',
#     'frame_effects': ['extendedart', 'legendary'],
#     'full_art': False,
#     'textless': False,
#     'booster': False,
#     'story_spotlight': False,
#     'preview': {'source': 'Wizards of the Coast',
#      'source_uri': 'https://magic.wizards.com/en/articles/archive/card-image-gallery/theros-beyond-death-variants',
#      'previewed_at': '2020-01-02'},
#     'prices': {'usd': '4.82', 'usd_foil': None, 'eur': None, 'tix': None},
#     'related_uris': {'tcgplayer_decks': 'https://decks.tcgplayer.com/magic/deck/search?contains=Dalakos%2C+Crafter+of+Wonders&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'edhrec': 'https://edhrec.com/route/?cc=Dalakos%2C+Crafter+of+Wonders',
#      'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Dalakos%2C+Crafter+of+Wonders'},
#     'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=206674&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Dalakos%2C+Crafter+of+Wonders&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#      'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Dalakos%2C+Crafter+of+Wonders&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}}},
#  {'PutRequest': {'Item': {'object': 'card',
#     'id': 'a3085763-e65b-49cb-a4e0-2cbad2658a1b',
#     'oracle_id': '8b2b00ab-f1c5-4057-9957-d7daac95a847',
#     'multiverse_ids': [],
#     'tcgplayer_id': 206670,
#     'name': 'Atris, Oracle of Half-Truths',
#     'lang': 'en',
#     'released_at': '2020-01-24',
#     'uri': 'https://api.scryfall.com/cards/a3085763-e65b-49cb-a4e0-2cbad2658a1b',
#     'scryfall_uri': 'https://scryfall.com/card/thb/333/atris-oracle-of-half-truths?utm_source=api',
#     'layout': 'normal',
#     'highres_image': False,
#     'image_uris': {'small': 'https://img.scryfall.com/cards/small/front/a/3/a3085763-e65b-49cb-a4e0-2cbad2658a1b.jpg?1577966612',
#      'normal': 'https://img.scryfall.com/cards/normal/front/a/3/a3085763-e65b-49cb-a4e0-2cbad2658a1b.jpg?1577966612',
#      'large': 'https://img.scryfall.com/cards/large/front/a/3/a3085763-e65b-49cb-a4e0-2cbad2658a1b.jpg?1577966612',
#      'png': 'https://img.scryfall.com/cards/png/front/a/3/a3085763-e65b-49cb-a4e0-2cbad2658a1b.png?1577966612',
#      'art_crop': 'https://img.scryfall.com/cards/art_crop/front/a/3/a3085763-e65b-49cb-a4e0-2cbad2658a1b.jpg?1577966612',
#      'border_crop': 'https://img.scryfall.com/cards/border_crop/front/a/3/a3085763-e65b-49cb-a4e0-2cbad2658a1b.jpg?1577966612'},
#     'mana_cost': '{2}{U}{B}',
#     'cmc': 4.0,
#     'type_line': 'Legendary Creature — Human Advisor',
#     'oracle_text': 'Menace\nWhen Atris, Oracle of Half-Truths enters the battlefield, target opponent looks at the top three cards of your library and separates them into a face-down pile and a face-up pile. Put one pile into your hand and the other into your graveyard.',
#     'power': '3',
#     'toughness': '2',
#     'colors': ['B', 'U'],
#     'color_identity': ['B', 'U'],
#     'legalities': {'standard': 'not_legal',
#      'future': 'legal',
#      'historic': 'not_legal',
#      'pioneer': 'not_legal',
#      'modern': 'not_legal',
#      'legacy': 'not_legal',
#      'pauper': 'not_legal',
#      'vintage': 'not_legal',
#      'penny': 'not_legal',
#      'commander': 'not_legal',
#      'brawl': 'not_legal',
#      'duel': 'not_legal',
#      'oldschool': 'not_legal'},
#     'games': [],
#     'reserved': False,
#     'foil': True,
#     'nonfoil': True,
#     'oversized': False,
#     'promo': True,
#     'reprint': False,
#     'variation': False,
#     'set': 'thb',
#     'set_name': 'Theros Beyond Death',
#     'set_type': 'expansion',
#     'set_uri': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913',
#     'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints',
#     'scryfall_set_uri': 'https://scryfall.com/sets/thb?utm_source=api',
#     'rulings_uri': 'https://api.scryfall.com/cards/a3085763-e65b-49cb-a4e0-2cbad2658a1b/rulings',
#     'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A8b2b00ab-f1c5-4057-9957-d7daac95a847&unique=prints',
#     'collector_number': '333',
#     'digital': False,
#     'rarity': 'rare',
#     'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#     'artist': 'Bastien L. Deharme',
#     'artist_ids': ['798f63ec-41ad-474e-9708-df08193345c6'],
#     'illustration_id': '3e413dc1-dbb9-4bc0-9739-2f80fec21625',
#     'border_color': 'black',
#     'frame': '2015',
#     'frame_effects': ['extendedart', 'legendary'],
#     'full_art': False,
#     'textless': False,
#     'booster': False,
#     'story_spotlight': False,
# ...
#     'colors': ['B'],
#     'color_identity': ['B'],
#     'legalities': {'standard': 'not_legal',
#      'future': 'legal',
#      'historic': 'not_legal',
#      'pioneer': 'not_legal',
#      'modern': 'not_legal',
#      'legacy': 'not_legal',
#      'pauper': 'not_legal',
#      'vintage': 'not_legal',
#      'penny': 'not_legal',
#      'commander': 'not_legal',
#      'brawl': 'not_legal',
#      'duel': 'not_legal',
#      'oldschool': 'not_legal'},
#     'games': [],
#     'reserved': False,
#     'foil': True,
#     'nonfoil': True,
#     'oversized': False,
#     'promo': True,
#     'reprint': False,
#     'variation': False,
#     'set': 'thb',
#     'set_name': 'Theros Beyond Death',
#     'set_type': 'expansion',
#     'set_uri': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913',
#     'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints',
#     'scryfall_set_uri': 'https://scryfall.com/sets/thb?utm_source=api',
#     'rulings_uri': 'https://api.scryfall.com/cards/7cde9bcb-1c60-4f3f-af07-7db3f8baf1cc/rulings',
#     'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A17f573c4-3ed4-453e-bfbe-4e42d54633e5&unique=prints',
#     'collector_number': '316',
#     'digital': False,
#     'rarity': 'rare',
#     'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#     'artist': 'Marco Teixeira',
#     'artist_ids': ['34108a62-3b01-4b43-b58e-9f5901908499'],
#     'illustration_id': '3171427a-c6f6-4f64-b7b3-4272b8976522',
#     'border_color': 'black',
#     'frame': '2015',
#     'frame_effects': ['extendedart'],
#     'full_art': False,
#     'textless': False,
#     'booster': False,
#     'story_spotlight': False,
#     'edhrec_rank': 19321,
#     'preview': {'source': 'Vana',
#      'source_uri': 'https://youtu.be/b2nXPdK2Gjs',
#      'previewed_at': '2019-12-31'},
#     'prices': {'usd': '6.11', 'usd_foil': None, 'eur': None, 'tix': None},
#     'related_uris': {'tcgplayer_decks': 'https://decks.tcgplayer.com/magic/deck/search?contains=Treacherous+Blessing&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'edhrec': 'https://edhrec.com/route/?cc=Treacherous+Blessing',
#      'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Treacherous+Blessing'},
#     'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=206658&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Treacherous+Blessing&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#      'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Treacherous+Blessing&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}}},
#  {'PutRequest': {'Item': {'object': 'card',
#     'id': 'a7f0dd24-d28c-4f94-8131-3061a1b92e93',
#     'oracle_id': '820dab0f-3b6b-437c-ba4b-2311437709c3',
#     'multiverse_ids': [],
#     'tcgplayer_id': 206700,
#     'name': 'Aphemia, the Cacophony',
#     'lang': 'en',
#     'released_at': '2020-01-24',
#     'uri': 'https://api.scryfall.com/cards/a7f0dd24-d28c-4f94-8131-3061a1b92e93',
#     'scryfall_uri': 'https://scryfall.com/card/thb/311/aphemia-the-cacophony?utm_source=api',
#     'layout': 'normal',
#     'highres_image': False,
#     'image_uris': {'small': 'https://img.scryfall.com/cards/small/front/a/7/a7f0dd24-d28c-4f94-8131-3061a1b92e93.jpg?1577968544',
#      'normal': 'https://img.scryfall.com/cards/normal/front/a/7/a7f0dd24-d28c-4f94-8131-3061a1b92e93.jpg?1577968544',
#      'large': 'https://img.scryfall.com/cards/large/front/a/7/a7f0dd24-d28c-4f94-8131-3061a1b92e93.jpg?1577968544',
#      'png': 'https://img.scryfall.com/cards/png/front/a/7/a7f0dd24-d28c-4f94-8131-3061a1b92e93.png?1577968544',
#      'art_crop': 'https://img.scryfall.com/cards/art_crop/front/a/7/a7f0dd24-d28c-4f94-8131-3061a1b92e93.jpg?1577968544',
#      'border_crop': 'https://img.scryfall.com/cards/border_crop/front/a/7/a7f0dd24-d28c-4f94-8131-3061a1b92e93.jpg?1577968544'},
#     'mana_cost': '{1}{B}',
#     'cmc': 2.0,
#     'type_line': 'Legendary Enchantment Creature — Harpy',
#     'oracle_text': 'Flying\nAt the beginning of your end step, you may exile an enchantment card from your graveyard. If you do, create a 2/2 black Zombie creature token.',
#     'power': '2',
#     'toughness': '1',
#     'colors': ['B'],
#     'color_identity': ['B'],
#     'legalities': {'standard': 'not_legal',
#      'future': 'legal',
#      'historic': 'not_legal',
#      'pioneer': 'not_legal',
#      'modern': 'not_legal',
#      'legacy': 'not_legal',
#      'pauper': 'not_legal',
#      'vintage': 'not_legal',
#      'penny': 'not_legal',
#      'commander': 'not_legal',
#      'brawl': 'not_legal',
#      'duel': 'not_legal',
#      'oldschool': 'not_legal'},
#     'games': [],
#     'reserved': False,
#     'foil': True,
#     'nonfoil': True,
#     'oversized': False,
#     'promo': True,
#     'reprint': False,
#     'variation': False,
#     'set': 'thb',
#     'set_name': 'Theros Beyond Death',
#     'set_type': 'expansion',
#     'set_uri': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913',
#     'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints',
#     'scryfall_set_uri': 'https://scryfall.com/sets/thb?utm_source=api',
#     'rulings_uri': 'https://api.scryfall.com/cards/a7f0dd24-d28c-4f94-8131-3061a1b92e93/rulings',
#     'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A820dab0f-3b6b-437c-ba4b-2311437709c3&unique=prints',
#     'collector_number': '311',
#     'digital': False,
#     'rarity': 'rare',
#     'flavor_text': '"Sing, beauty. Sing for death, and for the dead." —Ashiok',
#     'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#     'artist': 'Lucas Graciano',
#     'artist_ids': ['ce98f39c-7cdd-47e6-a520-6c50443bb4c2'],
#     'illustration_id': '6fe63701-af1f-4a77-a95b-358eb3d9a1fc',
#     'border_color': 'black',
#     'frame': '2015',
#     'frame_effects': ['extendedart', 'legendary', 'nyxtouched'],
#     'full_art': False,
#     'textless': False,
#     'booster': False,
#     'story_spotlight': False,
#     'preview': {'source': 'Wizards of the Coast',
#      'source_uri': 'https://magic.wizards.com/en/articles/archive/card-image-gallery/theros-beyond-death-variants',
#      'previewed_at': '2020-01-02'},
#     'prices': {'usd': '0.92', 'usd_foil': None, 'eur': None, 'tix': None},
#     'related_uris': {'tcgplayer_decks': 'https://decks.tcgplayer.com/magic/deck/search?contains=Aphemia%2C+the+Cacophony&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'edhrec': 'https://edhrec.com/route/?cc=Aphemia%2C+the+Cacophony',
#      'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Aphemia%2C+the+Cacophony'},
#     'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=206700&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Aphemia%2C+the+Cacophony&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#      'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Aphemia%2C+the+Cacophony&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}}},
#  {'PutRequest': {'Item': {'object': 'card',
#     'id': '3044489e-84e0-453e-9248-a200d27ad17c',
#     'oracle_id': '20004398-bd04-4583-8378-9df743246a32',
#     'multiverse_ids': [],
#     'name': 'Thryx, the Sudden Storm',
#     'lang': 'en',
#     'released_at': '2020-01-24',
#     'uri': 'https://api.scryfall.com/cards/3044489e-84e0-453e-9248-a200d27ad17c',
#     'scryfall_uri': 'https://scryfall.com/card/thb/309/thryx-the-sudden-storm?utm_source=api',
#     'layout': 'normal',
#     'highres_image': False,
#     'image_uris': {'small': 'https://img.scryfall.com/cards/small/front/3/0/3044489e-84e0-453e-9248-a200d27ad17c.jpg?1578315895',
#      'normal': 'https://img.scryfall.com/cards/normal/front/3/0/3044489e-84e0-453e-9248-a200d27ad17c.jpg?1578315895',
#      'large': 'https://img.scryfall.com/cards/large/front/3/0/3044489e-84e0-453e-9248-a200d27ad17c.jpg?1578315895',
#      'png': 'https://img.scryfall.com/cards/png/front/3/0/3044489e-84e0-453e-9248-a200d27ad17c.png?1578315895',
#      'art_crop': 'https://img.scryfall.com/cards/art_crop/front/3/0/3044489e-84e0-453e-9248-a200d27ad17c.jpg?1578315895',
#      'border_crop': 'https://img.scryfall.com/cards/border_crop/front/3/0/3044489e-84e0-453e-9248-a200d27ad17c.jpg?1578315895'},
#     'mana_cost': '{3}{U}{U}',
#     'cmc': 5.0,
#     'type_line': 'Legendary Creature — Elemental Giant',
#     'oracle_text': "Flash\nFlying\nSpells you cast with converted mana cost 5 or greater cost {1} less to cast and can't be countered.",
#     'power': '4',
#     'toughness': '5',
#     'colors': ['U'],
#     'color_identity': ['U'],
#     'legalities': {'standard': 'not_legal',
#      'future': 'legal',
#      'historic': 'not_legal',
#      'pioneer': 'not_legal',
#      'modern': 'not_legal',
#      'legacy': 'not_legal',
#      'pauper': 'not_legal',
#      'vintage': 'not_legal',
#      'penny': 'not_legal',
#      'commander': 'not_legal',
#      'brawl': 'not_legal',
#      'duel': 'not_legal',
#      'oldschool': 'not_legal'},
#     'games': [],
#     'reserved': False,
#     'foil': True,
#     'nonfoil': True,
#     'oversized': False,
#     'promo': True,
#     'reprint': False,
#     'variation': False,
#     'set': 'thb',
#     'set_name': 'Theros Beyond Death',
#     'set_type': 'expansion',
#     'set_uri': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913',
#     'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints',
#     'scryfall_set_uri': 'https://scryfall.com/sets/thb?utm_source=api',
#     'rulings_uri': 'https://api.scryfall.com/cards/3044489e-84e0-453e-9248-a200d27ad17c/rulings',
#     'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A20004398-bd04-4583-8378-9df743246a32&unique=prints',
#     'collector_number': '309',
#     'digital': False,
#     'rarity': 'rare',
#     'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#     'artist': 'Mathias Kollros',
#     'artist_ids': ['2ae0dd12-047c-4efb-80d7-bccc3bac5fba'],
#     'illustration_id': 'a74932b7-6de8-4c39-8b4a-91867894bc75',
#     'border_color': 'black',
#     'frame': '2015',
#     'frame_effects': ['extendedart', 'legendary'],
#     'full_art': False,
#     'textless': False,
#     'booster': False,
#     'story_spotlight': False,
#     'prices': {'usd': None, 'usd_foil': None, 'eur': None, 'tix': None},
#     'related_uris': {'tcgplayer_decks': 'https://decks.tcgplayer.com/magic/deck/search?contains=Thryx%2C+the+Sudden+Storm&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'edhrec': 'https://edhrec.com/route/?cc=Thryx%2C+the+Sudden+Storm',
#      'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Thryx%2C+the+Sudden+Storm'},
#     'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/productcatalog/product/show?ProductName=Thryx%2C+the+Sudden+Storm&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Thryx%2C+the+Sudden+Storm&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#      'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Thryx%2C+the+Sudden+Storm&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}}},
#  {'PutRequest': {'Item': {'object': 'card',
#     'id': 'f0c5d004-78bd-4564-9f4a-fcf463f3a76a',
#     'oracle_id': '5a73d439-bd78-42e1-90ae-eedd30536881',
#     'multiverse_ids': [],
#     'tcgplayer_id': 206660,
#     'name': 'Nadir Kraken',
#     'lang': 'en',
#     'released_at': '2020-01-24',
#     'uri': 'https://api.scryfall.com/cards/f0c5d004-78bd-4564-9f4a-fcf463f3a76a',
#     'scryfall_uri': 'https://scryfall.com/card/thb/305/nadir-kraken?utm_source=api',
#     'layout': 'normal',
#     'highres_image': False,
#     'image_uris': {'small': 'https://img.scryfall.com/cards/small/front/f/0/f0c5d004-78bd-4564-9f4a-fcf463f3a76a.jpg?1577830947',
#      'normal': 'https://img.scryfall.com/cards/normal/front/f/0/f0c5d004-78bd-4564-9f4a-fcf463f3a76a.jpg?1577830947',
#      'large': 'https://img.scryfall.com/cards/large/front/f/0/f0c5d004-78bd-4564-9f4a-fcf463f3a76a.jpg?1577830947',
#      'png': 'https://img.scryfall.com/cards/png/front/f/0/f0c5d004-78bd-4564-9f4a-fcf463f3a76a.png?1577830947',
#      'art_crop': 'https://img.scryfall.com/cards/art_crop/front/f/0/f0c5d004-78bd-4564-9f4a-fcf463f3a76a.jpg?1577830947',
#      'border_crop': 'https://img.scryfall.com/cards/border_crop/front/f/0/f0c5d004-78bd-4564-9f4a-fcf463f3a76a.jpg?1577830947'},
#     'mana_cost': '{1}{U}{U}',
#     'cmc': 3.0,
#     'type_line': 'Creature — Kraken',
#     'oracle_text': 'Whenever you draw a card, you may pay {1}. If you do, put a +1/+1 counter on Nadir Kraken and create a 1/1 blue Tentacle creature token.',
#     'power': '2',
#     'toughness': '3',
#     'colors': ['U'],
#     'color_identity': ['U'],
#     'legalities': {'standard': 'not_legal',
#      'future': 'legal',
#      'historic': 'not_legal',
#      'pioneer': 'not_legal',
#      'modern': 'not_legal',
#      'legacy': 'not_legal',
#      'pauper': 'not_legal',
#      'vintage': 'not_legal',
#      'penny': 'not_legal',
#      'commander': 'not_legal',
#      'brawl': 'not_legal',
#      'duel': 'not_legal',
#      'oldschool': 'not_legal'},
#     'games': [],
#     'reserved': False,
#     'foil': True,
#     'nonfoil': True,
#     'oversized': False,
#     'promo': True,
#     'reprint': False,
#     'variation': False,
#     'set': 'thb',
#     'set_name': 'Theros Beyond Death',
#     'set_type': 'expansion',
#     'set_uri': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913',
#     'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints',
#     'scryfall_set_uri': 'https://scryfall.com/sets/thb?utm_source=api',
#     'rulings_uri': 'https://api.scryfall.com/cards/f0c5d004-78bd-4564-9f4a-fcf463f3a76a/rulings',
#     'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A5a73d439-bd78-42e1-90ae-eedd30536881&unique=prints',
#     'collector_number': '305',
#     'digital': False,
#     'rarity': 'rare',
#     'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#     'artist': 'Dan Scott',
#     'artist_ids': ['f852fa13-137e-40f2-bbc1-0f01df09c0e0'],
#     'illustration_id': '81fb0188-5040-4d80-a8e7-0c733c4d0d09',
#     'border_color': 'black',
#     'frame': '2015',
#     'frame_effects': ['extendedart'],
#     'full_art': False,
#     'textless': False,
#     'booster': False,
#     'story_spotlight': False,
#     'edhrec_rank': 18722,
#     'preview': {'source': 'TheAsianAvenger',
#      'source_uri': 'https://twitter.com/Theasianavenger/status/1211868569719336960',
#      'previewed_at': '2019-12-31'},
#     'prices': {'usd': '2.14', 'usd_foil': None, 'eur': None, 'tix': None},
#     'related_uris': {'tcgplayer_decks': 'https://decks.tcgplayer.com/magic/deck/search?contains=Nadir+Kraken&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'edhrec': 'https://edhrec.com/route/?cc=Nadir+Kraken',
#      'mtgtop8': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Nadir+Kraken'},
#     'purchase_uris': {'tcgplayer': 'https://shop.tcgplayer.com/product/productsearch?id=206660&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall',
#      'cardmarket': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Nadir+Kraken&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#      'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Nadir+Kraken&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}}}]

# %%
def batch_format(val):
    if type(val) is str:
        return {"S": str(val)}
    if type(val) is int:
        return {"N": str(val)}
    if type(val) is float:
        return {"N": str(val)}
    if type(val) is list:
        return {"SS": val}
    if type(val) is bool:
        return {"BOOL": True}
    if val is None:
        return {"NULL": True}
    if type(val) is dict:
        return {"M": {val_key: batch_format(val_val) for val_key, val_val in val.items()}}

# %%
for key, val in items['global-cards-table'][0]['PutRequest']['Item'].items():
    items['global-cards-table'][0]['PutRequest']['Item'][key] = batch_format(val)

# %%
items['global-cards-table'][0]['PutRequest']['Item']
# Out:
# {'object': {'S': 'card'},
#  'id': {'S': '61dc9a80-850c-4945-b84a-85381cc3ee85'},
#  'oracle_id': {'S': 'e521322b-0e83-458c-8936-7021a80ee279'},
#  'multiverse_ids': {'SS': []},
#  'tcgplayer_id': {'N': '206636'},
#  'name': {'S': 'Temple of Plenty'},
#  'lang': {'S': 'en'},
#  'released_at': {'S': '2020-01-24'},
#  'uri': {'S': 'https://api.scryfall.com/cards/61dc9a80-850c-4945-b84a-85381cc3ee85'},
#  'scryfall_uri': {'S': 'https://scryfall.com/card/thb/351/temple-of-plenty?utm_source=api'},
#  'layout': {'S': 'normal'},
#  'highres_image': {'BOOL': True},
#  'image_uris': {'M': {'small': {'S': 'https://img.scryfall.com/cards/small/front/6/1/61dc9a80-850c-4945-b84a-85381cc3ee85.jpg?1577717404'},
#    'normal': {'S': 'https://img.scryfall.com/cards/normal/front/6/1/61dc9a80-850c-4945-b84a-85381cc3ee85.jpg?1577717404'},
#    'large': {'S': 'https://img.scryfall.com/cards/large/front/6/1/61dc9a80-850c-4945-b84a-85381cc3ee85.jpg?1577717404'},
#    'png': {'S': 'https://img.scryfall.com/cards/png/front/6/1/61dc9a80-850c-4945-b84a-85381cc3ee85.png?1577717404'},
#    'art_crop': {'S': 'https://img.scryfall.com/cards/art_crop/front/6/1/61dc9a80-850c-4945-b84a-85381cc3ee85.jpg?1577717404'},
#    'border_crop': {'S': 'https://img.scryfall.com/cards/border_crop/front/6/1/61dc9a80-850c-4945-b84a-85381cc3ee85.jpg?1577717404'}}},
#  'mana_cost': {'S': ''},
#  'cmc': {'N': '0.0'},
#  'type_line': {'S': 'Land'},
#  'oracle_text': {'S': 'Temple of Plenty enters the battlefield tapped.\nWhen Temple of Plenty enters the battlefield, scry 1. (Look at the top card of your library. You may put that card on the bottom of your library.)\n{T}: Add {G} or {W}.'},
#  'colors': {'SS': []},
#  'color_identity': {'SS': ['G', 'W']},
#  'legalities': {'M': {'standard': {'S': 'not_legal'},
#    'future': {'S': 'legal'},
#    'historic': {'S': 'not_legal'},
#    'pioneer': {'S': 'legal'},
#    'modern': {'S': 'legal'},
#    'legacy': {'S': 'legal'},
#    'pauper': {'S': 'not_legal'},
#    'vintage': {'S': 'legal'},
#    'penny': {'S': 'not_legal'},
#    'commander': {'S': 'legal'},
#    'brawl': {'S': 'not_legal'},
#    'duel': {'S': 'legal'},
#    'oldschool': {'S': 'not_legal'}}},
#  'games': {'SS': []},
#  'reserved': {'BOOL': True},
#  'foil': {'BOOL': True},
#  'nonfoil': {'BOOL': True},
#  'oversized': {'BOOL': True},
#  'promo': {'BOOL': True},
#  'reprint': {'BOOL': True},
#  'variation': {'BOOL': True},
#  'set': {'S': 'thb'},
#  'set_name': {'S': 'Theros Beyond Death'},
#  'set_type': {'S': 'expansion'},
#  'set_uri': {'S': 'https://api.scryfall.com/sets/5f23a78d-cda1-462a-8be3-a62b40c34913'},
#  'set_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=set&q=e%3Athb&unique=prints'},
#  'scryfall_set_uri': {'S': 'https://scryfall.com/sets/thb?utm_source=api'},
#  'rulings_uri': {'S': 'https://api.scryfall.com/cards/61dc9a80-850c-4945-b84a-85381cc3ee85/rulings'},
#  'prints_search_uri': {'S': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Ae521322b-0e83-458c-8936-7021a80ee279&unique=prints'},
#  'collector_number': {'S': '351'},
#  'digital': {'BOOL': True},
#  'rarity': {'S': 'rare'},
#  'card_back_id': {'S': '0aeebaf5-8c7d-4636-9e82-8c27447861f7'},
#  'artist': {'S': 'Chris Ostrowski'},
#  'artist_ids': {'SS': ['b5f1bd34-abee-40c9-99f7-a6ee089fb30b']},
#  'illustration_id': {'S': '846b14b7-34e8-4f0c-86bb-8bf5dc45bd00'},
#  'border_color': {'S': 'black'},
#  'frame': {'S': '2015'},
#  'frame_effects': {'SS': ['extendedart']},
#  'full_art': {'BOOL': True},
#  'textless': {'BOOL': True},
#  'booster': {'BOOL': True},
#  'story_spotlight': {'BOOL': True},
#  'edhrec_rank': {'N': '394'},
#  'preview': {'M': {'source': {'S': 'ChannelFireball'},
#    'source_uri': {'S': 'https://www.channelfireball.com/all-strategy/articles/3-point/theros-beyond-death-exclusive-preview/'},
#    'previewed_at': {'S': '2019-12-30'}}},
#  'prices': {'M': {'usd': {'S': '1.26'},
#    'usd_foil': {'NULL': True},
#    'eur': {'NULL': True},
#    'tix': {'NULL': True}}},
#  'related_uris': {'M': {'tcgplayer_decks': {'S': 'https://decks.tcgplayer.com/magic/deck/search?contains=Temple+of+Plenty&page=1&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#    'edhrec': {'S': 'https://edhrec.com/route/?cc=Temple+of+Plenty'},
#    'mtgtop8': {'S': 'https://mtgtop8.com/search?MD_check=1&SB_check=1&cards=Temple+of+Plenty'}}},
#  'purchase_uris': {'M': {'tcgplayer': {'S': 'https://shop.tcgplayer.com/product/productsearch?id=206636&partner=Scryfall&utm_campaign=affiliate&utm_medium=scryfall&utm_source=scryfall'},
#    'cardmarket': {'S': 'https://www.cardmarket.com/en/Magic/Products/Search?referrer=scryfall&searchString=Temple+of+Plenty&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall'},
#    'cardhoarder': {'S': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Temple+of+Plenty&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}}}

# %%
cards = res.json()['data'][batch[0]:batch[1]]

# %%
res.json()['total_cards']
# Out:
# 263830

# %%
import math

# %%
cards_per_page = 175
total_cards = res.json()['total_cards']

total_pages = math.ceil(total_cards / cards_per_page)

total_pages
# Out:
# 1508

# %%
PAGES_PER_WORKER = 100

# %%
total_pages = 1508

# %%
worker_pages = [(first, first+PAGES_PER_WORKER) for first in list(range(1, total_pages+1, PAGES_PER_WORKER))]
worker_pages
# Out:
# [(1, 101),
#  (101, 201),
#  (201, 301),
#  (301, 401),
#  (401, 501),
#  (501, 601),
#  (601, 701),
#  (701, 801),
#  (801, 901),
#  (901, 1001),
#  (1001, 1101),
#  (1101, 1201),
#  (1201, 1301),
#  (1301, 1401),
#  (1401, 1501),
#  (1501, 1601)]

# %%
CARDS_URL = 'https://api.scryfall.com/cards?page={}'

# %%
CARDS_URL.format(1)
# Out:
# 'https://api.scryfall.com/cards?page=1'

# %%
cards_url = 'https://api.scryfall.com/cards?page=10'

# %%
int(str.split(cards_url, '=')[1])
# Out:
# 10

# %%
import datetime

# %%
start = datetime.datetime.now()

# %%
print(datetime.datetime.now() - then)
# Out:
# 0:00:23.186929

# %%
start = datetime.datetime.now()
all_cards_path = os.path.join(os.getcwd(), 'data', 'all_scryfall.json')
all_cards_df = pd.DataFrame()
cards_url = 'https://api.scryfall.com/cards?page=1'
cards_per_page = 175
has_more = True
while has_more:
#while int(str.split(cards_url, '=')[1]) < 101:
    res = requests.get(cards_url)
    
    #if int(cards_url[-1]) % 10 == 0:
    #    print('Getting page {}'.format(cards_url))
    
    cards_df = pd.DataFrame.from_dict(res.json()['data'])

    all_cards_df = pd.concat([all_cards_df, cards_df], sort=True, ignore_index=True)
          
    has_more = res.json()['has_more']
    cards_url = res.json()['next_page']
    
    sleep(0.1)

print(datetime.datetime.now() - then)
#all_cards_df.to_json(all_cards_path)
# Out:
# Getting page https://api.scryfall.com/cards?page=10
# Getting page https://api.scryfall.com/cards?page=20
# Getting page https://api.scryfall.com/cards?page=30
# Getting page https://api.scryfall.com/cards?page=40
# Getting page https://api.scryfall.com/cards?page=50
# Getting page https://api.scryfall.com/cards?page=60
# Getting page https://api.scryfall.com/cards?page=70
# Getting page https://api.scryfall.com/cards?page=80
# Getting page https://api.scryfall.com/cards?page=90
# Getting page https://api.scryfall.com/cards?page=100
# 0:05:45.799994

# %%
all_cards_path
# Out:
# 'C:\\Users\\LWEST\\Desktop\\mtgml-api\\notebooks\\..\\data\\all_scryfall.json'

# %%
all_cards_path = os.path.join(os.getcwd(), '..', 'data', 'all_scryfall.json')

all_cards_df = pd.read_json(all_cards_path)

# %%
all_cards_df.shape
# Out:
# (261438, 73)

# %%
all_cards_df.head(2)
# Out:
#   all_parts  arena_id          artist                              artist_ids  \
# 0      None       NaN   Milivoj Ćeran  [1eced451-4da5-42bc-b49d-70c41246581f]
# 1      None       NaN  Lucas Graciano  [ce98f39c-7cdd-47e6-a520-6c50443bb4c2]
#
#    booster border_color                          card_back_id card_faces  cmc  \
# 0    False        black  0aeebaf5-8c7d-4636-9e82-8c27447861f7       None  6.0
# 1    False        black  0aeebaf5-8c7d-4636-9e82-8c27447861f7       None  6.0
#
#   collector_number color_identity color_indicator colors  digital  \
# 0                5            [G]            None    [G]    False
# 1                4            [R]            None    [R]    False
#
#    edhrec_rank                                        flavor_text  foil frame  \
# 0          NaN  "Come, my wild children. Let's give the interl...  True  2015
# 1          NaN                  Half the size, double the mayhem.  True  2015
#
#   frame_effects  full_art    games  hand_modifier  highres_image  \
# 0          None     False  [paper]            NaN          False
# 1          None     False  [paper]            NaN          False
#
#                                      id                       illustration_id  \
# 0  dbcdbf7a-9294-47ad-9f93-c16b78c7463a  fe97c475-ef9a-41b2-872b-2469ac9f48d7
# 1  acb3ce9b-ee4f-410a-8db3-e87aeb0a4444  56da4782-3fe9-4230-b426-8e7903fe281f
#
#                                           image_uris lang  layout  \
# 0  {'small': 'https://img.scryfall.com/cards/smal...   en  normal
# 1  {'small': 'https://img.scryfall.com/cards/smal...   en  normal
#
#                                           legalities  life_modifier loyalty  \
# 0  {'standard': 'not_legal', 'future': 'not_legal...            NaN    None
# 1  {'standard': 'not_legal', 'future': 'not_legal...            NaN    None
#
#    mana_cost  mtgo_foil_id  mtgo_id multiverse_ids               name  \
# 0  {4}{G}{G}           NaN      NaN             []  Earthshaker Giant
# 1  {4}{R}{R}           NaN      NaN             []       Fiendish Duo
#
#    nonfoil object                             oracle_id  \
# 0    False   card  cd6250ae-9079-4a62-8a70-0d94fbac21bc
# 1    False   card  ab0dfae5-b9d4-417b-8a0d-2525ae3a73b9
#
#                                          oracle_text  oversized power preview  \
# 0  Trample\nWhen Earthshaker Giant enters the bat...      False     6    None
# 1  First strike\nIf a source would deal damage to...      False     5    None
#
#                                               prices printed_name  \
# 0  {'usd': None, 'usd_foil': '12.00', 'eur': None...         None
# 1  {'usd': None, 'usd_foil': '15.00', 'eur': None...         None
#
#   printed_text printed_type_line  \
# 0         None              None
# 1         None              None
#
#                                    prints_search_uri  promo promo_types  \
# 0  https://api.scryfall.com/cards/search?order=re...  False        None
# 1  https://api.scryfall.com/cards/search?order=re...  False        None
#
#                                        purchase_uris  rarity  \
# 0  {'tcgplayer': 'https://shop.tcgplayer.com/prod...  mythic
# 1  {'tcgplayer': 'https://shop.tcgplayer.com/prod...  mythic
#
#                                         related_uris released_at  reprint  \
# 0  {'tcgplayer_decks': 'https://decks.tcgplayer.c...  2019-11-15    False
# 1  {'tcgplayer_decks': 'https://decks.tcgplayer.c...  2019-11-15    False
#
#    reserved                                        rulings_uri  \
# 0     False  https://api.scryfall.com/cards/dbcdbf7a-9294-4...
# 1     False  https://api.scryfall.com/cards/acb3ce9b-ee4f-4...
#
#                                scryfall_set_uri  \
# 0  https://scryfall.com/sets/gn2?utm_source=api
# 1  https://scryfall.com/sets/gn2?utm_source=api
#
#                                         scryfall_uri  set         set_name  \
# 0  https://scryfall.com/card/gn2/5/earthshaker-gi...  gn2  Game Night 2019
# 1  https://scryfall.com/card/gn2/4/fiendish-duo?u...  gn2  Game Night 2019
#
#                                       set_search_uri set_type  \
# 0  https://api.scryfall.com/cards/search?order=se...      box
# 1  https://api.scryfall.com/cards/search?order=se...      box
#
#                                              set_uri  story_spotlight  \
# 0  https://api.scryfall.com/sets/a72727dd-dbab-41...            False
# 1  https://api.scryfall.com/sets/a72727dd-dbab-41...            False
#
#    tcgplayer_id  textless toughness               type_line  \
# 0      200607.0     False         6  Creature — Giant Druid
# 1      200606.0     False         5        Creature — Devil
#
#                                                  uri  variation variation_of  \
# 0  https://api.scryfall.com/cards/dbcdbf7a-9294-4...      False         None
# 1  https://api.scryfall.com/cards/acb3ce9b-ee4f-4...      False         None
#
#   watermark
# 0      None
# 1      None

# %%
url = all_cards_df.sample(5).image_uris.values[4]['normal']

# %%
from PIL import Image
import requests
from io import BytesIO

response = requests.get(url)
img = Image.open(BytesIO(response.content))
img.show()
